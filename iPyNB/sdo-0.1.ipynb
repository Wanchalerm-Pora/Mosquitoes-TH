# %%
import numpy as np
import os, shutil, glob, tempfile, gc
import math, random
from datetime import datetime
import PIL
import PIL.Image
import tensorflow as tf

from tensorflow import keras
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt

mos_img_dir = './datasets/ParkDatasets/ParkDatasetAug'
class_names = ['Aedes albopictus', 'Aedes vexans', 'Anopheles sinensis', 'Culex pipiens', 'Culex tritaeniorhynchus', 'Non vectors']

SDO = 0.1

NUM_EPOCH_PER_TRAIN = 40

BATCH_SIZE = 8

# initial value of learning rate
LR = 2e-5
# multiplier factor
LR_MULTIPLIER = 0.5
# number of epochs per reduction
NUM_EPOCH_PER_LR_UPDATE = 10

# original image size
IMG_SIZE = 224

# ratio of (train, val, test)
RATIO = (0.80, 0.2, 0) # train, val, test -> We don't need test = val

# Function to callback every beginning of each epoch
# Learning rate adaptation
def lr_scheduler(epoch, lr):
    return lr * LR_MULTIPLIER if (epoch % NUM_EPOCH_PER_LR_UPDATE) == 0 else lr

lr_adjust = keras.callbacks.LearningRateScheduler(lr_scheduler, verbose=1)
# Early stopping
early_stopping = keras.callbacks.EarlyStopping(monitor='val_accuracy', baseline=0.2,  min_delta = 0.0001, 
                               patience=15, restore_best_weights = True)
# Out:
# 2022-10-04 09:46:00.955904: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
from keras import initializers, Input, layers
# from tensorflow.keras.utils import Sequence
# from keras.callbacks import EarlyStopping
from keras.models import Sequential, Model, load_model
from keras.layers import Dense, Flatten, Conv2D, Concatenate, Dropout, SpatialDropout2D, SpatialDropout1D, MaxPool2D, Add

# %%
def buildSDModel():
    # Create Model that is similar to VGG16 with early combination of two images
    input0 = Input(shape=(224, 224, 3), name="img0")
    first_conv = Conv2D(filters=64, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu')(input0)
    block1_conv2 = Conv2D(filters=64, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu')(first_conv)

    maxpool_1 = MaxPool2D(pool_size=(2,2),strides=(2,2))(block1_conv2)
    spa_1 = SpatialDropout2D(SDO)(maxpool_1)
    block2_conv1 = Conv2D(filters=128, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu')(spa_1)
    block2_conv2 = Conv2D(filters=128, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu')(block2_conv1)
    maxpool_2 = MaxPool2D(pool_size=(2,2),strides=(2,2))(block2_conv2)
    spa_2 = SpatialDropout2D(SDO)(maxpool_2)
    block3_conv1 = Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu')(spa_2)
    block3_conv2 = Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu')(block3_conv1)
    block3_conv3 = Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu')(block3_conv2)
    maxpool_3 = MaxPool2D(pool_size=(2,2),strides=(2,2))(block3_conv3)
    spa_3 = SpatialDropout2D(SDO)(maxpool_3)
    block4_conv1 = Conv2D(filters=512, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu')(spa_3)
    block4_conv2 = Conv2D(filters=512, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu')(block4_conv1)
    block4_conv3 = Conv2D(filters=512, kernel_size=(3,3) ,strides=(1,1), padding='same', activation='relu')(block4_conv2)
    maxpool_4 = MaxPool2D(pool_size=(2,2),strides=(2,2))(block4_conv3)
    spa_4 = SpatialDropout2D(SDO)(maxpool_4)
    block5_conv1 = Conv2D(filters=512, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu')(spa_4)
    block5_conv2 = Conv2D(filters=512, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu')(block5_conv1)
    block5_conv3 = Conv2D(filters=512, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu')(block5_conv2)
    maxpool_5 = MaxPool2D(pool_size=(2,2),strides=(2,2))(block5_conv3)
    spa_5 = SpatialDropout2D(SDO)(maxpool_5)
    flat = Flatten()(spa_5)
    dense1 = Dense(4096, activation='relu')(flat)
    drop_1 = Dropout(0)(dense1)
    dense2 = Dense(4096, activation='relu')(drop_1)
    drop_2 = Dropout(0)(dense2)
    output = Dense(6, activation='softmax')(drop_2)
    model = Model(inputs=input0, outputs=output)
    return model

# %%
def loadVGG16ImageNetWeightsSD(model):
    # load VGG16 with imagenet weights
    from keras.applications.vgg16 import VGG16
    vgg = VGG16(include_top=True, weights ='imagenet',  input_shape=(224, 224, 3))

    # print VGG16's layer names to copy its parameters
    [layer.name for layer in vgg.layers]

    # Check our modified VGG16
    [layer.name for layer in model.layers]

    # Apply weight from VGG16 to our Modified version
    for layer in vgg.layers: 
        if layer.name == 'block1_conv1':
            model.layers[1].set_weights(layer.get_weights()),
        elif layer.name == 'block1_conv2': 
            model.layers[2].set_weights(layer.get_weights()),
        elif layer.name == 'block2_conv1': 
            model.layers[5].set_weights(layer.get_weights()) 
        elif layer.name == 'block2_conv2': 
            model.layers[6].set_weights(layer.get_weights())
        elif layer.name == 'block3_conv1':
            model.layers[9].set_weights(layer.get_weights())
        elif layer.name == 'block3_conv2':
            model.layers[10].set_weights(layer.get_weights())
        elif layer.name == 'block3_conv3':
            model.layers[11].set_weights(layer.get_weights())
        elif layer.name == 'block4_conv1':
            model.layers[14].set_weights(layer.get_weights())
        elif layer.name == 'block4_conv2':
            model.layers[15].set_weights(layer.get_weights())
        elif layer.name == 'block4_conv3':
            model.layers[16].set_weights(layer.get_weights())
        elif layer.name == 'block5_conv1':
            model.layers[19].set_weights(layer.get_weights())
        elif layer.name == 'block5_conv2':
            model.layers[20].set_weights(layer.get_weights())
        elif layer.name == 'block5_conv3':
            model.layers[21].set_weights(layer.get_weights())
        elif layer.name == 'fc1':
            model.layers[25].set_weights(layer.get_weights())
        elif layer.name == 'fc2':
            model.layers[27].set_weights(layer.get_weights())
    return model

# %%
def between0i1x(f):
    if 0 <= f < 1:
        return True
    else:
        return False

# %%
def RandomTrainValTest(src_dir, dst_dir, ratio = (0.8, 0.2, 0)):
    #check if Destination directory already exists
    if os.path.exists(dst_dir):
        print('Destination directory already exists. Do nothing!!!')
        return
    TRAIN_RATIO = round(ratio[0], 3)
    VAL_RATIO = round(ratio[1], 3)
    TEST_RATIO = round(1 - TRAIN_RATIO - VAL_RATIO, 3)
    if not between0i1x(TEST_RATIO) or not between0i1x(VAL_RATIO) or not between0i1x(TRAIN_RATIO):
        print('Ratio must be more than or equal 0 and less than 1.')
        return
    print('Ratio = (' + str(TRAIN_RATIO) +', ' + str(VAL_RATIO) + ', ' + str(TEST_RATIO) + ').' )
    if TEST_RATIO != round(ratio[2],3):
        print('Sum of ratio must be 1.')
        return
    
    # create a temp dir and copy all files recursively to temp_dir
    tmp = tempfile.TemporaryDirectory()
    tmp_dir = tmp.name + '/tmp/'
    shutil.copytree(src_dir, tmp_dir)
    # scan species, they must be immediatly under the src_dir 
    for species in os.scandir(src_dir):
        if not species.name.startswith('.') and species.is_dir():
            class_dir = tmp_dir + '/' + species.name
            print('Found ' + species.name)
            #calculate No. of files in each species 
            file_no = 0
            for entry2 in os.scandir(class_dir):
                if not entry2.name.startswith('.') and entry2.is_file():
                    file_no += 1
            print('No. of files in ' + species.name + ' = ' + str(file_no) + '.')
            # create subdirectories if necessary
            if not os.path.exists(dst_dir):
                os.mkdir(dst_dir)
            test_dir = dst_dir + '/test/' 
            val_dir = dst_dir + '/val/' 
            train_dir = dst_dir + '/train/' 
            if not os.path.exists(test_dir):
                os.mkdir(test_dir)
            if not os.path.exists(val_dir):
                os.mkdir(val_dir)
            if not os.path.exists(train_dir):
                os.mkdir(train_dir)
            # create species.name dir    
            stest_dir = test_dir + species.name + '/'
            sval_dir = val_dir + species.name + '/'
            strain_dir = train_dir + species.name + '/'
            if not os.path.exists(stest_dir):
                os.mkdir(stest_dir)
            if not os.path.exists(sval_dir):
                os.mkdir(sval_dir)
            if not os.path.exists(strain_dir):
                os.mkdir(strain_dir)
            # calculate number of files for train, val, test    
            no_file_train = math.ceil(file_no*TRAIN_RATIO)
            no_file_val = math.ceil(file_no*VAL_RATIO)
            no_file_test = math.ceil(file_no*TEST_RATIO)
            
            # for training data
            file_no = 0
            while file_no < no_file_train : 
                selectedFile = random.choice(os.listdir(tmp_dir + '/' + species.name))
                # find index no
                no = selectedFile.rfind('_') 
                # select all files that have the same index no.
                SelectedFiles = '*' + selectedFile[no:] 
                # move all the selected files
                file_moved = 0
                for file in glob.iglob(class_dir +'/'+ SelectedFiles, recursive=True):    
                    file_name = os.path.basename(file)
                    shutil.move(file, strain_dir + file_name)
                    file_moved += 1
                # sum file_moved to file_no    
                file_no += file_moved
            print('No. of files in "' + strain_dir + '" should be around ' + str(no_file_train) + '.')
            print('No. of files in ' +strain_dir + ' = ' + str(file_no) +'.' )
            
            # for test data
            file_no = 0
            while file_no < no_file_test and os.listdir(tmp_dir + '/' + species.name): 
                selectedFile = random.choice(os.listdir(tmp_dir + '/' + species.name))
                # find index no
                no = selectedFile.rfind('_') 
                # select all files that have the same index no.
                SelectedFiles = '*' + selectedFile[no:] 
                # move all the selected files
                file_moved = 0
                for file in glob.iglob(class_dir +'/'+ SelectedFiles, recursive=True):    
                    file_name = os.path.basename(file)
                    shutil.move(file, strain_dir + file_name)
                    file_moved += 1
                # sum file_moved to file_no    
                file_no += file_moved
            print('No. of files in "' + stest_dir + '" should be around ' + str(no_file_test) + '.')
            print('No. of files in ' +stest_dir + ' = ' + str(file_no) +'.' )
            #move all remaining files to val_dir
            SelectedFiles = '*'
            file_moved = 0
            for file in glob.iglob(class_dir +'/'+ SelectedFiles, recursive=True):    
                file_name = os.path.basename(file)
                shutil.move(file, sval_dir + file_name)
                file_moved += 1
            file_no = file_moved    
            print('No. of files in "' + sval_dir + '" should be around ' + str(no_file_val) + '.')
            print('No. of files in ' +sval_dir + ' = ' + str(file_no) +'.' )

# %%
def read_ds(src_dir):
    
    train_dir = src_dir  + '/train'
    val_dir = src_dir    + '/val'
    
    train_ds = tf.keras.utils.image_dataset_from_directory(
      train_dir,
      #validation_split=0.2,
      #subset="training",
      seed=123,
      image_size=(IMG_SIZE, IMG_SIZE),
      shuffle = False,
      label_mode='categorical',
      batch_size=BATCH_SIZE)

    val_ds = tf.keras.utils.image_dataset_from_directory(
      val_dir,
      #validation_split=0.2,
      #subset="validation",
      seed=123,
      shuffle = False,
      label_mode='categorical',
      image_size=(IMG_SIZE, IMG_SIZE),
      batch_size=BATCH_SIZE)



    return (train_ds, val_ds)

# %%
def preprocessDS(train_ds, val_ds):
    train_num_batch = sum(1 for _ in train_ds)
    val_num_batch = sum(1 for _ in val_ds)

    # Normalize to (0-1)
    normalization_layer = tf.keras.layers.Rescaling(1./255)
    train_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
    val_ds = val_ds.map(lambda x, y: (normalization_layer(x), y))




    # Load the dataset onto GPU RAM for superspeed
    train_ds = train_ds.cache()
    val_ds = val_ds.cache()

    # reshuffle the train ds every batch (second times onwords in GPU), but shuffle val ds only once
    train_ds = train_ds.shuffle(train_num_batch, reshuffle_each_iteration=True)
    val_ds   = val_ds.shuffle(val_num_batch, reshuffle_each_iteration=False)


    # prefetch the datasets for lower latency
    train_ds = train_ds.prefetch(tf.data.AUTOTUNE)
    val_ds = val_ds.prefetch(tf.data.AUTOTUNE)

    return (train_ds, val_ds)
    #...

# %%
def compileModel(model):
    # Optimizer hyperparameter
    myAdam = keras.optimizers.Adam(
        learning_rate=LR/LR_MULTIPLIER,
        beta_1=0.9,
        beta_2=0.999,
        epsilon=0.0001,
        amsgrad=True,
        name="Adam",)

    model.compile(optimizer=myAdam,
              loss=tf.keras.losses.CategoricalCrossentropy(
                    from_logits=False,
                    label_smoothing=0.0,
                    axis=-1,
                    reduction="auto",
                    name="categorical_crossentropy"),
              metrics=['accuracy'])
    return model

# %%
def fitModel(model, train_ds, val_ds, lr_adjust = None, early_stopping = None):
    print('Start fitting from ' + datetime.now().strftime("%Y/%m/%d-%H:%M:%S"))
    history = model.fit(train_ds,    
                  epochs=NUM_EPOCH_PER_TRAIN,   
                  validation_data = val_ds,
                  callbacks=[lr_adjust, early_stopping])
    print('End fitting at '+ datetime.now().strftime("%Y/%m/%d-%H:%M:%S"))
    return history

# %%
def plotAccuracyLoss(hist):
    acc = hist.history['accuracy']
    val_acc = hist.history['val_accuracy']

    loss = hist.history['loss']
    val_loss = hist.history['val_loss']

    #epochs_range = range(epochs)
    epochs_range = range(len(loss))
    plt.figure(figsize=(8, 8))
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.show()

# %%
def printConfusionMatrix(model, ds):
    #Confution Matrix and Classification Report

    Y_pred = model.predict(ds)
    y_pred = np.argmax(Y_pred, axis=1)
    Y_true = np.concatenate([y for x, y in ds], axis=0)
    y_true = np.argmax(Y_true, axis=1)
    print('Confusion Matrix')
    print(confusion_matrix(y_true, y_pred))
    print('')
    print('')
    print('Classification Report')

    print(classification_report(y_true, y_pred, target_names=class_names))

# %%
def saveSDOModel(model):
    path = './models/Model_SDO_Park_' + datetime.now().strftime("%Y-%m-%d_%H-%M") +'.h5'
    print('Model is saved in ' + path)
    model.save(path)
    return path

# %%
tmpX = tempfile.TemporaryDirectory().name
RandomTrainValTest(mos_img_dir, tmpX, ratio = (0.8,0.2,0))
# Out:
# Ratio = (0.8, 0.2, -0.0).
# Found Aedes vexans
# No. of files in Aedes vexans = 5901.
# No. of files in "/tmp/tmpvf2b0qfm/train/Aedes vexans/" should be around 4721.
# No. of files in /tmp/tmpvf2b0qfm/train/Aedes vexans/ = 4727.
# No. of files in "/tmp/tmpvf2b0qfm/test/Aedes vexans/" should be around 0.
# No. of files in /tmp/tmpvf2b0qfm/test/Aedes vexans/ = 0.
# No. of files in "/tmp/tmpvf2b0qfm/val/Aedes vexans/" should be around 1181.
# No. of files in /tmp/tmpvf2b0qfm/val/Aedes vexans/ = 1174.
# Found Anopheles sinensis
# No. of files in Anopheles sinensis = 5923.
# No. of files in "/tmp/tmpvf2b0qfm/train/Anopheles sinensis/" should be around 4739.
# No. of files in /tmp/tmpvf2b0qfm/train/Anopheles sinensis/ = 4765.
# No. of files in "/tmp/tmpvf2b0qfm/test/Anopheles sinensis/" should be around 0.
# No. of files in /tmp/tmpvf2b0qfm/test/Anopheles sinensis/ = 0.
# No. of files in "/tmp/tmpvf2b0qfm/val/Anopheles sinensis/" should be around 1185.
# No. of files in /tmp/tmpvf2b0qfm/val/Anopheles sinensis/ = 1158.
# Found Culex tritaeniorhynchus
# No. of files in Culex tritaeniorhynchus = 5940.
# No. of files in "/tmp/tmpvf2b0qfm/train/Culex tritaeniorhynchus/" should be around 4752.
# No. of files in /tmp/tmpvf2b0qfm/train/Culex tritaeniorhynchus/ = 4781.
# No. of files in "/tmp/tmpvf2b0qfm/test/Culex tritaeniorhynchus/" should be around 0.
# No. of files in /tmp/tmpvf2b0qfm/test/Culex tritaeniorhynchus/ = 0.
# No. of files in "/tmp/tmpvf2b0qfm/val/Culex tritaeniorhynchus/" should be around 1188.
# No. of files in /tmp/tmpvf2b0qfm/val/Culex tritaeniorhynchus/ = 1159.
# Found Aedes albopictus
# No. of files in Aedes albopictus = 6000.
# No. of files in "/tmp/tmpvf2b0qfm/train/Aedes albopictus/" should be around 4800.
# No. of files in /tmp/tmpvf2b0qfm/train/Aedes albopictus/ = 4805.
# No. of files in "/tmp/tmpvf2b0qfm/test/Aedes albopictus/" should be around 0.
# No. of files in /tmp/tmpvf2b0qfm/test/Aedes albopictus/ = 0.
# No. of files in "/tmp/tmpvf2b0qfm/val/Aedes albopictus/" should be around 1200.
# No. of files in /tmp/tmpvf2b0qfm/val/Aedes albopictus/ = 1195.
# Found Non vectors
# No. of files in Non vectors = 6006.
# No. of files in "/tmp/tmpvf2b0qfm/train/Non vectors/" should be around 4805.
# No. of files in /tmp/tmpvf2b0qfm/train/Non vectors/ = 4809.
# No. of files in "/tmp/tmpvf2b0qfm/test/Non vectors/" should be around 0.
# No. of files in /tmp/tmpvf2b0qfm/test/Non vectors/ = 0.
# No. of files in "/tmp/tmpvf2b0qfm/val/Non vectors/" should be around 1202.
# No. of files in /tmp/tmpvf2b0qfm/val/Non vectors/ = 1197.
# Found Culex pipiens
# No. of files in Culex pipiens = 5970.
# No. of files in "/tmp/tmpvf2b0qfm/train/Culex pipiens/" should be around 4776.
# No. of files in /tmp/tmpvf2b0qfm/train/Culex pipiens/ = 4776.
# No. of files in "/tmp/tmpvf2b0qfm/test/Culex pipiens/" should be around 0.
# No. of files in /tmp/tmpvf2b0qfm/test/Culex pipiens/ = 0.
# No. of files in "/tmp/tmpvf2b0qfm/val/Culex pipiens/" should be around 1194.
# No. of files in /tmp/tmpvf2b0qfm/val/Culex pipiens/ = 1194.

# %%
(train_ds, val_ds) = read_ds(tmpX)
(train_ds, val_ds) = preprocessDS(train_ds, val_ds)
# Out:
# Found 28663 files belonging to 6 classes.
# 2022-10-04 09:46:14.923160: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-04 09:46:15.844932: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22232 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:af:00.0, compute capability: 8.6
# Found 7077 files belonging to 6 classes.

# %%
model = buildSDModel()
model.summary()
model = loadVGG16ImageNetWeightsSD(model)
model = compileModel(model)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  img0 (InputLayer)           [(None, 224, 224, 3)]     0
#
#  conv2d (Conv2D)             (None, 224, 224, 64)      1792
#
#  conv2d_1 (Conv2D)           (None, 224, 224, 64)      36928
#
#  max_pooling2d (MaxPooling2D  (None, 112, 112, 64)     0
#  )
#
#  spatial_dropout2d (SpatialD  (None, 112, 112, 64)     0
#  ropout2D)
#
#  conv2d_2 (Conv2D)           (None, 112, 112, 128)     73856
#
#  conv2d_3 (Conv2D)           (None, 112, 112, 128)     147584
#
#  max_pooling2d_1 (MaxPooling  (None, 56, 56, 128)      0
#  2D)
#
#  spatial_dropout2d_1 (Spatia  (None, 56, 56, 128)      0
#  lDropout2D)
#
#  conv2d_4 (Conv2D)           (None, 56, 56, 256)       295168
#
#  conv2d_5 (Conv2D)           (None, 56, 56, 256)       590080
#
#  conv2d_6 (Conv2D)           (None, 56, 56, 256)       590080
#
#  max_pooling2d_2 (MaxPooling  (None, 28, 28, 256)      0
#  2D)
#
#  spatial_dropout2d_2 (Spatia  (None, 28, 28, 256)      0
#  lDropout2D)
#
#  conv2d_7 (Conv2D)           (None, 28, 28, 512)       1180160
#
#  conv2d_8 (Conv2D)           (None, 28, 28, 512)       2359808
#
#  conv2d_9 (Conv2D)           (None, 28, 28, 512)       2359808
#
#  max_pooling2d_3 (MaxPooling  (None, 14, 14, 512)      0
#  2D)
#
#  spatial_dropout2d_3 (Spatia  (None, 14, 14, 512)      0
#  lDropout2D)
#
#  conv2d_10 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  conv2d_11 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  conv2d_12 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  max_pooling2d_4 (MaxPooling  (None, 7, 7, 512)        0
#  2D)
#
#  spatial_dropout2d_4 (Spatia  (None, 7, 7, 512)        0
#  lDropout2D)
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 4096)              102764544
#
#  dropout (Dropout)           (None, 4096)              0
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  dropout_1 (Dropout)         (None, 4096)              0
#
#  dense_2 (Dense)             (None, 6)                 24582
#
# =================================================================
# Total params: 134,285,126
# Trainable params: 134,285,126
# Non-trainable params: 0
# _________________________________________________________________

# %%
fitHistory = fitModel(model, train_ds, val_ds, lr_adjust, early_stopping)
maxAcc = np.max(fitHistory.history['val_accuracy'])
# Out:
# Start fitting from 2022/10/04-09:46:23
#
# Epoch 1: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 1/40
# 2022-10-04 09:46:29.937257: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8401
# 2022-10-04 09:46:32.352311: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 3583/3583 [==============================] - 228s 61ms/step - loss: 1.2735 - accuracy: 0.4787 - val_loss: 0.6454 - val_accuracy: 0.7553 - lr: 2.0000e-05
#
# Epoch 2: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 2/40
# 3583/3583 [==============================] - 213s 60ms/step - loss: 0.3475 - accuracy: 0.8720 - val_loss: 0.1885 - val_accuracy: 0.9375 - lr: 2.0000e-05
#
# Epoch 3: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 3/40
# 3583/3583 [==============================] - 213s 59ms/step - loss: 0.1357 - accuracy: 0.9527 - val_loss: 0.1668 - val_accuracy: 0.9429 - lr: 2.0000e-05
#
# Epoch 4: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 4/40
# 3583/3583 [==============================] - 214s 60ms/step - loss: 0.0730 - accuracy: 0.9750 - val_loss: 0.1163 - val_accuracy: 0.9665 - lr: 2.0000e-05
#
# Epoch 5: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 5/40
# 3583/3583 [==============================] - 214s 60ms/step - loss: 0.0428 - accuracy: 0.9852 - val_loss: 0.0887 - val_accuracy: 0.9756 - lr: 2.0000e-05
#
# Epoch 6: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 6/40
# 3583/3583 [==============================] - 211s 59ms/step - loss: 0.0277 - accuracy: 0.9915 - val_loss: 0.0963 - val_accuracy: 0.9775 - lr: 2.0000e-05
#
# Epoch 7: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 7/40
# 3583/3583 [==============================] - 209s 58ms/step - loss: 0.0215 - accuracy: 0.9925 - val_loss: 0.0880 - val_accuracy: 0.9792 - lr: 2.0000e-05
#
# Epoch 8: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 8/40
# 3583/3583 [==============================] - 209s 58ms/step - loss: 0.0229 - accuracy: 0.9926 - val_loss: 0.1213 - val_accuracy: 0.9641 - lr: 2.0000e-05
#
# Epoch 9: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 9/40
# 3583/3583 [==============================] - 208s 58ms/step - loss: 0.0112 - accuracy: 0.9968 - val_loss: 0.0950 - val_accuracy: 0.9773 - lr: 2.0000e-05
#
# Epoch 10: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 10/40
# 3583/3583 [==============================] - 209s 58ms/step - loss: 0.0093 - accuracy: 0.9969 - val_loss: 0.1363 - val_accuracy: 0.9640 - lr: 2.0000e-05
#
# Epoch 11: LearningRateScheduler setting learning rate to 9.999999747378752e-06.
# Epoch 11/40
# 3583/3583 [==============================] - 209s 58ms/step - loss: 0.0032 - accuracy: 0.9990 - val_loss: 0.1020 - val_accuracy: 0.9788 - lr: 1.0000e-05
#
# Epoch 12: LearningRateScheduler setting learning rate to 9.999999747378752e-06.
# Epoch 12/40
# 3583/3583 [==============================] - 211s 59ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0932 - val_accuracy: 0.9805 - lr: 1.0000e-05
#
# Epoch 13: LearningRateScheduler setting learning rate to 9.999999747378752e-06.
# Epoch 13/40
# 3583/3583 [==============================] - 209s 58ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 0.0846 - val_accuracy: 0.9835 - lr: 1.0000e-05
#
# Epoch 14: LearningRateScheduler setting learning rate to 9.999999747378752e-06.
# Epoch 14/40
# 3583/3583 [==============================] - 209s 58ms/step - loss: 0.0027 - accuracy: 0.9993 - val_loss: 0.0915 - val_accuracy: 0.9806 - lr: 1.0000e-05
#
# Epoch 15: LearningRateScheduler setting learning rate to 9.999999747378752e-06.
# Epoch 15/40
# 3583/3583 [==============================] - 209s 58ms/step - loss: 0.0017 - accuracy: 0.9994 - val_loss: 0.0886 - val_accuracy: 0.9818 - lr: 1.0000e-05
#
# Epoch 16: LearningRateScheduler setting learning rate to 9.999999747378752e-06.
# Epoch 16/40
# 3583/3583 [==============================] - 209s 58ms/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.0979 - val_accuracy: 0.9801 - lr: 1.0000e-05
#
# Epoch 17: LearningRateScheduler setting learning rate to 9.999999747378752e-06.
# Epoch 17/40
# 3583/3583 [==============================] - 209s 58ms/step - loss: 9.9172e-04 - accuracy: 0.9998 - val_loss: 0.1054 - val_accuracy: 0.9799 - lr: 1.0000e-05
#
# Epoch 18: LearningRateScheduler setting learning rate to 9.999999747378752e-06.
# Epoch 18/40
# 3583/3583 [==============================] - 208s 58ms/step - loss: 6.6113e-04 - accuracy: 0.9998 - val_loss: 0.0885 - val_accuracy: 0.9829 - lr: 1.0000e-05
#
# Epoch 19: LearningRateScheduler setting learning rate to 9.999999747378752e-06.
# Epoch 19/40
# 3583/3583 [==============================] - 208s 58ms/step - loss: 0.0025 - accuracy: 0.9992 - val_loss: 0.0849 - val_accuracy: 0.9828 - lr: 1.0000e-05
#
# Epoch 20: LearningRateScheduler setting learning rate to 9.999999747378752e-06.
# Epoch 20/40
# 3583/3583 [==============================] - 209s 58ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.1032 - val_accuracy: 0.9816 - lr: 1.0000e-05
#
# Epoch 21: LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 21/40
# 3583/3583 [==============================] - 209s 58ms/step - loss: 7.8324e-04 - accuracy: 0.9998 - val_loss: 0.0986 - val_accuracy: 0.9818 - lr: 5.0000e-06
#
# Epoch 22: LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 22/40
# 3583/3583 [==============================] - 208s 58ms/step - loss: 7.0443e-04 - accuracy: 0.9998 - val_loss: 0.0963 - val_accuracy: 0.9811 - lr: 5.0000e-06
#
# Epoch 23: LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 23/40
# 3583/3583 [==============================] - 203s 57ms/step - loss: 8.6167e-04 - accuracy: 0.9997 - val_loss: 0.0974 - val_accuracy: 0.9825 - lr: 5.0000e-06
#
# Epoch 24: LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 24/40
# 3583/3583 [==============================] - 206s 58ms/step - loss: 6.8559e-04 - accuracy: 0.9998 - val_loss: 0.0957 - val_accuracy: 0.9830 - lr: 5.0000e-06
#
# Epoch 25: LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 25/40
# 3583/3583 [==============================] - 209s 58ms/step - loss: 4.4691e-04 - accuracy: 0.9999 - val_loss: 0.0941 - val_accuracy: 0.9825 - lr: 5.0000e-06
#
# Epoch 26: LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 26/40
# 3583/3583 [==============================] - 212s 59ms/step - loss: 4.3787e-04 - accuracy: 0.9999 - val_loss: 0.0971 - val_accuracy: 0.9815 - lr: 5.0000e-06
#
# Epoch 27: LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 27/40
# 3583/3583 [==============================] - 211s 59ms/step - loss: 9.9692e-04 - accuracy: 0.9997 - val_loss: 0.0941 - val_accuracy: 0.9829 - lr: 5.0000e-06
#
# Epoch 28: LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 28/40
# 3583/3583 [==============================] - 212s 59ms/step - loss: 3.8174e-04 - accuracy: 0.9999 - val_loss: 0.0908 - val_accuracy: 0.9822 - lr: 5.0000e-06
# End fitting at 2022/10/04-11:24:32

# %%
print('Maximum test accuracy is at', np.round(maxAcc*100,2), '%.')
plotAccuracyLoss(fitHistory)
# Out:
# Maximum test accuracy is at 98.35 %.

# %%
printConfusionMatrix(model, val_ds)
earlyModelPath = saveSDOModel(model)
# Out:
# 885/885 [==============================] - 13s 15ms/step
# Confusion Matrix
# [[1181    1    0    9    0    4]
#  [   0 1145    0    1   17   11]
#  [   1    5 1134    0    7   11]
#  [   0    9    0 1183    0    2]
#  [   0    9    0    0 1150    0]
#  [   8   10    2    6    4 1167]]
#
#
# Classification Report
#                          precision    recall  f1-score   support
#
#        Aedes albopictus       0.99      0.99      0.99      1195
#            Aedes vexans       0.97      0.98      0.97      1174
#      Anopheles sinensis       1.00      0.98      0.99      1158
#           Culex pipiens       0.99      0.99      0.99      1194
# Culex tritaeniorhynchus       0.98      0.99      0.98      1159
#             Non vectors       0.98      0.97      0.98      1197
#
#                accuracy                           0.98      7077
#               macro avg       0.98      0.98      0.98      7077
#            weighted avg       0.98      0.98      0.98      7077
#
# Model is saved in ./models/Model_SDO_Park_2022-10-04_11-24.h5

# %%
#-----Run 2

# %%
tmpX = tempfile.TemporaryDirectory().name
RandomTrainValTest(mos_img_dir, tmpX, ratio = (0.8,0.2,0))
#-----------------------
# Out:
# Ratio = (0.8, 0.2, -0.0).
# Found Aedes vexans
# No. of files in Aedes vexans = 5901.
# No. of files in "/tmp/tmpr9blnvxf/train/Aedes vexans/" should be around 4721.
# No. of files in /tmp/tmpr9blnvxf/train/Aedes vexans/ = 4740.
# No. of files in "/tmp/tmpr9blnvxf/test/Aedes vexans/" should be around 0.
# No. of files in /tmp/tmpr9blnvxf/test/Aedes vexans/ = 0.
# No. of files in "/tmp/tmpr9blnvxf/val/Aedes vexans/" should be around 1181.
# No. of files in /tmp/tmpr9blnvxf/val/Aedes vexans/ = 1161.
# Found Anopheles sinensis
# No. of files in Anopheles sinensis = 5923.
# No. of files in "/tmp/tmpr9blnvxf/train/Anopheles sinensis/" should be around 4739.
# No. of files in /tmp/tmpr9blnvxf/train/Anopheles sinensis/ = 4763.
# No. of files in "/tmp/tmpr9blnvxf/test/Anopheles sinensis/" should be around 0.
# No. of files in /tmp/tmpr9blnvxf/test/Anopheles sinensis/ = 0.
# No. of files in "/tmp/tmpr9blnvxf/val/Anopheles sinensis/" should be around 1185.
# No. of files in /tmp/tmpr9blnvxf/val/Anopheles sinensis/ = 1160.
# Found Culex tritaeniorhynchus
# No. of files in Culex tritaeniorhynchus = 5940.
# No. of files in "/tmp/tmpr9blnvxf/train/Culex tritaeniorhynchus/" should be around 4752.
# No. of files in /tmp/tmpr9blnvxf/train/Culex tritaeniorhynchus/ = 4767.
# No. of files in "/tmp/tmpr9blnvxf/test/Culex tritaeniorhynchus/" should be around 0.
# No. of files in /tmp/tmpr9blnvxf/test/Culex tritaeniorhynchus/ = 0.
# No. of files in "/tmp/tmpr9blnvxf/val/Culex tritaeniorhynchus/" should be around 1188.
# No. of files in /tmp/tmpr9blnvxf/val/Culex tritaeniorhynchus/ = 1173.
# Found Aedes albopictus
# No. of files in Aedes albopictus = 6000.
# No. of files in "/tmp/tmpr9blnvxf/train/Aedes albopictus/" should be around 4800.
# No. of files in /tmp/tmpr9blnvxf/train/Aedes albopictus/ = 4801.
# No. of files in "/tmp/tmpr9blnvxf/test/Aedes albopictus/" should be around 0.
# No. of files in /tmp/tmpr9blnvxf/test/Aedes albopictus/ = 0.
# No. of files in "/tmp/tmpr9blnvxf/val/Aedes albopictus/" should be around 1200.
# No. of files in /tmp/tmpr9blnvxf/val/Aedes albopictus/ = 1199.
# Found Non vectors
# No. of files in Non vectors = 6006.
# No. of files in "/tmp/tmpr9blnvxf/train/Non vectors/" should be around 4805.
# No. of files in /tmp/t
# %%
tmpX = tempfile.TemporaryDirectory().name
RandomTrainValTest(mos_img_dir, tmpX, ratio = (0.8,0.2,0))
#-----------------------
# Out:
# Ratio = (0.8, 0.2, -0.0).
# Found Aedes vexans
# No. of files in Aedes vexans = 5901.
# No. of files in "/tmp/tmp7tt4evt0/train/Aedes vexans/" should be around 4721.
# No. of files in /tmp/tmp7tt4evt0/train/Aedes vexans/ = 4723.
# No. of files in "/tmp/tmp7tt4evt0/test/Aedes vexans/" should be around 0.
# No. of files in /tmp/tmp7tt4evt0/test/Aedes vexans/ = 0.
# No. of files in "/tmp/tmp7tt4evt0/val/Aedes vexans/" should be around 1181.
# No. of files in /tmp/tmp7tt4evt0/val/Aedes vexans/ = 1178.
# Found Anopheles sinensis
# No. of files in Anopheles sinensis = 5923.
# No. of files in "/tmp/tmp7tt4evt0/train/Anopheles sinensis/" should be around 4739.
# No. of files in /tmp/tmp7tt4evt0/train/Anopheles sinensis/ = 4739.
# No. of files in "/tmp/tmp7tt4evt0/test/Anopheles sinensis/" should be around 0.
# No. of files in /tmp/tmp7tt4evt0/test/Anopheles sinensis/ = 0.
# No. of files in "/tmp/tmp7tt4evt0/val/Anopheles sinensis/" should be around 1185.
# No. of files in /tmp/tmp7tt4evt0/val/Anopheles sinensis/ = 1184.
# Found Culex tritaeniorhynchus
# No. of files in Culex tritaeniorhynchus = 5940.
# No. of files in "/tmp/tmp7tt4evt0/train/Culex tritaeniorhynchus/" should be around 4752.
# No. of files in /tmp/tmp7tt4evt0/train/Culex tritaeniorhynchus/ = 4773.
# No. of files in "/tmp/tmp7tt4evt0/test/Culex tritaeniorhynchus/" should be around 0.
# No. of files in /tmp/tmp7tt4evt0/test/Culex tritaeniorhynchus/ = 0.
# No. of files in "/tmp/tmp7tt4evt0/val/Culex tritaeniorhynchus/" should be around 1188.
# No. of files in /tmp/tmp7tt4evt0/val/Culex tritaeniorhynchus/ = 1167.
# Found Aedes albopictus
# No. of files in Aedes albopictus = 6000.
# No. of files in "/tmp/tmp7tt4evt0/train/Aedes albopictus/" should be around 4800.
# No. of files in /tmp/tmp7tt4evt0/train/Aedes albopictus/ = 4817.
# No. of files in "/tmp/tmp7tt4evt0/test/Aedes albopictus/" should be around 0.
# No. of files in /tmp/tmp7tt4evt0/test/Aedes albopictus/ = 0.
# No. of files in "/tmp/tmp7tt4evt0/val/Aedes albopictus/" should be around 1200.
# No. of files in /tmp/tmp7tt4evt0/val/Aedes albopictus/ = 1183.
# Found Non vectors
# No. of files in Non vectors = 6006.
# No. of files in "/tmp/tmp7tt4evt0/train/Non vectors/" should be around 4805.
# No. of files in /tmp/tmp7tt4evt0/train/Non vectors/ = 4815.
# No. of files in "/tmp/tmp7tt4evt0/test/Non vectors/" should be around 0.
# No. of files in /tmp/tmp7tt4evt0/test/Non vectors/ = 0.
# No. of files in "/tmp/tmp7tt4evt0/val/Non vectors/" should be around 1202.
# No. of files in /tmp/tmp7tt4evt0/val/Non vectors/ = 1191.
# Found Culex pipiens
# No. of files in Culex pipiens = 5970.
# No. of files in "/tmp/tmp7tt4evt0/train/Culex pipiens/" should be around 4776.
# No. of files in /tmp/tmp7tt4evt0/train/Culex pipiens/ = 4780.
# No. of files in "/tmp/tmp7tt4evt0/test/Culex pipiens/" should be around 0.
# No. of files in /tmp/tmp7tt4evt0/test/Culex pipiens/ = 0.
# No. of files in "/tmp/tmp7tt4evt0/val/Culex pipiens/" should be around 1194.
# No. of files in /tmp/tmp7tt4evt0/val/Culex pipiens/ = 1190.

# %%
(train_ds, val_ds) = read_ds(tmpX)
(train_ds, val_ds) = preprocessDS(train_ds, val_ds)
#-----------------------
# Out:
# Found 28647 files belonging to 6 classes.
# Found 7093 files belonging to 6 classes.

# %%
model = buildSDModel()
model = loadVGG16ImageNetWeightsSD(model)
model = compileModel(model)
fitHistory = fitModel(model, train_ds, val_ds, lr_adjust, early_stopping)
#-----------------------
# Out:
# Start fitting from 2022/10/04-13:44:50
#
# Epoch 1: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 1/40
# 3581/3581 [==============================] - 208s 56ms/step - loss: 1.4513 - accuracy: 0.3884 - val_loss: 1.0539 - val_accuracy: 0.5861 - lr: 2.0000e-05
#
# Epoch 2: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 2/40
# 3581/3581 [==============================] - 208s 58ms/step - loss: 0.5933 - accuracy: 0.7725 - val_loss: 0.3007 - val_accuracy: 0.8943 - lr: 2.0000e-05
#
# Epoch 3: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 3/40
# 3581/3581 [==============================] - 200s 56ms/step - loss: 0.1967 - accuracy: 0.9288 - val_loss: 0.2797 - val_accuracy: 0.9009 - lr: 2.0000e-05
#
# Epoch 4: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 4/40
# 3581/3581 [==============================] - 210s 59ms/step - loss: 0.1005 - accuracy: 0.9654 - val_loss: 0.1100 - val_accuracy: 0.9612 - lr: 2.0000e-05
#
# Epoch 5: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 5/40
# 3581/3581 [==============================] - 208s 58ms/step - loss: 0.0568 - accuracy: 0.9801 - val_loss: 0.1577 - val_accuracy: 0.9543 - lr: 2.0000e-05
#
# Epoch 6: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 6/40
# 3581/3581 [==============================] - 203s 57ms/step - loss: 0.0399 - accuracy: 0.9864 - val_loss: 0.1063 - val_accuracy: 0.9707 - lr: 2.0000e-05
#
# Epoch 7: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 7/40
# 3581/3581 [==============================] - 206s 57ms/step - loss: 0.0284 - accuracy: 0.9905 - val_loss: 0.1153 - val_accuracy: 0.9672 - lr: 2.0000e-05
#
# Epoch 8: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 8/40
# 3581/3581 [==============================] - 208s 58ms/step - loss: 0.0211 - accuracy: 0.9926 - val_loss: 0.0918 - val_accuracy: 0.9739 - lr: 2.0000e-05
#
# Epoch 9: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 9/40
# 3581/3581 [==============================] - 206s 57ms/step - loss: 0.0152 - accuracy: 0.9946 - val_loss: 0.1042 - val_accuracy: 0.9734 - lr: 2.0000e-05
#
# Epoch 10: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 10/40
# 3581/3581 [==============================] - 203s 57ms/step - loss: 0.0116 - accuracy: 0.9960 - val_loss: 0.0760 - val_accuracy: 0.9804 - lr: 2.0000e-05
#
# Epoch 11: LearningRateScheduler setting learning rate to 9.999999747378752e-06.
# Epoch 11/40
# 3581/3581 [==============================] - 206s 58ms/step - loss: 0.0051 - accuracy: 0.9986 - val_loss: 0.0743 - val_accuracy: 0.9794 - lr: 1.0000e-05
#
# Epoch 12: LearningRateScheduler setting learning rate to 9.999999747378752e-06.
# Epoch 12/40
# 3581/3581 [==============================] - 210s 59ms/step - loss: 0.0028 - accuracy: 0.9991 - val_loss: 0.0804 - val_accuracy: 0.9815 - lr: 1.0000e-05
#
# Epoch 13: LearningRateScheduler setting learning rate to 9.999999747378752e-06.
# Epoch 13/40
# 
-06
#
# Epoch 37: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 37/40
# 3581/3581 [==============================] - 203s 57ms/step - loss: 6.3543e-04 - accuracy: 0.9997 - val_loss: 0.0890 - val_accuracy: 0.9835 - lr: 2.5000e-06
#
# Epoch 38: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 38/40
# 3581/3581 [==============================] - 204s 57ms/step - loss: 2.8643e-04 - accuracy: 0.9999 - val_loss: 0.0800 - val_accuracy: 0.9846 - lr: 2.5000e-06
#
# Epoch 39: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 39/40
# 3581/3581 [==============================] - 210s 59ms/step - loss: 2.9257e-04 - accuracy: 0.9999 - val_loss: 0.0831 - val_accuracy: 0.9846 - lr: 2.5000e-06
#
# Epoch 40: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 40/40
# 3581/3581 [==============================] - 205s 57ms/step - loss: 3.1430e-04 - accuracy: 0.9999 - val_loss: 0.0911 - val_accuracy: 0.9832 - lr: 2.5000e-06
# End fitting at 2022/10/04-16:01:35

# %%
maxAcc = np.max(fitHistory.history['val_accuracy'])
print('Maximum test accuracy is at', np.round(maxAcc*100,2), '%.')
plotAccuracyLoss(fitHistory)
#-----------------------
# Out:
# Maximum test accuracy is at 98.48 %.

# %%
printConfusionMatrix(model, val_ds)
earlyModelPath = saveSDOModel(model)
# Out:
# 887/887 [==============================] - 14s 15ms/step
# Confusion Matrix
# [[1161    2    0    0    1   19]
#  [   0 1156    4    0    7   11]
#  [   0   25 1138    2    0   19]
#  [   0    0    0 1190    0    0]
#  [   1   13    0    0 1153    0]
#  [   4    7    0    1    3 1176]]
#
#
# Classification Report
#                          precision    recall  f1-score   support
#
#        Aedes albopictus       1.00      0.98      0.99      1183
#            Aedes vexans       0.96      0.98      0.97      1178
#      Anopheles sinensis       1.00      0.96      0.98      1184
#           Culex pipiens       1.00      1.00      1.00      1190
# Culex tritaeniorhynchus       0.99      0.99      0.99      1167
#             Non vectors       0.96      0.99      0.97      1191
#
#                accuracy                           0.98      7093
#               macro avg       0.98      0.98      0.98      7093
#            weighted avg       0.98      0.98      0.98      7093
#
# Model is saved in ./models/Model_SDO_Park_2022-10-04_16-01.h5

# %%
#-----Run 4

# %%
tmpX = tempfile.TemporaryDirectory().name
RandomTrainValTest(mos_img_dir, tmpX, ratio = (0.8,0.2,0))
#-----------------------
# Out:
# Ratio = (0.8, 0.2, -0.0).
# Found Aedes vexans
# No. of files in Aedes vexans = 5901.
# No. of files in "/tmp/tmp6b34ydw3/train/Aedes vexans/" should be around 4721.
# No. of files in /tmp/tmp6b34ydw3/train/Aedes vexans/ = 4731.
# No. of files in "/tmp/tmp6b34ydw3/test/Aedes vexans/" should be around 0.
# No. of files in /tmp/tmp6b34ydw3/test/Aedes vexans/ = 0.
# No. of files in "/tmp/tmp6b34ydw3/val/Aedes vexans/" should be around 1181.
# No. of files in /tmp/tmp6b34ydw3/val/Aedes vexans/ = 1170.
# Found Anopheles sinensis
# No. of files in Anopheles sinensis = 5923.
# No. of files in "/tmp/tmp6b34ydw3/train/Anopheles sinensis/" should be around 4739.
# No. of files in /tmp/tmp6b34ydw3/train/Anopheles sinensis/ = 4739.
# No. of files in "/tmp/tmp6b34ydw3/test/Anopheles sinensis/" should be around 0.
# No. of files in /tmp/tmp6b34ydw3/test/Anopheles sinensis/ = 0.
# No. of files in "/tmp/tmp6b34ydw3/val/Anopheles sinensis/" should be around 1185.
# No. of files in /tmp/tmp6b34ydw3/val/Anopheles sinensis/ = 1184.
# Found Culex tritaeniorhynchus
# No. of files in Culex tritaeniorhynchus = 5940.
# No. of files in "/tmp/tmp6b34ydw3/train/Culex tritaeniorhynchus/" should be around 4752.
# No. of files in /tmp/tmp6b34ydw3/train/Culex tritaeniorhynchus/ = 4760.
# No. of files in "/tmp/tmp6b34ydw3/test/Culex tritaeniorhynchus/" should be around 0.
# No. of files in /tmp/tmp6b34ydw3/test/Culex tritaeniorhynchus/ = 0.
# No. of files in "/tmp/tmp6b34ydw3/val/Culex tritaeniorhynchus/" should be around 1188.
# No. of files in /tmp/tmp6b34ydw3/val/Culex tritaeniorhynchus/ = 1180.
# Found Aedes albopictus
# No. of files in Aedes albopictus = 6000.
# No. of files in "/tmp/tmp6b34ydw3/train/Aedes albopictus/" should be around 4800.
# No. of files in /tmp/tmp6b34ydw3/train/Aedes albopictus/ = 4811.
# No. of files in "/tmp/tmp6b34ydw3/test/Aedes albopictus/" should be around 0.
# No. of files in /tmp/tmp6b34ydw3/test/Aedes albopictus/ = 0.
# No. of files in "/tmp/tmp6b34ydw3/val/Aedes albopictus/" should be around 1200.
# No. of files in /tmp/tmp6b34ydw3/val/Aedes albopictus/ = 1189.
# Found Non vectors
# No. of files in Non vectors = 6006.
# No. of files in "/tmp/tmp6b34ydw3/train/Non vectors/" should be around 4805.
# No. of files in /tmp/tmp6b34ydw3/train/Non vectors/ = 4821.
# No. of files in "/tmp/tmp6b34ydw3/test/Non vectors/" should be around 0.
# No. of files in /tmp/tmp6b34ydw3/test/Non vectors/ = 0.
# No. of files in "/tmp/tmp6b34ydw3/val/Non vectors/" should be around 1202.
# No. of files in /tmp/tmp6b34ydw3/val/Non vectors/ = 1185.
# Found Culex pipiens
# No. of files in Culex pipiens = 5970.
# No. of files in "/tmp/tmp6b34ydw3/train/Culex pipiens/" should be around 4776.
# No. of files in /tmp/tmp6b34ydw3/train/Culex pipiens/ = 4793.
# No. of files in "/tmp/tmp6b34ydw3/test/Culex pipiens/" should be around 0.
# No. of files in /tmp/t
e-06
#
# Epoch 30: LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 30/40
# 3582/3582 [==============================] - 208s 58ms/step - loss: 6.7045e-04 - accuracy: 0.9998 - val_loss: 0.0501 - val_accuracy: 0.9924 - lr: 5.0000e-06
#
# Epoch 31: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 31/40
# 3582/3582 [==============================] - 201s 56ms/step - loss: 4.4038e-04 - accuracy: 0.9999 - val_loss: 0.0481 - val_accuracy: 0.9924 - lr: 2.5000e-06
#
# Epoch 32: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 32/40
# 3582/3582 [==============================] - 209s 58ms/step - loss: 8.0185e-04 - accuracy: 0.9997 - val_loss: 0.0483 - val_accuracy: 0.9920 - lr: 2.5000e-06
#
# Epoch 33: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 33/40
# 3582/3582 [==============================] - 204s 57ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.0527 - val_accuracy: 0.9918 - lr: 2.5000e-06
#
# Epoch 34: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 34/40
# 3582/3582 [==============================] - 206s 58ms/step - loss: 7.1204e-04 - accuracy: 0.9998 - val_loss: 0.0484 - val_accuracy: 0.9921 - lr: 2.5000e-06
#
# Epoch 35: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 35/40
# 3582/3582 [==============================] - 209s 58ms/step - loss: 7.6104e-04 - accuracy: 0.9998 - val_loss: 0.0485 - val_accuracy: 0.9917 - lr: 2.5000e-06
#
# Epoch 36: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 36/40
# 3582/3582 [==============================] - 202s 56ms/step - loss: 6.3881e-04 - accuracy: 0.9998 - val_loss: 0.0519 - val_accuracy: 0.9912 - lr: 2.5000e-06
#
# Epoch 37: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 37/40
# 3582/3582 [==============================] - 208s 58ms/step - loss: 6.7859e-04 - accuracy: 0.9999 - val_loss: 0.0493 - val_accuracy: 0.9920 - lr: 2.5000e-06
#
# Epoch 38: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 38/40
# 3582/3582 [==============================] - 200s 56ms/step - loss: 6.7383e-04 - accuracy: 0.9998 - val_loss: 0.0510 - val_accuracy: 0.9915 - lr: 2.5000e-06
#
# Epoch 39: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 39/40
# 3582/3582 [==============================] - 205s 57ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.0482 - val_accuracy: 0.9922 - lr: 2.5000e-06
#
# Epoch 40: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 40/40
# 3582/3582 [==============================] - 199s 56ms/step - loss: 5.4693e-04 - accuracy: 0.9998 - val_loss: 0.0496 - val_accuracy: 0.9924 - lr: 2.5000e-06
# End fitting at 2022/10/04-18:20:23

# %%
maxAcc = np.max(fitHistory.history['val_accuracy'])
print('Maximum test accuracy is at', np.round(maxAcc*100,2), '%.')
plotAccuracyLoss(fitHistory)
#-----------------------
# Out:
# Maximum test accuracy is at 99.27 %.

# %%
printConfusionMatrix(model, val_ds)
earlyModelPath = saveSDOModel(model)
# Out:
# 886/886 [==============================] - 13s 14ms/step
# Confusion Matrix
# [[1183    1    0    4    0    1]
#  [   0 1159    0    0    5    6]
#  [   0    5 1166    1    0   12]
#  [   0    0    0 1174    1    2]
#  [   0   10    0    0 1170    0]
#  [   4    2    0    0    0 1179]]
#
#
# Classification Report
#                          precision    recall  f1-score   support
#
#        Aedes albopictus       1.00      0.99      1.00      1189
#            Aedes vexans       0.98      0.99      0.99      1170
#      Anopheles sinensis       1.00      0.98      0.99      1184
#           Culex pipiens       1.00      1.00      1.00      1177
# Culex tritaeniorhynchus       0.99      0.99      0.99      1180
#             Non vectors       0.98      0.99      0.99      1185
#
#                accuracy                           0.99      7085
#               macro avg       0.99      0.99      0.99      7085
#            weighted avg       0.99      0.99      0.99      7085
#
# Model is saved in ./models/Model_SDO_Park_2022-10-04_18-20.h5

# %%
#-----Run 5

# %%
tmpX = tempfile.TemporaryDirectory().name
RandomTrainValTest(mos_img_dir, tmpX, ratio = (0.8,0.2,0))
#-----------------------
# Out:
# Ratio = (0.8, 0.2, -0.0).
# Found Aedes vexans
# No. of files in Aedes vexans = 5901.
# No. of files in "/tmp/tmpo4ebjmv_/train/Aedes vexans/" should be around 4721.
# No. of files in /tmp/tmpo4ebjmv_/train/Aedes vexans/ = 4733.
# No. of files in "/tmp/tmpo4ebjmv_/test/Aedes vexans/" should be around 0.
# No. of files in /tmp/tmpo4ebjmv_/test/Aedes vexans/ = 0.
# No. of files in "/tmp/tmpo4ebjmv_/val/Aedes vexans/" should be around 1181.
# No. of files in /tmp/tmpo4ebjmv_/val/Aedes vexans/ = 1168.
# Found Anopheles sinensis
# No. of files in Anopheles sinensis = 5923.
# No. of files in "/tmp/tmpo4ebjmv_/train/Anopheles sinensis/" should be around 4739.
# No. of files in /tmp/tmpo4ebjmv_/train/Anopheles sinensis/ = 4749.
# No. of files in "/tmp/tmpo4ebjmv_/test/Anopheles sinensis/" should be around 0.
# No. of files in /tmp/tmpo4ebjmv_/test/Anopheles sinensis/ = 0.
# No. of files in "/tmp/tmpo4ebjmv_/val/Anopheles sinensis/" should be around 1185.
# No. of files in /tmp/tmpo4ebjmv_/val/Anopheles sinensis/ = 1174.
# Found Culex tritaeniorhynchus
# No. of files in Culex tritaeniorhynchus = 5940.
# No. of files in "/tmp/tmpo4ebjmv_/train/Culex tritaeniorhynchus/" should be around 4752.
# No. of files in /tmp/tmpo4ebjmv_/train/Culex tritaeniorhynchus/ = 4772.
# No. of files in "/tmp/tmpo4ebjmv_/test/Culex tritaeniorhynchus/" should be around 0.
# No. of files in /tmp/tmpo4ebjmv_/test/Culex tritaeniorhynchus/ = 0.
# No. of files in "/tmp/tmpo4ebjmv_/val/Culex tritaeniorhynchus/" should be around 1188.
# No. of files in /tmp/tmpo4ebjmv_/val/Culex tritaeniorhynchus/ = 1168.
# Found Aedes albopictus
# No. of files in Aedes albopictus = 6000.
# No. of files in "/tmp/tmpo4ebjmv_/train/Aedes albopictus/" should be around 4800.
# No. of files in /tmp/tmpo4ebjmv_/train/Aedes albopictus/ = 4806.
# No. of files in "/tmp/tmpo4ebjmv_/test/Aedes albopictus/" should be around 0.
# No. of files in /tmp/tmpo4ebjmv_/test/Aedes albopictus/ = 0.
# No. of files in "/tmp/tmpo4ebjmv_/val/Aedes albopictus/" should be around 1200.
# No. of files in /tmp/tmpo4ebjmv_/val/Aedes albopictus/ = 1194.
# Found Non vectors
# No. of files in Non vectors = 6006.
# No. of files in "/tmp/tmpo4ebjmv_/train/Non vectors/" should be around 4805.
# No. of files in /tmp/tmpo4ebjmv_/train/Non vectors/ = 4812.
# No. of files in "/tmp/tmpo4ebjmv_/test/Non vectors/" should be around 0.
# No. of files in /tmp/tmpo4ebjmv_/test/Non vectors/ = 0.
# No. of files in "/tmp/tmpo4ebjmv_/val/Non vectors/" should be around 1202.
# No. of files in /tmp/tmpo4ebjmv_/val/Non vectors/ = 1194.
# Found Culex pipiens
# No. of files in Culex pipiens = 5970.
# No. of files in "/tmp/tmpo4ebjmv_/train/Culex pipiens/" should be around 4776.
# No. of files in /tmp/tmpo4ebjmv_/train/Culex pipiens/ = 4779.
# No. of files in "/tmp/tmpo4ebjmv_/test/Culex pipiens/" should be around 0.
# No. of files in /tmp/tmpo4ebjmv_/test/Culex pipiens/ = 0.
# No. of files in "/tmp/tmpo4ebjmv_/val/Culex pipiens/" should be around 1194.
# No. of files in /tmp/tmpo4ebjmv_/val/Culex pipiens/ = 1191.

# %%
(train_ds, val_ds) = read_ds(tmpX)
(train_ds, val_ds) = preprocessDS(train_ds, val_ds)
#-----------------------
# Out:
# Found 28651 files belonging to 6 classes.
# Found 7089 files belonging to 6 classes.

# %%
model = buildSDModel()
model = loadVGG16ImageNetWeightsSD(model)
model = compileModel(model)
fitHistory = fitModel(model, train_ds, val_ds, lr_adjust, early_stopping)
#-----------------------
# Out:
# Start fitting from 2022/10/04-18:21:00
#
# Epoch 1: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 1/40
# 3582/3582 [==============================] - 211s 57ms/step - loss: 1.8440 - accuracy: 0.1946 - val_loss: 1.5965 - val_accuracy: 0.2873 - lr: 2.0000e-05
#
# Epoch 2: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 2/40
# 3582/3582 [==============================] - 206s 57ms/step - loss: 1.1637 - accuracy: 0.5199 - val_loss: 0.8675 - val_accuracy: 0.6468 - lr: 2.0000e-05
#
# Epoch 3: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 3/40
# 3582/3582 [==============================] - 204s 57ms/step - loss: 0.5070 - accuracy: 0.8093 - val_loss: 0.3570 - val_accuracy: 0.8761 - lr: 2.0000e-05
#
# Epoch 4: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 4/40
# 3582/3582 [==============================] - 203s 57ms/step - loss: 0.2053 - accuracy: 0.9292 - val_loss: 0.1965 - val_accuracy: 0.9343 - lr: 2.0000e-05
#
# Epoch 5: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 5/40
# 3582/3582 [==============================] - 206s 57ms/step - loss: 0.1113 - accuracy: 0.9622 - val_loss: 0.1600 - val_accuracy: 0.9513 - lr: 2.0000e-05
#
# Epoch 6: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 6/40
# 3582/3582 [==============================] - 200s 56ms/step - loss: 0.0638 - accuracy: 0.9784 - val_loss: 0.1372 - val_accuracy: 0.9547 - lr: 2.0000e-05
#
# Epoch 7: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 7/40
# 3582/3582 [==============================] - 202s 56ms/step - loss: 0.0424 - accuracy: 0.9857 - val_loss: 0.0880 - val_accuracy: 0.9716 - lr: 2.0000e-05
#
# Epoch 8: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 8/40
# 3582/3582 [==============================] - 199s 56ms/step - loss: 0.0387 - accuracy: 0.9861 - val_loss: 0.1117 - val_accuracy: 0.9678 - lr: 2.0000e-05
#
# Epoch 9: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 9/40
# 3582/3582 [==============================] - 198s 55ms/step - loss: 0.0252 - accuracy: 0.9917 - val_loss: 0.0821 - val_accuracy: 0.9736 - lr: 2.0000e-05
#
# Epoch 10: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 10/40
# 3582/3582 [==============================] - 201s 56ms/step - loss: 0.0176 - accuracy: 0.9943 - val_loss: 0.1035 - val_accuracy: 0.9697 - lr: 2.0000e-05
#
# Epoch 11: LearningRateScheduler setting learning rate to 9.999999747378752e-06.
# Epoch 11/40
# 3582/3582 [==============================] - 199s 56ms/step - loss: 0.0059 - accuracy: 0.9985 - val_loss: 0.0839 - val_accuracy: 0.9760 - lr: 1.0000e-05
#
# Epoch 12: LearningRateScheduler setting learning rate to 9.999999747378752e-06.
# Epoch 12/40
# 3582/3582 [==============================] - 197s 55ms/step - loss: 0.0043 - accuracy: 0.9987 - val_loss: 0.0790 - val_accuracy: 0.9774 - lr: 1.0000e-05
#
# Epoch 13: LearningRateScheduler setting learning rate to 9.999999747378752e-06.
# Epoch 13/40
# 3582/3582 [==============================] - 206s 57ms/step - loss: 0.0030 - accuracy: 0.9992 - val_loss: 0.0785 - val_accuracy: 0.9784 - lr: 1.0000e-05
#
# Epoch 14: LearningRateScheduler setting learning rate to 9.999999747378752e-06.
# Epoch 14/40
# 3582/3582 [==============================] - 201s 56ms/step - loss: 0.0029 - accuracy: 0.9994 - val_loss: 0.0780 - val_accuracy: 0.9787 - lr: 1.0000e-05
#
# Epoch 15: LearningRateScheduler setting learning rate to 9.999999747378752e-06.
# Epoch 15/40
# 3582/3582 [==============================] - 203s 57ms/step - loss: 0.0033 - accuracy: 0.9992 - val_loss: 0.0770 - val_accuracy: 0.9786 - lr: 1.0000e-05
#
# Epoch 16: LearningRateScheduler setting learning rate to 9.999999747378752e-06.
# Epoch 16/40
# 3582/3582 [==============================] - 201s 56ms/step - loss: 0.0024 - accuracy: 0.9993 - val_loss: 0.0780 - val_accuracy: 0.9781 - lr: 1.0000e-05
#
# Epoch 17: LearningRateScheduler setting learning rate to 9.999999747378752e-06.
# Epoch 17/40
# 3582/3582 [==============================] - 202s 56ms/step - loss: 0.0030 - accuracy: 0.9993 - val_loss: 0.0716 - val_accuracy: 0.9803 - lr: 1.0000e-05
#
# Epoch 18: LearningRateScheduler setting learning rate to 9.999999747378752e-06.
# Epoch 18/40
# 3582/3582 [==============================] - 199s 56ms/step - loss: 0.0025 - accuracy: 0.9993 - val_loss: 0.0811 - val_accuracy: 0.9788 - lr: 1.0000e-05
#
# Epoch 19: LearningRateScheduler setting learning rate to 9.999999747378752e-06.
# Epoch 19/40
# 3582/3582 [==============================] - 201s 56ms/step - loss: 0.0024 - accuracy: 0.9993 - val_loss: 0.1037 - val_accuracy: 0.9752 - lr: 1.0000e-05
#
# Epoch 20: LearningRateScheduler setting learning rate to 9.999999747378752e-06.
# Epoch 20/40
# 3582/3582 [==============================] - 196s 55ms/step - loss: 0.0021 - accuracy: 0.9994 - val_loss: 0.1011 - val_accuracy: 0.9750 - lr: 1.0000e-05
#
# Epoch 21: LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 21/40
# 3582/3582 [==============================] - 202s 56ms/step - loss: 0.0014 - accuracy: 0.9995 - val_loss: 0.0788 - val_accuracy: 0.9807 - lr: 5.0000e-06
#
# Epoch 22: LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 22/40
# 3582/3582 [==============================] - 201s 56ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.0799 - val_accuracy: 0.9803 - lr: 5.0000e-06
#
# Epoch 23: LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 23/40
# 3582/3582 [==============================] - 199s 56ms/step - loss: 8.5165e-04 - accuracy: 0.9997 - val_loss: 0.0834 - val_accuracy: 0.9803 - lr: 5.0000e-06
#
# Epoch 24: LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 24/40
# 3582/3582 [==============================] - 204s 57ms/step - loss: 4.1883e-04 - accuracy: 1.0000 - val_loss: 0.0867 - val_accuracy: 0.9804 - lr: 5.0000e-06
#
# Epoch 25: LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 25/40
# 3582/3582 [==============================] - 201s 56ms/step - loss:
]
#
#
# Classification Report
#                          precision    recall  f1-score   support
#
#        Aedes albopictus       0.99      0.98      0.99      1194
#            Aedes vexans       0.94      0.98      0.96      1168
#      Anopheles sinensis       0.99      0.97      0.98      1174
#           Culex pipiens       0.98      0.99      0.99      1191
# Culex tritaeniorhynchus       0.99      0.99      0.99      1168
#             Non vectors       0.99      0.97      0.98      1194
#
#                accuracy                           0.98      7089
#               macro avg       0.98      0.98      0.98      7089
#            weighted avg       0.98      0.98      0.98      7089
#
# Model is saved in ./models/Model_SDO_Park_2022-10-04_20-34.h5

# %%
#-----Run 6

# %%
tmpX = tempfile.TemporaryDirectory().name
RandomTrainValTest(mos_img_dir, tmpX, ratio = (0.8,0.2,0))
#-----------------------
# Out:
# Ratio = (0.8, 0.2, -0.0).
# Found Aedes vexans
# No. of files in Aedes vexans = 5901.
# No. of files in "/tmp/tmpo17wur5t/train/Aedes vexans/" should be around 4721.
# No. of files in /tmp/tmpo17wur5t/train/Aedes vexans/ = 4726.
# No. of files in "/tmp/tmpo17wur5t/test/Aedes vexans/" should be around 0.
# No. of files in /tmp/tmpo17wur5t/test/Aedes vexans/ = 0.
# No. of files in "/tmp/tmpo17wur5t/val/Aedes vexans/" should be around 1181.
# No. of files in /tmp/tmpo17wur5t/val/Aedes vexans/ = 1175.
# Found Anopheles sinensis
# No. of files in Anopheles sinensis = 5923.
# No. of files in "/tmp/tmpo17wur5t/train/Anopheles sinensis/" should be around 4739.
# No. of files in /tmp/tmpo17wur5t/train/Anopheles sinensis/ = 4740.
# No. of files in "/tmp/tmpo17wur5t/test/Anopheles sinensis/" should be around 0.
# No. of files in /tmp/tmpo17wur5t/test/Anopheles sinensis/ = 0.
# No. of files in "/tmp/tmpo17wur5t/val/Anopheles sinensis/" should be around 1185.
# No. of files in /tmp/tmpo17wur5t/val/Anopheles sinensis/ = 1183.
# Found Culex tritaeniorhynchus
# No. of files in Culex tritaeniorhynchus = 5940.
# No. of files in "/tmp/tmpo17wur5t/train/Culex tritaeniorhynchus/" should be around 4752.
# No. of files in /tmp/tmpo17wur5t/train/Culex tritaeniorhynchus/ = 4784.
# No. of files in "/tmp/tmpo17wur5t/test/Culex tritaeniorhynchus/" should be around 0.
# No. of files in /tmp/tmpo17wur5t/test/Culex tritaeniorhynchus/ = 0.
# No. of files in "/tmp/tmpo17wur5t/val/Culex tritaeniorhynchus/" should be around 1188.
# No. of files in /tmp/tmpo17wur5t/val/Culex tritaeniorhynchus/ = 1156.
# Found Aedes albopictus
# No. of files in Aedes albopictus = 6000.
# No. of files in "/tmp/tmpo17wur5t/train/Aedes albopictus/" should be around 4800.
# No. of files in /tmp/tmpo17wur5t/train/Aedes albopictus/ = 4816.
# No. of files in "/tmp/tmpo17wur5t/test/Aedes albopictus/" should be around 0.
# No. of files in /tmp/tmpo17wur5t/test/Aedes albopictus/ = 0.
# No. of files in "/tmp/tmpo17wur5t/val/Aedes albopictus/" should be around 1200.
# No. of files in /tmp/tmpo17wur5t/val/Aedes albopictus/ = 1184.
# Found Non vectors
# No. of files in Non vectors = 6006.
# No. of files in "/tmp/tmpo17wur5t/train/Non vectors/" should be around 4805.
# No. of files in /tmp/tmpo17wur5t/train/Non vectors/ = 4809.
# No. of files in "/tmp/tmpo17wur5t/test/Non vectors/" should be around 0.
# No. of files in /tmp/tmpo17wur5t/test/Non vectors/ = 0.
# No. of files in "/tmp/tmpo17wur5t/val/Non vectors/" should be around 1202.
# No. of files in /tmp/tmpo17wur5t/val/Non vectors/ = 1197.
# Found Culex pipiens
# No. of files in Culex pipiens = 5970.
# No. of files in "/tmp/tmpo17wur5t/train/Culex pipiens/" should be around 4776.
# No. of files in /tmp/tmpo17wur5t/train/Culex pipiens/ = 4795.
# No. of files in "/tmp/tmpo17wur5t/test/Culex pipiens/" should be around 0.
# No. of files in /tmp/tmpo17wur5t/test/Culex pipiens/ = 0.
# No. of files in "/tmp/tmpo17wur5t/val/Culex pipiens/" should be around 1194.
# No. of files in /tmp/tmpo17wur5t/val/Culex pipiens/ = 1175.

# %%
(train_ds, val_ds) = read_ds(tmpX)
(train_ds, val_ds) = preprocessDS(train_ds, val_ds)
#-----------------------
# Out:
# Found 28670 files belonging to 6 classes.
# Found 7070 files belonging to 6 classes.

# %%
model = buildSDModel()
model = loadVGG16ImageNetWeightsSD(model)
model = compileModel(model)
fitHistory = fitModel(model, train_ds, val_ds, lr_adjust, early_stopping)
#-----------------------
# Out:
# Start fitting from 2022/10/04-20:35:18
#
# Epoch 1: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 1/40
# 3584/3584 [==============================] - 207s 56ms/step - loss: 1.3723 - accuracy: 0.4355 - val_loss: 0.7300 - val_accuracy: 0.7129 - lr: 2.0000e-05
#
# Epoch 2: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 2/40
# 3584/3584 [==============================] - 202s 56ms/step - loss: 0.3983 - accuracy: 0.8527 - val_loss: 0.2199 - val_accuracy: 0.9212 - lr: 2.0000e-05
#
# Epoch 3: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 3/40
# 3584/3584 [==============================] - 203s 57ms/step - loss: 0.1605 - accuracy: 0.9432 - val_loss: 0.1127 - val_accuracy: 0.9618 - lr: 2.0000e-05
#
# Epoch 4: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 4/40
# 3584/3584 [==============================] - 195s 54ms/step - loss: 0.0858 - accuracy: 0.9712 - val_loss: 0.1228 - val_accuracy: 0.9615 - lr: 2.0000e-05
#
# Epoch 5: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 5/40
# 3584/3584 [==============================] - 205s 57ms/step - loss: 0.0488 - accuracy: 0.9833 - val_loss: 0.0931 - val_accuracy: 0.9731 - lr: 2.0000e-05
#
# Epoch 6: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 6/40
# 3584/3584 [==============================] - 200s 56ms/step - loss: 0.0367 - accuracy: 0.9875 - val_loss: 0.1040 - val_accuracy: 0.9703 - lr: 2.0000e-05
#
# Epoch 7: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 7/40
# 3584/3584 [==============================] - 204s 57ms/step - loss: 0.0229 - accuracy: 0.9925 - val_loss: 0.1149 - val_accuracy: 0.9661 - lr: 2.0000e-05
#
# Epoch 8: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 8/40
# 3584/3584 [==============================] - 202s 56ms/step - loss: 0.0216 - accuracy: 0.9928 - val_loss: 0.1106 - val_accuracy: 0.9744 - lr: 2.0000e-05
#
# Epoch 9: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 9/40
# 3584/3584 [==============================] - 202s 56ms/step - loss: 0.0116 - accuracy: 0.9961 - val_loss: 0.0943 - val_accuracy: 0.9741 - lr: 2.0000e-05
#
# Epoch 10: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 10/40
# 3584/3584 [==============================] - 201s 56ms/step - loss: 0.0123 - accuracy: 0.9958 - val_loss: 0
]
#
#
# Classification Report
#                          precision    recall  f1-score   support
#
#        Aedes albopictus       0.99      0.99      0.99      1184
#            Aedes vexans       0.99      0.97      0.98      1175
#      Anopheles sinensis       0.99      0.98      0.99      1183
#           Culex pipiens       1.00      1.00      1.00      1175
# Culex tritaeniorhynchus       0.97      0.99      0.98      1156
#             Non vectors       0.97      0.99      0.98      1197
#
#                accuracy                           0.99      7070
#               macro avg       0.99      0.99      0.99      7070
#            weighted avg       0.99      0.99      0.99      7070
#
# Model is saved in ./models/Model_SDO_Park_2022-10-04_22-19.h5

# %%
#-----Run 7

# %%
tmpX = tempfile.TemporaryDirectory().name
RandomTrainValTest(mos_img_dir, tmpX, ratio = (0.8,0.2,0))
#-----------------------
# Out:
# Ratio = (0.8, 0.2, -0.0).
# Found Aedes vexans
# No. of files in Aedes vexans = 5901.
# No. of files in "/tmp/tmpyvan6xh3/train/Aedes vexans/" should be around 4721.
# No. of files in /tmp/tmpyvan6xh3/train/Aedes vexans/ = 4722.
# No. of files in "/tmp/tmpyvan6xh3/test/Aedes vexans/" should be around 0.
# No. of files in /tmp/tmpyvan6xh3/test/Aedes vexans/ = 0.
# No. of files in "/tmp/tmpyvan6xh3/val/Aedes vexans/" should be around 1181.
# No. of files in /tmp/tmpyvan6xh3/val/Aedes vexans/ = 1179.
# Found Anopheles sinensis
# No. of files in Anopheles sinensis = 5923.
# No. of files in "/tmp/tmpyvan6xh3/train/Anopheles sinensis/" should be around 4739.
# No. of files in /tmp/tmpyvan6xh3/train/Anopheles sinensis/ = 4761.
# No. of files in "/tmp/tmpyvan6xh3/test/Anopheles sinensis/" should be around 0.
# No. of files in /tmp/tmpyvan6xh3/test/Anopheles sinensis/ = 0.
# No. of files in "/tmp/tmpyvan6xh3/val/Anopheles sinensis/" should be around 1185.
# No. of files in /tmp/tmpyvan6xh3/val/Anopheles sinensis/ = 1162.
# Found Culex tritaeniorhynchus
# No. of files in Culex tritaeniorhynchus = 5940.
# No. of files in "/tmp/tmpyvan6xh3/train/Culex tritaeniorhynchus/" should be around 4752.
# No. of files in /tmp/tmpyvan6xh3/train/Culex tritaeniorhynchus/ = 4775.
# No. of files in "/tmp/tmpyvan6xh3/test/Culex tritaeniorhynchus/" should be around 0.
# No. of files in /tmp/tmpyvan6xh3/test/Culex tritaeniorhynchus/ = 0.
# No. of files in "/tmp/tmpyvan6xh3/val/Culex tritaeniorhynchus/" should be around 1188.
# No. of files in /tmp/tmpyvan6xh3/val/Culex tritaeniorhynchus/ = 1165.
# Found Aedes albopictus
# No. of files in Aedes albopictus = 6000.
# No. of files in "/tmp/tmpyvan6xh3/train/Aedes albopictus/" should be around 4800.
# No. of files in /tmp/tmpyvan6xh3/train/Aedes albopictus/ = 4833.
# No. of files in "/tmp/tmpyvan6xh3/test/Aedes albopictus/" should be around 0.
# No. of files in /tmp/tmpyvan6xh3/test/Aedes albopictus/ = 0.
# No. of files in "/tmp/tmpyvan6xh3/val/Aedes albopictus/" should be around 1200.
# No. of files in /tmp/tmpyvan6xh3/val/Aedes albopictus/ = 1167.
# Found Non vectors
# No. of files in Non vectors = 6006.
# No. of files in "/tmp/tmpyvan6xh3/train/Non vectors/" should be around 4805.
# No. of files in /tmp/tmpyvan6xh3/train/Non vectors/ = 4866.
# No. of files in "/tmp/tmpyvan6xh3/test/Non vectors/" should be around 0.
# No. of files in /tmp/tmpyvan6xh3/test/Non vectors/ = 0.
# No. of files in "/tmp/tmpyvan6xh3/val/Non vectors/" should be around 1202.
# No. of files in /tmp/tmpyvan6xh3/val/Non vectors/ = 1140.
# Found Culex pipiens
# No. of files in Culex pipiens = 5970.
# No. of files in "/tmp/tmpyvan6xh3/train/Culex pipiens/" should be around 4776.
# No. of files in /tmp/tmpyvan6xh3/train/Culex pipiens/ = 4786.
# No. of files in "/tmp/tmpyvan6xh3/test/Culex pipiens/" should be around 0.
# No. of files in /tmp/tmpyvan6xh3/test/Culex pipiens/ = 0.
# No. of files in "/tmp/tmpyvan6xh3/val/Culex pipiens/" should be around 1194.
# No. of files in /tmp/tmpyvan6xh3/val/Culex pipiens/ = 1184.

# %%
(train_ds, val_ds) = read_ds(tmpX)
(train_ds, val_ds) = preprocessDS(train_ds, val_ds)
#-----------------------
# Out:
# Found 28743 files belonging to 6 classes.
# Found 6997 files belonging to 6 classes.

# %%
model = buildSDModel()
model = loadVGG16ImageNetWeightsSD(model)
model = compileModel(model)
fitHistory = fitModel(model, train_ds, val_ds, lr_adjust, early_stopping)
#-----------------------
# Out:
# Start fitting from 2022/10/04-22:20:11
#
# Epoch 1: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 1/40
# 3593/3593 [==============================] - 203s 55ms/step - loss: 1.2379 - accuracy: 0.4944 - val_loss: 0.6761 - val_accuracy: 0.7466 - lr: 2.0000e-05
#
# Epoch 2: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 2/40
# 3593/3593 [==============================] - 202s 56ms/step - loss: 0.3431 - accuracy: 0.8742 - val_loss: 0.2133 - val_accuracy: 0.9197 - lr: 2.0000e-05
#
# Epoch 3: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 3/40
# 3593/3593 [==============================] - 203s 57ms/step - loss: 0.1294 - accuracy: 0.9537 - val_loss: 0.1217 - val_accuracy: 0.9578 - lr: 2.0000e-05
#
# Epoch 4: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 4/40
# 3593/3593 [==============================] - 203s 56ms/step - loss: 0.0732 - accuracy: 0.9745 - val_loss: 0.0816 - val_accuracy: 0.9746 - lr: 2.0000e-05
#
# Epoch 5: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 5/40
# 3593/3593 [==============================] - 203s 56ms/step - loss: 0.0410 - accuracy: 0.9865 - val_loss: 0.1109 - val_accuracy: 0.9658 - lr: 2.0000e-05
#
# Epoch 6: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 6/40
# 3593/3593 [==============================] - 202s 56ms/step - loss: 0.0276 - accuracy: 0.9906 - val_loss: 0.0837 - val_accuracy: 0.9697 - lr: 2.0000e-05
#
# Epoch 7: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 7/40
# 3593/3593 [==============================] - 210s 58ms/step - loss: 0.0253 - accuracy: 0.9918 - val_loss: 0.1116 - val_accuracy: 0.9671 - lr: 2.0000e-05
#
# Epoch 8: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 8/40
# 
]
#
#
# Classification Report
#                          precision    recall  f1-score   support
#
#        Aedes albopictus       0.99      0.99      0.99      1167
#            Aedes vexans       0.97      0.99      0.98      1179
#      Anopheles sinensis       0.99      0.99      0.99      1162
#           Culex pipiens       1.00      1.00      1.00      1184
# Culex tritaeniorhynchus       1.00      0.99      0.99      1165
#             Non vectors       0.99      0.98      0.98      1140
#
#                accuracy                           0.99      6997
#               macro avg       0.99      0.99      0.99      6997
#            weighted avg       0.99      0.99      0.99      6997
#
# Model is saved in ./models/Model_SDO_Park_2022-10-05_00-09.h5

# %%
#-----Run 8

# %%
tmpX = tempfile.TemporaryDirectory().name
RandomTrainValTest(mos_img_dir, tmpX, ratio = (0.8,0.2,0))
#-----------------------
# Out:
# Ratio = (0.8, 0.2, -0.0).
# Found Aedes vexans
# No. of files in Aedes vexans = 5901.
# No. of files in "/tmp/tmpus04fy7n/train/Aedes vexans/" should be around 4721.
# No. of files in /tmp/tmpus04fy7n/train/Aedes vexans/ = 4723.
# No. of files in "/tmp/tmpus04fy7n/test/Aedes vexans/" should be around 0.
# No. of files in /tmp/tmpus04fy7n/test/Aedes vexans/ = 0.
# No. of files in "/tmp/tmpus04fy7n/val/Aedes vexans/" should be around 1181.
# No. of files in /tmp/tmpus04fy7n/val/Aedes vexans/ = 1178.
# Found Anopheles sinensis
# No. of files in Anopheles sinensis = 5923.
# No. of files in "/tmp/tmpus04fy7n/train/Anopheles sinensis/" should be around 4739.
# No. of files in /tmp/tmpus04fy7n/train/Anopheles sinensis/ = 4749.
# No. of files in "/tmp/tmpus04fy7n/test/Anopheles sinensis/" should be around 0.
# No. of files in /tmp/tmpus04fy7n/test/Anopheles sinensis/ = 0.
# No. of files in "/tmp/tmpus04fy7n/val/Anopheles sinensis/" should be around 1185.
# No. of files in /tmp/tmpus04fy7n/val/Anopheles sinensis/ = 1174.
# Found Culex tritaeniorhynchus
# No. of files in Culex tritaeniorhynchus = 5940.
# No. of files in "/tmp/tmpus04fy7n/train/Culex tritaeniorhynchus/" should be around 4752.
# No. of files in /tmp/tmpus04fy7n/train/Culex tritaeniorhynchus/ = 4754.
# No. of files in "/tmp/tmpus04fy7n/test/Culex tritaeniorhynchus/" should be around 0.
# No. of files in /tmp/tmpus04fy7n/test/Culex tritaeniorhynchus/ = 0.
# No. of files in "/tmp/tmpus04fy7n/val/Culex tritaeniorhynchus/" should be around 1188.
# No. of files in /tmp/tmpus04fy7n/val/Culex tritaeniorhynchus/ = 1186.
# Found Aedes albopictus
# No. of files in Aedes albopictus = 6000.
# No. of files in "/tmp/tmpus04fy7n/train/Aedes albopictus/" should be around 4800.
# No. of files in /tmp/tmpus04fy7n/train/Aedes albopictus/ = 4817.
# No. of files in "/tmp/tmpus04fy7n/test/Aedes albopictus/" should be around 0.
# No. of files in /tmp/tmpus04fy7n/test/Aedes albopictus/ = 0.
# No. of files in "/tmp/tmpus04fy7n/val/Aedes albopictus/" should be around 1200.
# No. of files in /tmp/tmpus04fy7n/val/Aedes albopictus/ = 1183.
# Found Non vectors
# No. of files in Non vectors = 6006.
# No. of files in "/tmp/tmpus04fy7n/train/Non vectors/" should be around 4805.
# No. of files in /tmp/tmpus04fy7n/train/Non vectors/ = 4826.
# No. of files in "/tmp/tmpus04fy7n/test/Non vectors/" should be around 0.
# No. of files in /tmp/tmpus04fy7n/test/Non vectors/ = 0.
# No. of files in "/tmp/tmpus04fy7n/val/Non vectors/" should be around 1202.
# No. of files in /tmp/tmpus04fy7n/val/Non vectors/ = 1180.
# Found Culex pipiens
# No. of files in Culex pipiens = 5970.
# No. of files in "/tmp/tmpus04fy7n/train/Culex pipiens/" should be around 4776.
# No. of files in /tmp/tmpus04fy7n/train/Culex pipiens/ = 4784.
# No. of files in "/tmp/tmpus04fy7n/test/Culex pipiens/" should be around 0.
# No. of files in /tmp/tmpus04fy7n/test/Culex pipiens/ = 0.
# No. of files in "/tmp/tmpus04fy7n/val/Culex pipiens/" should be around 1194.
# No. of files in /tmp/tmpus04fy7n/val/Culex pipiens/ = 1186.

# %%
(train_ds, val_ds) = read_ds(tmpX)
(train_ds, val_ds) = preprocessDS(train_ds, val_ds)
#-----------------------
# Out:
# Found 28653 files belonging to 6 classes.
# Found 7087 files belonging to 6 classes.

# %%
model = buildSDModel()
model = loadVGG16ImageNetWeightsSD(model)
model = compileModel(model)
fitHistory = fitModel(model, train_ds, val_ds, lr_adjust, early_stopping)
#-----------------------
# Out:
# Start fitting from 2022/10/05-00:10:17
#
# Epoch 1: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 1/40
# 3582/3582 [==============================] - 211s 57ms/step - loss: 1.3330 - accuracy: 0.4344 - val_loss: 0.6819 - val_accuracy: 0.7737 - lr: 2.0000e-05
#
# Epoch 2: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 2/40
# 3582/3582 [==============================] - 206s 58ms/step - loss: 0.3725 - accuracy: 0.8643 - val_loss: 0.1723 - val_accuracy: 0.9381 - lr: 2.0000e-05
#
# Epoch 3: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 3/40
# 3582/3582 [==============================] - 206s 58ms/step - loss: 0.1328 - accuracy: 0.9523 - val_loss: 0.1031 - val_accuracy: 0.9637 - lr: 2.0000e-05
#
# Epoch 4: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 4/40
# 3582/3582 [==============================] - 206s 57ms/step - loss: 0.0692 - accuracy: 0.9763 - val_loss: 0.1064 - val_accuracy: 0.9629 - lr: 2.0000e-05
#
# Epoch 5: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 5/40
# 3582/3582 [==============================] - 209s 58ms/step - loss: 0.0410 - accuracy: 0.9860 - val_loss: 0.0822 - val_accuracy: 0.9776 - lr: 2.0000e-05
#
# Epoch 6: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 6/40
# 3582/3582 [==============================] - 203s 57ms/step - loss: 0.0265 - accuracy: 0.9912 - val_loss: 0.0662 - val_accuracy: 0.9808 - lr: 2.0000e-05
#
# Epoch 7: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 7/40
# 3582/3582 [==============================] - 205s 57ms/step - loss: 0.0271 - accuracy: 0.9902 - val_loss: 0.0616 - val_accuracy: 0.9832 - lr: 2.0000e-05
#
# Epoch 8: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 8/40
# 3582/3582 [==============================] - 204s 57ms/step - loss: 0.0125 - accuracy: 0.9960 - val_loss: 0.
-06
#
# Epoch 39: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 39/40
# 3582/3582 [==============================] - 196s 55ms/step - loss: 2.6367e-04 - accuracy: 1.0000 - val_loss: 0.0626 - val_accuracy: 0.9883 - lr: 2.5000e-06
#
# Epoch 40: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 40/40
# 3582/3582 [==============================] - 200s 56ms/step - loss: 4.7526e-04 - accuracy: 0.9999 - val_loss: 0.0658 - val_accuracy: 0.9873 - lr: 2.5000e-06
# End fitting at 2022/10/05-02:25:34

# %%
maxAcc = np.max(fitHistory.history['val_accuracy'])
print('Maximum test accuracy is at', np.round(maxAcc*100,2), '%.')
plotAccuracyLoss(fitHistory)
#-----------------------
# Out:
# Maximum test accuracy is at 98.98 %.

# %%
printConfusionMatrix(model, val_ds)
earlyModelPath = saveSDOModel(model)
# Out:
# 886/886 [==============================] - 13s 14ms/step
# Confusion Matrix
# [[1162   12    0    4    0    5]
#  [   0 1162    1    0   15    0]
#  [   0    0 1162    0    1   11]
#  [   0    0    0 1186    0    0]
#  [   2   20    0    0 1164    0]
#  [   2   11    1    0    5 1161]]
#
#
# Classification Report
#                          precision    recall  f1-score   support
#
#        Aedes albopictus       1.00      0.98      0.99      1183
#            Aedes vexans       0.96      0.99      0.98      1178
#      Anopheles sinensis       1.00      0.99      0.99      1174
#           Culex pipiens       1.00      1.00      1.00      1186
# Culex tritaeniorhynchus       0.98      0.98      0.98      1186
#             Non vectors       0.99      0.98      0.99      1180
#
#                accuracy                           0.99      7087
#               macro avg       0.99      0.99      0.99      7087
#            weighted avg       0.99      0.99      0.99      7087
#
# Model is saved in ./models/Model_SDO_Park_2022-10-05_02-25.h5

# %%
#-----Run 9

# %%
tmpX = tempfile.TemporaryDirectory().name
RandomTrainValTest(mos_img_dir, tmpX, ratio = (0.8,0.2,0))
#-----------------------
# Out:
# Ratio = (0.8, 0.2, -0.0).
# Found Aedes vexans
# No. of files in Aedes vexans = 5901.
# No. of files in "/tmp/tmpfx1c53gw/train/Aedes vexans/" should be around 4721.
# No. of files in /tmp/tmpfx1c53gw/train/Aedes vexans/ = 4721.
# No. of files in "/tmp/tmpfx1c53gw/test/Aedes vexans/" should be around 0.
# No. of files in /tmp/tmpfx1c53gw/test/Aedes vexans/ = 0.
# No. of files in "/tmp/tmpfx1c53gw/val/Aedes vexans/" should be around 1181.
# No. of files in /tmp/tmpfx1c53gw/val/Aedes vexans/ = 1180.
# Found Anopheles sinensis
# No. of files in Anopheles sinensis = 5923.
# No. of files in "/tmp/tmpfx1c53gw/train/Anopheles sinensis/" should be around 4739.
# No. of files in /tmp/tmpfx1c53gw/train/Anopheles sinensis/ = 4744.
# No. of files in "/tmp/tmpfx1c53gw/test/Anopheles sinensis/" should be around 0.
# No. of files in /tmp/tmpfx1c53gw/test/Anopheles sinensis/ = 0.
# No. of files in "/tmp/tmpfx1c53gw/val/Anopheles sinensis/" should be around 1185.
# No. of files in /tmp/tmpfx1c53gw/val/Anopheles sinensis/ = 1179.
# Found Culex tritaeniorhynchus
# No. of files in Culex tritaeniorhynchus = 5940.
# No. of files in "/tmp/tmpfx1c53gw/train/Culex tritaeniorhynchus/" should be around 4752.
# No. of files in /tmp/tmpfx1c53gw/train/Culex tritaeniorhynchus/ = 4755.
# No. of files in "/tmp/tmpfx1c53gw/test/Culex tritaeniorhynchus/" should be around 0.
# No. of files in /tmp/tmpfx1c53gw/test/Culex tritaeniorhynchus/ = 0.
# No. of files in "/tmp/tmpfx1c53gw/val/Culex tritaeniorhynchus/" should be around 1188.
# No. of files in /tmp/tmpfx1c53gw/val/Culex tritaeniorhynchus/ = 1185.
# Found Aedes albopictus
# No. of files in Aedes albopictus = 6000.
# No. of files in "/tmp/tmpfx1c53gw/train/Aedes albopictus/" should be around 4800.
# No. of files in /tmp/tmpfx1c53gw/train/Aedes albopictus/ = 4803.
# No. of files in "/tmp/tmpfx1c53gw/test/Aedes albopictus/" should be around 0.
# No. of files in /tmp/tmpfx1c53gw/test/Aedes albopictus/ = 0.
# No. of files in "/tmp/tmpfx1c53gw/val/Aedes albopictus/" should be around 1200.
# No. of files in /tmp/tmpfx1c53gw/val/Aedes albopictus/ = 1197.
# Found Non vectors
# No. of files in Non vectors = 6006.
# No. of files in "/tmp/tmpfx1c53gw/train/Non vectors/" should be around 4805.
# No. of files in /tmp/tmpfx1c53gw/train/Non vectors/ = 4843.
# No. of files in "/tmp/tmpfx1c53gw/test/Non vectors/" should be around 0.
# No. of files in /tmp/tmpfx1c53gw/test/Non vectors/ = 0.
# No. of files in "/tmp/tmpfx1c53gw/val/Non vectors/" should be around 1202.
# No. of files in /tmp/tmpfx1c53gw/val/Non vectors/ = 1163.
# Found Culex pipiens
# No. of files in Culex pipiens = 5970.
# No. of files in "/tmp/tmpfx1c53gw/train/Culex pipiens/" should be around 4776.
# No. of files in /tmp/tmpfx1c53gw/train/Culex pipiens/ = 4785.
# No. of files in "/tmp/tmpfx1c53gw/test/Culex pipiens/" should be around 0.
# No. of files in /tmp/tmpfx1c53gw/test/Culex pipiens/ = 0.
# No. of files in "/tmp/tmpfx1c53gw/val/Culex pipiens/" should be around 1194.
# No. of files in /tmp/tmpfx1c53gw/val/Culex pipiens/ = 1185.

# %%
(train_ds, val_ds) = read_ds(tmpX)
(train_ds, val_ds) = preprocessDS(train_ds, val_ds)
#-----------------------
# Out:
# Found 28651 files belonging to 6 classes.
# Found 7089 files belonging to 6 classes.

# %%
model = buildSDModel()
model = loadVGG16ImageNetWeightsSD(model)
model = compileModel(model)
fitHistory = fitModel(model, train_ds, val_ds, lr_adjust, early_stopping)
#-----------------------
# Out:
# Start fitting from 2022/10/05-02:26:11
#
# Epoch 1: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 1/40
# 3582/3582 [==============================] - 209s 56ms/step - loss: 1.1937 - accuracy: 0.5115 - val_loss: 0.5342 - val_accuracy: 0.8185 - lr: 2.0000e-05
#
# Epoch 2: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 2/40
# 3582/3582 [==============================] - 204s 57ms/step - loss: 0.3102 - accuracy: 0.8895 - val_loss: 0.2263 - val_accuracy: 0.9227 - lr: 2.0000e-05
#
# Epoch 3: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 3/40
# 3582/3582 [==============================] - 204s 57ms/step - loss:
-06
#
# Epoch 34: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 34/40
# 3582/3582 [==============================] - 201s 56ms/step - loss: 3.6235e-04 - accuracy: 0.9999 - val_loss: 0.0556 - val_accuracy: 0.9858 - lr: 2.5000e-06
#
# Epoch 35: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 35/40
# 3582/3582 [==============================] - 205s 57ms/step - loss: 2.6308e-04 - accuracy: 0.9999 - val_loss: 0.0516 - val_accuracy: 0.9862 - lr: 2.5000e-06
#
# Epoch 36: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 36/40
# 3582/3582 [==============================] - 200s 56ms/step - loss: 3.5379e-04 - accuracy: 0.9999 - val_loss: 0.0503 - val_accuracy: 0.9874 - lr: 2.5000e-06
#
# Epoch 37: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 37/40
# 3582/3582 [==============================] - 202s 56ms/step - loss: 4.4216e-04 - accuracy: 0.9998 - val_loss: 0.0567 - val_accuracy: 0.9856 - lr: 2.5000e-06
#
# Epoch 38: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 38/40
# 3582/3582 [==============================] - 198s 55ms/step - loss: 2.3242e-04 - accuracy: 1.0000 - val_loss: 0.0496 - val_accuracy: 0.9863 - lr: 2.5000e-06
#
# Epoch 39: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 39/40
# 3582/3582 [==============================] - 205s 57ms/step - loss: 3.8455e-04 - accuracy: 0.9999 - val_loss: 0.0517 - val_accuracy: 0.9862 - lr: 2.5000e-06
#
# Epoch 40: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 40/40
# 3582/3582 [==============================] - 197s 55ms/step - loss: 4.0071e-04 - accuracy: 0.9999 - val_loss: 0.0522 - val_accuracy: 0.9860 - lr: 2.5000e-06
# End fitting at 2022/10/05-04:40:24

# %%
maxAcc = np.max(fitHistory.history['val_accuracy'])
print('Maximum test accuracy is at', np.round(maxAcc*100,2), '%.')
plotAccuracyLoss(fitHistory)
#-----------------------
# Out:
# Maximum test accuracy is at 98.74 %.

# %%
printConfusionMatrix(model, val_ds)
earlyModelPath = saveSDOModel(model)
# Out:
# 887/887 [==============================] - 13s 14ms/step
# Confusion Matrix
# [[1174    5    3    3    2   10]
#  [   1 1166    2    1    6    4]
#  [   0    8 1164    0    4    3]
#  [   0    0    0 1184    0    1]
#  [   1   27    0    0 1157    0]
#  [   5    8    2    0    3 1145]]
#
#
# Classification Report
#                          precision    recall  f1-score   support
#
#        Aedes albopictus       0.99      0.98      0.99      1197
#            Aedes vexans       0.96      0.99      0.97      1180
#      Anopheles sinensis       0.99      0.99      0.99      1179
#           Culex pipiens       1.00      1.00      1.00      1185
# Culex tritaeniorhynchus       0.99      0.98      0.98      1185
#             Non vectors       0.98      0.98      0.98      1163
#
#                accuracy                           0.99      7089
#               macro avg       0.99      0.99      0.99      7089
#            weighted avg       0.99      0.99      0.99      7089
#
# Model is saved in ./models/Model_SDO_Park_2022-10-05_04-40.h5

# %%
#-----Run 10

# %%
tmpX = tempfile.TemporaryDirectory().name
RandomTrainValTest(mos_img_dir, tmpX, ratio = (0.8,0.2,0))

#-----------------------
# Out:
# Ratio = (0.8, 0.2, -0.0).
# Found Aedes vexans
# No. of files in Aedes vexans = 5901.
# No. of files in "/tmp/tmpkzk9vg80/train/Aedes vexans/" should be around 4721.
# No. of files in /tmp/tmpkzk9vg80/train/Aedes vexans/ = 4730.
# No. of files in "/tmp/tmpkzk9vg80/test/Aedes vexans/" should be around 0.
# No. of files in /tmp/tmpkzk9vg80/test/Aedes vexans/ = 0.
# No. of files in "/tmp/tmpkzk9vg80/val/Aedes vexans/" should be around 1181.
# No. of files in /tmp/tmpkzk9vg80/val/Aedes vexans/ = 1171.
# Found Anopheles sinensis
# No. of files in Anopheles sinensis = 5923.
# No. of files in "/tmp/tmpkzk9vg80/train/Anopheles sinensis/" should be around 4739.
# No. of files in /tmp/tmpkzk9vg80/train/Anopheles sinensis/ = 4743.
# No. of files in "/tmp/tmpkzk9vg80/test/Anopheles sinensis/" should be around 0.
# No. of files in /tmp/tmpkzk9vg80/test/Anopheles sinensis/ = 0.
# No. of files in "/tmp/tmpkzk9vg80/val/Anopheles sinensis/" should be around 1185.
# No. of files in /tmp/tmpkzk9vg80/val/Anopheles sinensis/ = 1180.
# Found Culex tritaeniorhynchus
# No. of files in Culex tritaeniorhynchus = 5940.
# No. of files in "/tmp/tmpkzk9vg80/train/Culex tritaeniorhynchus/" should be around 4752.
# No. of files in /tmp/tmpkzk9vg80/train/Culex tritaeniorhynchus/ = 4769.
# No. of files in "/tmp/tmpkzk9vg80/test/Culex tritaeniorhynchus/" should be around 0.
# No. of files in /tmp/tmpkzk9vg80/test/Culex tritaeniorhynchus/ = 0.
# No. of files in "/tmp/tmpkzk9vg80/val/Culex tritaeniorhynchus/" should be around 1188.
# No. of files in /tmp/tmpkzk9vg80/val/Culex tritaeniorhynchus/ = 1171.
# Found Aedes albopictus
# No. of files in Aedes albopictus = 6000.
# No. of files in "/tmp/tmpkzk9vg80/train/Aedes albopictus/" should be around 4800.
# No. of files in /tmp/tmpkzk9vg80/train/Aedes albopictus/ = 4803.
# No. of files in "/tmp/tmpkzk9vg80/test/Aedes albopictus/" should be around 0.
# No. of files in /tmp/tmpkzk9vg80/test/Aedes albopictus/ = 0.
# No. of files in "/tmp/tmpkzk9vg80/val/Aedes albopictus/" should be around 1200.
# No. of files in /tmp/tmpkzk9vg80/val/Aedes albopictus/ = 1197.
# Found Non vectors
# No. of files in Non vectors = 6006.
# No. of files in "/tmp/tmpkzk9vg80/train/Non vectors/" should be around 4805.
# No. of files in /tmp/tmpkzk9vg80/train/Non vectors/ = 4837.
# No. of files in "/tmp/tmpkzk9vg80/test/Non vectors/" should be around 0.
# No. of files in /tmp/tmpkzk9vg80/test/Non vectors/ = 0.
# No. of files in "/tmp/tmpkzk9vg80/val/Non vectors/" should be around 1202.
# No. of files in /tmp/tmpkzk9vg80/val/Non vectors/ = 1169.
# Found Culex pipiens
# No. of files in Culex pipiens = 5970.
# No. of files in "/tmp/tmpkzk9vg80/train/Culex pipiens/" should be around 4776.
# No. of files in /tmp/tmpkzk9vg80/train/Culex pipiens/ = 4778.
# No. of files in "/tmp/tmpkzk9vg80/test/Culex pipiens/" should be around 0.
# No. of files in /tmp/tmpkzk9vg80/test/Culex pipiens/ = 0.
# No. of files in "/tmp/tmpkzk9vg80/val/Culex pipiens/" should be around 1194.
# No. of files in /tmp/tmpkzk9vg80/val/Culex pipiens/ = 1192.

# %%
(train_ds, val_ds) = read_ds(tmpX)
(train_ds, val_ds) = preprocessDS(train_ds, val_ds)
#-----------------------
# Out:
# Found 28660 files belonging to 6 classes.
# Found 7080 files belonging to 6 classes.

# %%
model = buildSDModel()
model = loadVGG16ImageNetWeightsSD(model)
model = compileModel(model)
fitHistory = fitModel(model, train_ds, val_ds, lr_adjust, early_stopping)
#-----------------------
# Out:
# Start fitting from 2022/10/05-04:41:00
#
# Epoch 1: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch
0000e-05
#
# Epoch 21: LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 21/40
# 3583/3583 [==============================] - 201s 56ms/step - loss: 0.0051 - accuracy: 0.9983 - val_loss: 0.0912 - val_accuracy: 0.9754 - lr: 5.0000e-06
#
# Epoch 22: LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 22/40
# 3583/3583 [==============================] - 202s 56ms/step - loss: 0.0039 - accuracy: 0.9989 - val_loss: 0.0675 - val_accuracy: 0.9799 - lr: 5.0000e-06
#
# Epoch 23: LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 23/40
# 3583/3583 [==============================] - 207s 58ms/step - loss: 0.0032 - accuracy: 0.9992 - val_loss: 0.0655 - val_accuracy: 0.9815 - lr: 5.0000e-06
#
# Epoch 24: LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 24/40
# 3583/3583 [==============================] - 204s 57ms/step - loss: 0.0037 - accuracy: 0.9989 - val_loss: 0.0822 - val_accuracy: 0.9757 - lr: 5.0000e-06
#
# Epoch 25: LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 25/40
# 3583/3583 [==============================] - 209s 58ms/step - loss: 0.0029 - accuracy: 0.9994 - val_loss: 0.0758 - val_accuracy: 0.9788 - lr: 5.0000e-06
#
# Epoch 26: LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 26/40
# 3583/3583 [==============================] - 202s 56ms/step - loss: 0.0028 - accuracy: 0.9993 - val_loss: 0.0780 - val_accuracy: 0.9785 - lr: 5.0000e-06
#
# Epoch 27: LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 27/40
# 3583/3583 [==============================] - 208s 58ms/step - loss: 0.0028 - accuracy: 0.9991 - val_loss: 0.0745 - val_accuracy: 0.9782 - lr: 5.0000e-06
#
# Epoch 28: LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 28/40
# 3583/3583 [==============================] - 205s 57ms/step - loss: 0.0022 - accuracy: 0.9994 - val_loss: 0.0761 - val_accuracy: 0.9778 - lr: 5.0000e-06
#
# Epoch 29: LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 29/40
# 3583/3583 [==============================] - 204s 57ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0759 - val_accuracy: 0.9790 - lr: 5.0000e-06
#
# Epoch 30: LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 30/40
# 3583/3583 [==============================] - 206s 58ms/step - loss: 0.0025 - accuracy: 0.9994 - val_loss: 0.0756 - val_accuracy: 0.9787 - lr: 5.0000e-06
#
# Epoch 31: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 31/40
# 3583/3583 [==============================] - 202s 56ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0721 - val_accuracy: 0.9797 - lr: 2.5000e-06
#
# Epoch 32: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 32/40
# 3583/3583 [==============================] - 209s 58ms/step - loss: 0.0021 - accuracy: 0.9994 - val_loss: 0.0676 - val_accuracy: 0.9809 - lr: 2.5000e-06
#
# Epoch 33: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 33/40
# 3583/3583 [==============================] - 201s 56ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.0778 - val_accuracy: 0.9790 - lr: 2.5000e-06
#
# Epoch 34: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 34/40
# 3583/3583 [==============================] - 204s 57ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.0832 - val_accuracy: 0.9782 - lr: 2.5000e-06
#
# Epoch 35: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 35/40
# 3583/3583 [==============================] - 205s 57ms/step - loss: 0.0013 - accuracy: 0.9998 - val_loss: 0.0792 - val_accuracy: 0.9790 - lr: 2.5000e-06
#
# Epoch 36: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 36/40
# 3583/3583 [==============================] - 213s 59ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.0817 - val_accuracy: 0.9790 - lr: 2.5000e-06
#
# Epoch 37: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 37/40
# 3583/3583 [==============================] - 205s 57ms/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.0884 - val_accuracy: 0.9775 - lr: 2.5000e-06
#
# Epoch 38: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 38/40
# 3583/3583 [==============================] - 209s 58ms/step - loss: 0.0021 - accuracy: 0.9994 - val_loss: 0.0814 - val_accuracy: 0.9785 - lr: 2.5000e-06
# End fitting at 2022/10/05-06:50:47

# %%
maxAcc = np.max(fitHistory.history['val_accuracy'])
print('Maximum test accuracy is at', np.round(maxAcc*100,2), '%.')
plotAccuracyLoss(fitHistory)
#-----------------------
# Out:
# Maximum test accuracy is at 98.15 %.

# %%
printConfusionMatrix(model, val_ds)
earlyModelPath = saveSDOModel(model)
# Out:
# 885/885 [==============================] - 13s 14ms/step
# Confusion Matrix
# [[1171    6    2    3    9    6]
#  [   1 1136    2    3   16   13]
#  [   4   19 1153    0    2    2]
#  [   0    1    0 1191    0    0]
#  [   0   33    0    0 1138    0]
#  [   2    0    0    1    6 1160]]
#
#
# Classification Report
#                          precision    recall  f1-score   support
#
#        Aedes albopictus       0.99      0.98      0.99      1197
#            Aedes vexans       0.95      0.97      0.96      1171
#      Anopheles sinensis       1.00      0.98      0.99      1180
#           Culex pipiens       0.99      1.00      1.00      1192
# Culex tritaeniorhynchus       0.97      0.97      0.97      1171
#             Non vectors       0.98      0.99      0.99      1169
#
#                accuracy                           0.98      7080
#               macro avg       0.98      0.98      0.98      7080
#            weighted avg       0.98      0.98      0.98      7080
#
# Model is saved in ./models/Model_SDO_Park_2022-10-05_06-51.h5
