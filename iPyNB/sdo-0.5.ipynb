# %%
import numpy as np
import os, shutil, glob, tempfile, gc
import math, random
from datetime import datetime
import PIL
import PIL.Image
import tensorflow as tf

from tensorflow import keras
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt

mos_img_dir = './datasets/ParkDatasets/ParkDatasetAug'
class_names = ['Aedes albopictus', 'Aedes vexans', 'Anopheles sinensis', 'Culex pipiens', 'Culex tritaeniorhynchus', 'Non vectors']

SDO = 0.5

NUM_EPOCH_PER_TRAIN = 40

BATCH_SIZE = 8

# initial value of learning rate
LR = 2e-5
# multiplier factor
LR_MULTIPLIER = 0.5
# number of epochs per reduction
NUM_EPOCH_PER_LR_UPDATE = 10

# original image size
IMG_SIZE = 224

# ratio of (train, val, test)
RATIO = (0.80, 0.2, 0) # train, val, test -> We don't need test = val

# Function to callback every beginning of each epoch
# Learning rate adaptation
def lr_scheduler(epoch, lr):
    return lr * LR_MULTIPLIER if (epoch % NUM_EPOCH_PER_LR_UPDATE) == 0 else lr

lr_adjust = keras.callbacks.LearningRateScheduler(lr_scheduler, verbose=1)
# Early stopping
early_stopping = keras.callbacks.EarlyStopping(monitor='val_accuracy', baseline=0.2,  min_delta = 0.0001, 
                               patience=15, restore_best_weights = True)
# Out:
# 2022-09-27 23:44:41.252295: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
from keras import initializers, Input, layers
# from tensorflow.keras.utils import Sequence
# from keras.callbacks import EarlyStopping
from keras.models import Sequential, Model, load_model
from keras.layers import Dense, Flatten, Conv2D, Concatenate, Dropout, SpatialDropout2D, SpatialDropout1D, MaxPool2D, Add

# %%
def buildSDModel():
    # Create Model that is similar to VGG16 with early combination of two images
    input0 = Input(shape=(224, 224, 3), name="img0")
    first_conv = Conv2D(filters=64, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu')(input0)
    block1_conv2 = Conv2D(filters=64, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu')(first_conv)

    maxpool_1 = MaxPool2D(pool_size=(2,2),strides=(2,2))(block1_conv2)
    spa_1 = SpatialDropout2D(SDO)(maxpool_1)
    block2_conv1 = Conv2D(filters=128, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu')(spa_1)
    block2_conv2 = Conv2D(filters=128, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu')(block2_conv1)
    maxpool_2 = MaxPool2D(pool_size=(2,2),strides=(2,2))(block2_conv2)
    spa_2 = SpatialDropout2D(SDO)(maxpool_2)
    block3_conv1 = Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu')(spa_2)
    block3_conv2 = Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu')(block3_conv1)
    block3_conv3 = Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu')(block3_conv2)
    maxpool_3 = MaxPool2D(pool_size=(2,2),strides=(2,2))(block3_conv3)
    spa_3 = SpatialDropout2D(SDO)(maxpool_3)
    block4_conv1 = Conv2D(filters=512, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu')(spa_3)
    block4_conv2 = Conv2D(filters=512, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu')(block4_conv1)
    block4_conv3 = Conv2D(filters=512, kernel_size=(3,3) ,strides=(1,1), padding='same', activation='relu')(block4_conv2)
    maxpool_4 = MaxPool2D(pool_size=(2,2),strides=(2,2))(block4_conv3)
    spa_4 = SpatialDropout2D(SDO)(maxpool_4)
    block5_conv1 = Conv2D(filters=512, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu')(spa_4)
    block5_conv2 = Conv2D(filters=512, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu')(block5_conv1)
    block5_conv3 = Conv2D(filters=512, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu')(block5_conv2)
    maxpool_5 = MaxPool2D(pool_size=(2,2),strides=(2,2))(block5_conv3)
    spa_5 = SpatialDropout2D(SDO)(maxpool_5)
    flat = Flatten()(spa_5)
    dense1 = Dense(4096, activation='relu')(flat)
    drop_1 = Dropout(0)(dense1)
    dense2 = Dense(4096, activation='relu')(drop_1)
    drop_2 = Dropout(0)(dense2)
    output = Dense(6, activation='softmax')(drop_2)
    model = Model(inputs=input0, outputs=output)
    return model

# %%
def loadVGG16ImageNetWeightsSD(model):
    # load VGG16 with imagenet weights
    from keras.applications.vgg16 import VGG16
    vgg = VGG16(include_top=True, weights ='imagenet',  input_shape=(224, 224, 3))

    # print VGG16's layer names to copy its parameters
    [layer.name for layer in vgg.layers]

    # Check our modified VGG16
    [layer.name for layer in model.layers]

    # Apply weight from VGG16 to our Modified version
    for layer in vgg.layers: 
        if layer.name == 'block1_conv1':
            model.layers[1].set_weights(layer.get_weights()),
        elif layer.name == 'block1_conv2': 
            model.layers[2].set_weights(layer.get_weights()),
        elif layer.name == 'block2_conv1': 
            model.layers[5].set_weights(layer.get_weights()) 
        elif layer.name == 'block2_conv2': 
            model.layers[6].set_weights(layer.get_weights())
        elif layer.name == 'block3_conv1':
            model.layers[9].set_weights(layer.get_weights())
        elif layer.name == 'block3_conv2':
            model.layers[10].set_weights(layer.get_weights())
        elif layer.name == 'block3_conv3':
            model.layers[11].set_weights(layer.get_weights())
        elif layer.name == 'block4_conv1':
            model.layers[14].set_weights(layer.get_weights())
        elif layer.name == 'block4_conv2':
            model.layers[15].set_weights(layer.get_weights())
        elif layer.name == 'block4_conv3':
            model.layers[16].set_weights(layer.get_weights())
        elif layer.name == 'block5_conv1':
            model.layers[19].set_weights(layer.get_weights())
        elif layer.name == 'block5_conv2':
            model.layers[20].set_weights(layer.get_weights())
        elif layer.name == 'block5_conv3':
            model.layers[21].set_weights(layer.get_weights())
        elif layer.name == 'fc1':
            model.layers[25].set_weights(layer.get_weights())
        elif layer.name == 'fc2':
            model.layers[27].set_weights(layer.get_weights())
    return model

# %%
def between0i1x(f):
    if 0 <= f < 1:
        return True
    else:
        return False

# %%
def RandomTrainValTest(src_dir, dst_dir, ratio = (0.8, 0.2, 0)):
    #check if Destination directory already exists
    if os.path.exists(dst_dir):
        print('Destination directory already exists. Do nothing!!!')
        return
    TRAIN_RATIO = round(ratio[0], 3)
    VAL_RATIO = round(ratio[1], 3)
    TEST_RATIO = round(1 - TRAIN_RATIO - VAL_RATIO, 3)
    if not between0i1x(TEST_RATIO) or not between0i1x(VAL_RATIO) or not between0i1x(TRAIN_RATIO):
        print('Ratio must be more than or equal 0 and less than 1.')
        return
    print('Ratio = (' + str(TRAIN_RATIO) +', ' + str(VAL_RATIO) + ', ' + str(TEST_RATIO) + ').' )
    if TEST_RATIO != round(ratio[2],3):
        print('Sum of ratio must be 1.')
        return
    
    # create a temp dir and copy all files recursively to temp_dir
    tmp = tempfile.TemporaryDirectory()
    tmp_dir = tmp.name + '/tmp/'
    shutil.copytree(src_dir, tmp_dir)
    # scan species, they must be immediatly under the src_dir 
    for species in os.scandir(src_dir):
        if not species.name.startswith('.') and species.is_dir():
            class_dir = tmp_dir + '/' + species.name
            print('Found ' + species.name)
            #calculate No. of files in each species 
            file_no = 0
            for entry2 in os.scandir(class_dir):
                if not entry2.name.startswith('.') and entry2.is_file():
                    file_no += 1
            print('No. of files in ' + species.name + ' = ' + str(file_no) + '.')
            # create subdirectories if necessary
            if not os.path.exists(dst_dir):
                os.mkdir(dst_dir)
            test_dir = dst_dir + '/test/' 
            val_dir = dst_dir + '/val/' 
            train_dir = dst_dir + '/train/' 
            if not os.path.exists(test_dir):
                os.mkdir(test_dir)
            if not os.path.exists(val_dir):
                os.mkdir(val_dir)
            if not os.path.exists(train_dir):
                os.mkdir(train_dir)
            # create species.name dir    
            stest_dir = test_dir + species.name + '/'
            sval_dir = val_dir + species.name + '/'
            strain_dir = train_dir + species.name + '/'
            if not os.path.exists(stest_dir):
                os.mkdir(stest_dir)
            if not os.path.exists(sval_dir):
                os.mkdir(sval_dir)
            if not os.path.exists(strain_dir):
                os.mkdir(strain_dir)
            # calculate number of files for train, val, test    
            no_file_train = math.ceil(file_no*TRAIN_RATIO)
            no_file_val = math.ceil(file_no*VAL_RATIO)
            no_file_test = math.ceil(file_no*TEST_RATIO)
            
            # for training data
            file_no = 0
            while file_no < no_file_train : 
                selectedFile = random.choice(os.listdir(tmp_dir + '/' + species.name))
                # find index no
                no = selectedFile.rfind('_') 
                # select all files that have the same index no.
                SelectedFiles = '*' + selectedFile[no:] 
                # move all the selected files
                file_moved = 0
                for file in glob.iglob(class_dir +'/'+ SelectedFiles, recursive=True):    
                    file_name = os.path.basename(file)
                    shutil.move(file, strain_dir + file_name)
                    file_moved += 1
                # sum file_moved to file_no    
                file_no += file_moved
            print('No. of files in "' + strain_dir + '" should be around ' + str(no_file_train) + '.')
            print('No. of files in ' +strain_dir + ' = ' + str(file_no) +'.' )
            
            # for test data
            file_no = 0
            while file_no < no_file_test and os.listdir(tmp_dir + '/' + species.name): 
                selectedFile = random.choice(os.listdir(tmp_dir + '/' + species.name))
                # find index no
                no = selectedFile.rfind('_') 
                # select all files that have the same index no.
                SelectedFiles = '*' + selectedFile[no:] 
                # move all the selected files
                file_moved = 0
                for file in glob.iglob(class_dir +'/'+ SelectedFiles, recursive=True):    
                    file_name = os.path.basename(file)
                    shutil.move(file, strain_dir + file_name)
                    file_moved += 1
                # sum file_moved to file_no    
                file_no += file_moved
            print('No. of files in "' + stest_dir + '" should be around ' + str(no_file_test) + '.')
            print('No. of files in ' +stest_dir + ' = ' + str(file_no) +'.' )
            #move all remaining files to val_dir
            SelectedFiles = '*'
            file_moved = 0
            for file in glob.iglob(class_dir +'/'+ SelectedFiles, recursive=True):    
                file_name = os.path.basename(file)
                shutil.move(file, sval_dir + file_name)
                file_moved += 1
            file_no = file_moved    
            print('No. of files in "' + sval_dir + '" should be around ' + str(no_file_val) + '.')
            print('No. of files in ' +sval_dir + ' = ' + str(file_no) +'.' )

# %%
def read_ds(src_dir):
    
    train_dir = src_dir  + '/train'
    val_dir = src_dir    + '/val'
    
    train_ds = tf.keras.utils.image_dataset_from_directory(
      train_dir,
      #validation_split=0.2,
      #subset="training",
      seed=123,
      image_size=(IMG_SIZE, IMG_SIZE),
      shuffle = False,
      label_mode='categorical',
      batch_size=BATCH_SIZE)

    val_ds = tf.keras.utils.image_dataset_from_directory(
      val_dir,
      #validation_split=0.2,
      #subset="validation",
      seed=123,
      shuffle = False,
      label_mode='categorical',
      image_size=(IMG_SIZE, IMG_SIZE),
      batch_size=BATCH_SIZE)



    return (train_ds, val_ds)

# %%
def preprocessDS(train_ds, val_ds):
    train_num_batch = sum(1 for _ in train_ds)
    val_num_batch = sum(1 for _ in val_ds)

    # Normalize to (0-1)
    normalization_layer = tf.keras.layers.Rescaling(1./255)
    train_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
    val_ds = val_ds.map(lambda x, y: (normalization_layer(x), y))




    # Load the dataset onto GPU RAM for superspeed
    train_ds = train_ds.cache()
    val_ds = val_ds.cache()

    # reshuffle the train ds every batch (second times onwords in GPU), but shuffle val ds only once
    train_ds = train_ds.shuffle(train_num_batch, reshuffle_each_iteration=True)
    val_ds   = val_ds.shuffle(val_num_batch, reshuffle_each_iteration=False)


    # prefetch the datasets for lower latency
    train_ds = train_ds.prefetch(tf.data.AUTOTUNE)
    val_ds = val_ds.prefetch(tf.data.AUTOTUNE)

    return (train_ds, val_ds)
    #...

# %%
def compileModel(model):
    # Optimizer hyperparameter
    myAdam = keras.optimizers.Adam(
        learning_rate=LR/LR_MULTIPLIER,
        beta_1=0.9,
        beta_2=0.999,
        epsilon=0.0001,
        amsgrad=True,
        name="Adam",)

    model.compile(optimizer=myAdam,
              loss=tf.keras.losses.CategoricalCrossentropy(
                    from_logits=False,
                    label_smoothing=0.0,
                    axis=-1,
                    reduction="auto",
                    name="categorical_crossentropy"),
              metrics=['accuracy'])
    return model

# %%
def fitModel(model, train_ds, val_ds, lr_adjust = None, early_stopping = None):
    print('Start fitting from ' + datetime.now().strftime("%Y/%m/%d-%H:%M:%S"))
    history = model.fit(train_ds,    
                  epochs=NUM_EPOCH_PER_TRAIN,   
                  validation_data = val_ds,
                  callbacks=[lr_adjust, early_stopping])
    print('End fitting at '+ datetime.now().strftime("%Y/%m/%d-%H:%M:%S"))
    return history

# %%
def plotAccuracyLoss(hist):
    acc = hist.history['accuracy']
    val_acc = hist.history['val_accuracy']

    loss = hist.history['loss']
    val_loss = hist.history['val_loss']

    #epochs_range = range(epochs)
    epochs_range = range(len(loss))
    plt.figure(figsize=(8, 8))
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.show()

# %%
def printConfusionMatrix(model, ds):
    #Confution Matrix and Classification Report

    Y_pred = model.predict(ds)
    y_pred = np.argmax(Y_pred, axis=1)
    Y_true = np.concatenate([y for x, y in ds], axis=0)
    y_true = np.argmax(Y_true, axis=1)
    print('Confusion Matrix')
    print(confusion_matrix(y_true, y_pred))
    print('')
    print('')
    print('Classification Report')

    print(classification_report(y_true, y_pred, target_names=class_names))

# %%
def saveSDOModel(model):
    path = './models/Model_SDO_Park_' + datetime.now().strftime("%Y-%m-%d_%H-%M") +'.h5'
    print('Model is saved in ' + path)
    model.save(path)
    return path

# %%
tmpX = tempfile.TemporaryDirectory().name
RandomTrainValTest(mos_img_dir, tmpX, ratio = (0.8,0.2,0))
# Out:
# Ratio = (0.8, 0.2, -0.0).
# Found Aedes vexans
# No. of files in Aedes vexans = 5901.
# No. of files in "/tmp/tmp11rf9s2z/train/Aedes vexans/" should be around 4721.
# No. of files in /tmp/tmp11rf9s2z/train/Aedes vexans/ = 4726.
# No. of files in "/tmp/tmp11rf9s2z/test/Aedes vexans/" should be around 0.
# No. of files in /tmp/tmp11rf9s2z/test/Aedes vexans/ = 0.
# No. of files in "/tmp/tmp11rf9s2z/val/Aedes vexans/" should be around 1181.
# No. of files in /tmp/tmp11rf9s2z/val/Aedes vexans/ = 1175.
# Found Anopheles sinensis
# No. of files in Anopheles sinensis = 5923.
# No. of files in "/tmp/tmp11rf9s2z/train/Anopheles sinensis/" should be around 4739.
# No. of files in /tmp/tmp11rf9s2z/train/Anopheles sinensis/ = 4740.
# No. of files in "/tmp/tmp11rf9s2z/test/Anopheles sinensis/" should be around 0.
# No. of files in /tmp/tmp11rf9s2z/test/Anopheles sinensis/ = 0.
# No. of files in "/tmp/tmp11rf9s2z/val/Anopheles sinensis/" should be around 1185.
# No. of files in /tmp/tmp11rf9s2z/val/Anopheles sinensis/ = 1183.
# Found Culex tritaeniorhynchus
# No. of files in Culex tritaeniorhynchus = 5940.
# No. of files in "/tmp/tmp11rf9s2z/train/Culex tritaeniorhynchus/" should be around 4752.
# No. of files in /tmp/tmp11rf9s2z/train/Culex tritaeniorhynchus/ = 4769.
# No. of files in "/tmp/tmp11rf9s2z/test/Culex tritaeniorhynchus/" should be around 0.
# No. of files in /tmp/tmp11rf9s2z/test/Culex tritaeniorhynchus/ = 0.
# No. of files in "/tmp/tmp11rf9s2z/val/Culex tritaeniorhynchus/" should be around 1188.
# No. of files in /tmp/tmp11rf9s2z/val/Culex tritaeniorhynchus/ = 1171.
# Found Aedes albopictus
# No. of files in Aedes albopictus = 6000.
# No. of files in "/tmp/tmp11rf9s2z/train/Aedes albopictus/" should be around 4800.
# No. of files in /tmp/tmp11rf9s2z/train/Aedes albopictus/ = 4805.
# No. of files in "/tmp/tmp11rf9s2z/test/Aedes albopictus/" should be around 0.
# No. of files in /tmp/tmp11rf9s2z/test/Aedes albopictus/ = 0.
# No. of files in "/tmp/tmp11rf9s2z/val/Aedes albopictus/" should be around 1200.
# No. of files in /tmp/tmp11rf9s2z/val/Aedes albopictus/ = 1195.
# Found Non vectors
# No. of files in Non vectors = 6006.
# No. of files in "/tmp/tmp11rf9s2z/train/Non vectors/" should be around 4805.
# No. of files in /tmp/tmp11rf9s2z/train/Non vectors/ = 4816.
# No. of files in "/tmp/tmp11rf9s2z/test/Non vectors/" should be around 0.
# No. of files in /tmp/tmp11rf9s2z/test/Non vectors/ = 0.
# No. of files in "/tmp/tmp11rf9s2z/val/Non vectors/" should be around 1202.
# No. of files in /tmp/tmp11rf9s2z/val/Non vectors/ = 1190.
# Found Culex pipiens
# No. of files in Culex pipiens = 5970.
# No. of files in "/tmp/tmp11rf9s2z/train/Culex pipiens/" should be around 4776.
# No. of files in /tmp/tmp11rf9s2z/train/Culex pipiens/ = 4781.
# No. of files in "/tmp/tmp11rf9s2z/test/Culex pipiens/" should be around 0.
# No. of files in /tmp/tmp11rf9s2z/test/Culex pipiens/ = 0.
# No. of files in "/tmp/tmp11rf9s2z/val/Culex pipiens/" should be around 1194.
# No. of files in /tmp/tmp11rf9s2z/val/Culex pipiens/ = 1189.

# %%
(train_ds, val_ds) = read_ds(tmpX)
(train_ds, val_ds) = preprocessDS(train_ds, val_ds)
# Out:
# Found 28637 files belonging to 6 classes.
# 2022-09-26 00:27:49.827825: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-26 00:27:50.621768: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22221 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:af:00.0, compute capability: 8.6
# Found 7103 files belonging to 6 classes.

# %%
model = buildSDModel()
model.summary()
model = loadVGG16ImageNetWeightsSD(model)
model = compileModel(model)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  img0 (InputLayer)           [(None, 224, 224, 3)]     0
#
#  conv2d (Conv2D)             (None, 224, 224, 64)      1792
#
#  conv2d_1 (Conv2D)           (None, 224, 224, 64)      36928
#
#  max_pooling2d (MaxPooling2D  (None, 112, 112, 64)     0
#  )
#
#  spatial_dropout2d (SpatialD  (None, 112, 112, 64)     0
#  ropout2D)
#
#  conv2d_2 (Conv2D)           (None, 112, 112, 128)     73856
#
#  conv2d_3 (Conv2D)           (None, 112, 112, 128)     147584
#
#  max_pooling2d_1 (MaxPooling  (None, 56, 56, 128)      0
#  2D)
#
#  spatial_dropout2d_1 (Spatia  (None, 56, 56, 128)      0
#  lDropout2D)
#
#  conv2d_4 (Conv2D)           (None, 56, 56, 256)       295168
#
#  conv2d_5 (Conv2D)           (None, 56, 56, 256)       590080
#
#  conv2d_6 (Conv2D)           (None, 56, 56, 256)       590080
#
#  max_pooling2d_2 (MaxPooling  (None, 28, 28, 256)      0
#  2D)
#
#  spatial_dropout2d_2 (Spatia  (None, 28, 28, 256)      0
#  lDropout2D)
#
#  conv2d_7 (Conv2D)           (None, 28, 28, 512)       1180160
#
#  conv2d_8 (Conv2D)           (None, 28, 28, 512)       2359808
#
#  conv2d_9 (Conv2D)           (None, 28, 28, 512)       2359808
#
#  max_pooling2d_3 (MaxPooling  (None, 14, 14, 512)      0
#  2D)
#
#  spatial_dropout2d_3 (Spatia  (None, 14, 14, 512)      0
#  lDropout2D)
#
#  conv2d_10 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  conv2d_11 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  conv2d_12 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  max_pooling2d_4 (MaxPooling  (None, 7, 7, 512)        0
#  2D)
#
#  spatial_dropout2d_4 (Spatia  (None, 7, 7, 512)        0
#  lDropout2D)
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 4096)              102764544
#
#  dropout (Dropout)           (None, 4096)              0
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  dropout_1 (Dropout)         (None, 4096)              0
#
#  dense_2 (Dense)             (None, 6)                 24582
#
# =================================================================
# Total params: 134,285,126
# Trainable params: 134,285,126
# Non-trainable params: 0
# _________________________________________________________________

# %%
fitHistory = fitModel(model, train_ds, val_ds, lr_adjust, early_stopping)
maxAcc = np.max(fitHistory.history['val_accuracy'])
# Out:
# Start fitting from 2022/09/26-00:27:58
#
# Epoch 1: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 1/40
# 2022-09-26 00:28:04.558289: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8401
# 2022-09-26 00:28:06.754418: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 3580/3580 [==============================] - 241s 65ms/step - loss: 1.8095 - accuracy: 0.1960 - val_loss: 1.9223 - val_accuracy: 0.1516 - lr: 2.0000e-05
#
# Epoch 2: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 2/40
# 3580/3580 [==============================] - 222s 62ms/step - loss: 1.4283 - accuracy: 0.3997 - val_loss: 0.9985 - val_accuracy: 0.6104 - lr: 2.0000e-05
#
# Epoch 3: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 3/40
# 3580/3580 [==============================] - 213s 60ms/step - loss: 1.0117 - accuracy: 0.6060 - val_loss: 0.8210 - val_accuracy: 0.6683 - lr: 2.0000e-05
#
# Epoch 4: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 4/40
# 3580/3580 [==============================] - 211s 59ms/step - loss: 0.7347 - accuracy: 0.7228 - val_loss: 0.5105 - val_accuracy: 0.8085 - lr: 2.0000e-05
#
# Epoch 5: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 5/40
# 3580/3580 [==============================] - 206s 58ms/step - loss: 0.5399 - accuracy: 0.7994 - val_loss: 0.4822 - val_accuracy: 0.8215 - lr: 2.0000e-05
#
# Epoch 6: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 6/40
# 3580/3580 [==============================] - 206s 57ms/step - loss: 0.4041 - accuracy: 0.8522 - val_loss: 0.2689 - val_accuracy: 0.9037 - lr: 2.0000e-05
#
# Epoch 7: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch
LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 24/40
# 3580/3580 [==============================] - 210s 59ms/step - loss: 0.0200 - accuracy: 0.9930 - val_loss: 0.2070 - val_accuracy: 0.9464 - lr: 5.0000e-06
#
# Epoch 25: LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 25/40
# 3580/3580 [==============================] - 211s 59ms/step - loss: 0.0188 - accuracy: 0.9938 - val_loss: 0.2006 - val_accuracy: 0.9514 - lr: 5.0000e-06
#
# Epoch 26: LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 26/40
# 3580/3580 [==============================] - 205s 57ms/step - loss: 0.0184 - accuracy: 0.9943 - val_loss: 0.2038 - val_accuracy: 0.9509 - lr: 5.0000e-06
#
# Epoch 27: LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 27/40
# 3580/3580 [==============================] - 208s 58ms/step - loss: 0.0175 - accuracy: 0.9942 - val_loss: 0.2255 - val_accuracy: 0.9469 - lr: 5.0000e-06
#
# Epoch 28: LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 28/40
# 3580/3580 [==============================] - 201s 56ms/step - loss: 0.0169 - accuracy: 0.9941 - val_loss: 0.1957 - val_accuracy: 0.9527 - lr: 5.0000e-06
#
# Epoch 29: LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 29/40
# 3580/3580 [==============================] - 205s 57ms/step - loss: 0.0178 - accuracy: 0.9937 - val_loss: 0.1921 - val_accuracy: 0.9537 - lr: 5.0000e-06
#
# Epoch 30: LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 30/40
# 3580/3580 [==============================] - 202s 56ms/step - loss: 0.0154 - accuracy: 0.9952 - val_loss: 0.2072 - val_accuracy: 0.9497 - lr: 5.0000e-06
#
# Epoch 31: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 31/40
# 3580/3580 [==============================] - 205s 57ms/step - loss: 0.0145 - accuracy: 0.9953 - val_loss: 0.2086 - val_accuracy: 0.9504 - lr: 2.5000e-06
#
# Epoch 32: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 32/40
# 3580/3580 [==============================] - 202s 56ms/step - loss: 0.0121 - accuracy: 0.9958 - val_loss: 0.2191 - val_accuracy: 0.9490 - lr: 2.5000e-06
#
# Epoch 33: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 33/40
# 3580/3580 [==============================] - 211s 59ms/step - loss: 0.0130 - accuracy: 0.9958 - val_loss: 0.2036 - val_accuracy: 0.9524 - lr: 2.5000e-06
# End fitting at 2022/09/26-02:22:21

# %%
print('Maximum test accuracy is at', np.round(maxAcc*100,2), '%.')
plotAccuracyLoss(fitHistory)
# Out:
# Maximum test accuracy is at 95.37 %.

# %%
printConfusionMatrix(model, val_ds)
earlyModelPath = saveSDOModel(model)
# Out:
# 888/888 [==============================] - 14s 15ms/step
# Confusion Matrix
# [[1180    8    1    1    0    5]
#  [   1 1103    5    1   47   18]
#  [   1   43 1081    0    1   57]
#  [   2    2    0 1183    0    2]
#  [   5   45    2    3 1116    0]
#  [   6   24   20   26    3 1111]]
#
#
# Classification Report
#                          precision    recall  f1-score   support
#
#        Aedes albopictus       0.99      0.99      0.99      1195
#            Aedes vexans       0.90      0.94      0.92      1175
#      Anopheles sinensis       0.97      0.91      0.94      1183
#           Culex pipiens       0.97      0.99      0.98      1189
# Culex tritaeniorhynchus       0.96      0.95      0.95      1171
#             Non vectors       0.93      0.93      0.93      1190
#
#                accuracy                           0.95      7103
#               macro avg       0.95      0.95      0.95      7103
#            weighted avg       0.95      0.95      0.95      7103
#
# Model is saved in ./models/Model_SDO_Park_2022-09-26_02-22.h5

# %%
#-----Run 2

# %%
tmpX = tempfile.TemporaryDirectory().name
RandomTrainValTest(mos_img_dir, tmpX, ratio = (0.8,0.2,0))
#-----------------------
# Out:
# Ratio = (0.8, 0.2, -0.0).
# Found Aedes vexans
# No. of files in Aedes vexans = 5901.
# No. of files in "/tmp/tmpsflycyex/train/Aedes vexans/" should be around 4721.
# No. of files in /tmp/tmpsflycyex/train/Aedes vexans/ = 4739.
# No. of files in "/tmp/tmpsflycyex/test/Aedes vexans/" should be around 0.
# No. of files in /tmp/tmpsflycyex/test/Aedes vexans/ = 0.
# No. of files in "/tmp/tmpsflycyex/val/Aedes vexans/" should be around 1181.
# No. of files in /tmp/tmpsflycyex/val/Aedes vexans/ = 1162.
# Found Anopheles sinensis
# No. of files in Anopheles sinensis = 5923.
# No. of files in "/tmp/tmpsflycyex/train/Anopheles sinensis/" should be around 4739.
# No. of files in /tmp/tmpsflycyex/train/Anopheles sinensis/ = 4748.
# No. of files in "/tmp/tmpsflycyex/test/Anopheles sinensis/" should be around 0.
# No. of files in /tmp/tmpsflycyex/test/Anopheles sinensis/ = 0.
# No. of files in "/tmp/tmpsflycyex/val/Anopheles sinensis/" should be around 1185.
# No. of files in /tmp/tmpsflycyex/val/Anopheles sinensis/ = 1175.
# Found Culex tritaeniorhynchus
# No. of files in Culex tritaeniorhynchus = 5940.
# No. of files in "/tmp/tmpsflycyex/train/Culex tritaeniorhynchus/" should be around 4752.
# No. of files in /tmp/tmpsflycyex/train/Culex tritaeniorhynchus/ = 4768.
# No. of files in "/tmp/tmpsflycyex/test/Culex tritaeniorhynchus/" should be around 0.
# No. of files in /tmp/tmpsflycyex/test/Culex tritaeniorhynchus/ = 0.
# No. of files in "/tmp/tmpsflycyex/val/Culex tritaeniorhynchus/" should be around 1188.
# No. of files in /tmp/tmpsflycyex/val/Culex tritaeniorhynchus/ = 1172.
# Found Aedes albopictus
# No. of files in Aedes albopictus = 6000.
# No. of files in "/tmp/tmpsflycyex/train/Aedes albopictus/" should be around 4800.
# No. of files in /tmp/tmpsflycyex/train/Aedes albopictus/ = 4841.
# No. of files in "/tmp/tmpsflycyex/test/Aedes albopictus/" should be around 0.
# No. of files in /tmp/tmpsflycyex/test/Aedes albopictus/ = 0.
# No. of files in "/tmp/tmpsflycyex/val/Aedes albopictus/" should be around 1200.
# No. of files in /tmp/tmpsflycyex/val/Aedes albopictus/ = 1159.
# Found Non vectors
# No. of files in Non vectors = 6006.
# No. of files in "/tmp/tmpsflycyex/train/Non vectors/" should be around 4805.
# No. of files in /tmp/tmpsflycyex/train/Non vectors/ = 4839.
# No. of files in "/tmp/tmpsflycyex/test/Non vectors/" should be around 0.
# No. of files in /tmp/tmpsflycyex/test/Non vectors/ = 0.
# No. of files in "/tmp/tmpsflycyex/val/Non vectors/" should be around 1202.
# No. of files in /tmp/tmpsflycyex/val/Non vectors/ = 1167.
# Found Culex pipiens
# No. of files in Culex pipiens = 5970.
# No. of files in "/tmp/tmpsflycyex/train/Culex pipiens/" should be around 4776.
# No. of files in /tmp/tmpsflycyex/train/Culex pipiens/ = 4777.
# No. of files in "/tmp/tmpsflycyex/test/Culex pipiens/" should be around 0.
# No. of files in /tmp/tmpsflycyex/test/Culex pipiens/ = 0.
# No. of files in "/tmp/tmpsflycyex/val/Culex pipiens/" should be around 1194.
# No. of files in /tmp/tmpsflycyex/val/Culex pipiens/ = 1193.

# %%
(train_ds, val_ds) = read_ds(tmpX)
(train_ds, val_ds) = preprocessDS(train_ds, val_ds)
#-----------------------
# Out:
# Found 28712 files belonging to 6 classes.
# Found 7028 files belonging to 6 classes.

# %%
model = buildSDModel()
model = loadVGG16ImageNetWeightsSD(model)
model = compileModel(model)
fitHistory = fitModel(model, train_ds, val_ds, lr_adjust, early_stopping)
#-----------------------
# Out:
# Start fitting from 2022/09/26-02:22:57
#
# Epoch 1: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 1/40
# 3589/3589 [==============================] - 220s 60ms/step - loss: 1.8142 - accuracy: 0.1899 - val_loss: 1.5959 - val_accuracy: 0.3399 - lr: 2.0000e-05
#
# Epoch 2: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 2/40
# 3589/3589 [==============================] - 213s 59ms/step - loss: 1.4644 - accuracy: 0.3703 - val_loss: 1.1795 - val_accuracy: 0.5179 - lr: 2.0000e-05
#
# Epoch 3: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 3/40
# 3589/3589 [==============================] - 208s 58ms/step - loss: 1.1543 - accuracy: 0.5413 - val_loss: 0.8113 - val_accuracy: 0.6864 - lr: 2.0000e-05
#
# Epoch 4: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 4/40
# 3589/3589 [==============================] - 204s 57ms/step - loss: 0.8364 - accuracy: 0.6822 - val_loss: 0.6026 - val_accuracy: 0.7856 - lr: 2.0000e-05
#
# Epoch 5: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 5/40
# 3589/3589 [==============================] - 199s 55ms/step - loss: 0.6216 - accuracy: 0.7662 - val_loss: 0.4407 - val_accuracy: 0.8409 - lr: 2.0000e-05
#
# Epoch 6: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 6/40
# 3589/3589 [==============================] - 214s 60ms/step - loss: 0.4728 - accuracy: 0.8283 - val_loss: 0.4049 - val_accuracy: 0.8489 - lr: 2.0000e-05
#
# Epoch 7: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 7/40
# 3589/3589 [==============================] - 210s 58ms/step - loss: 0.3589 - accuracy: 0.8711 - val_loss: 0.4281 - val_accuracy: 0.8554 - lr: 2.0000e-05
#
# Epoch 8: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 8/40
# 3589/3589 [==============================] - 204s 57ms/step - loss: 0.2795 - accuracy: 0.9021 - val_loss: 0.2750 - val_accuracy: 0.9061 - lr: 2.0000e-05
#
# Epoch 9: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 9/40
# 3589/3589 [==============================] - 205s 57ms/step - loss: 0.2225 - accuracy: 0.9198 - val_loss: 0.2773 - val_accuracy: 0.9096 - lr: 2.0000e-05
#
# Epoch 10: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 10/40
# 3589/3589 [==============================] - 195s 54ms/step - loss: 0.1809 - accuracy: 0.9364 - val_loss: 0.2895 - val_accuracy: 0.9003 - lr: 2.0000e-05
#
# Epoch 11: LearningRateScheduler setting learning rate to 9.999999747378752e-06.
# Epoch 11/40
# 3589/3589 [==============================] - 201s 56ms/step - loss: 0.1143 - accuracy: 0.9600 - val_loss: 0.2061 - val_accuracy: 0.9328 - lr: 1.0000e-05
#
# Epoch 12: LearningRateScheduler setting learning rate to 9.999999747378752e-06.
# Epoch
#  [   4   48    1    0 1119    0]
#  [   5   45   24   59    5 1029]]
#
#
# Classification Report
#                          precision    recall  f1-score   support
#
#        Aedes albopictus       0.99      0.97      0.98      1159
#            Aedes vexans       0.90      0.94      0.92      1162
#      Anopheles sinensis       0.96      0.99      0.98      1175
#           Culex pipiens       0.94      0.99      0.96      1193
# Culex tritaeniorhynchus       0.96      0.95      0.96      1172
#             Non vectors       0.98      0.88      0.93      1167
#
#                accuracy                           0.95      7028
#               macro avg       0.96      0.95      0.95      7028
#            weighted avg       0.96      0.95      0.95      7028
#
# Model is saved in ./models/Model_SDO_Park_2022-09-26_04-38.h5

# %%
#-----Run 3

# %%
tmpX = tempfile.TemporaryDirectory().name
RandomTrainValTest(mos_img_dir, tmpX, ratio = (0.8,0.2,0))
#-----------------------
# Out:
# Ratio = (0.8, 0.2, -0.0).
# Found Aedes vexans
# No. of files in Aedes vexans = 5901.
# No. of files in "/tmp/tmpxvnd4cj5/train/Aedes vexans/" should be around 4721.
# No. of files in /tmp/tmpxvnd4cj5/train/Aedes vexans/ = 4734.
# No. of files in "/tmp/tmpxvnd4cj5/test/Aedes vexans/" should be around 0.
# No. of files in /tmp/tmpxvnd4cj5/test/Aedes vexans/ = 0.
# No. of files in "/tmp/tmpxvnd4cj5/val/Aedes vexans/" should be around 1181.
# No. of files in /tmp/tmpxvnd4cj5/val/Aedes vexans/ = 1167.
# Found Anopheles sinensis
# No. of files in Anopheles sinensis = 5923.
# No. of files in "/tmp/tmpxvnd4cj5/train/Anopheles sinensis/" should be around 4739.
# No. of files in /tmp/tmpxvnd4cj5/train/Anopheles sinensis/ = 4762.
# No. of files in "/tmp/tmpxvnd4cj5/test/Anopheles sinensis/" should be around 0.
# No. of files in /tmp/tmpxvnd4cj5/test/Anopheles sinensis/ = 0.
# No. of files in "/tmp/tmpxvnd4cj5/val/Anopheles sinensis/" should be around 1185.
# No. of files in /tmp/tmpxvnd4cj5/val/Anopheles sinensis/ = 1161.
# Found Culex tritaeniorhynchus
# No. of files in Culex tritaeniorhynchus = 5940.
# No. of files in "/tmp/tmpxvnd4cj5/train/Culex tritaeniorhynchus/" should be around 4752.
# No. of files in /tmp/tmpxvnd4cj5/train/Culex tritaeniorhynchus/ = 4759.
# No. of files in "/tmp/tmpxvnd4cj5/test/Culex tritaeniorhynchus/" should be around 0.
# No. of files in /tmp/tmpxvnd4cj5/test/Culex tritaeniorhynchus/ = 0.
# No. of files in "/tmp/tmpxvnd4cj5/val/Culex tritaeniorhynchus/" should be around 1188.
# No. of files in /tmp/tmpxvnd4cj5/val/Culex tritaeniorhynchus/ = 1181.
# Found Aedes albopictus
# No. of files in Aedes albopictus = 6000.
# No. of files in "/tmp/tmpxvnd4cj5/train/Aedes albopictus/" should be around 4800.
# No. of files in /tmp/tmpxvnd4cj5/train/Aedes albopictus/ = 4817.
# No. of files in "/tmp/tmpxvnd4cj5/test/Aedes albopictus/" should be around 0.
# No. of files in /tmp/tmpxvnd4cj5/test/Aedes albopictus/ = 0.
# No. of files in "/tmp/tmpxvnd4cj5/val/Aedes albopictus/" should be around 1200.
# No. of files in /tmp/tmpxvnd4cj5/val/Aedes albopictus/ = 1183.
# Found Non vectors
# No. of files in Non vectors = 6006.
# No. of files in "/tmp/tmpxvnd4cj5/train/Non vectors/" should be around 4805.
# No. of files in /tmp/tmpxvnd4cj5/train/Non vectors/ = 4810.
# No. of files in "/tmp/tmpxvnd4cj5/test/Non vectors/" should be around 0.
# No. of files in /tmp/tmpxvnd4cj5/test/Non vectors/ = 0.
# No. of files in "/tmp/tmpxvnd4cj5/val/Non vectors/" should be around 1202.
# No. of files in /tmp/tmpxvnd4cj5/val/Non vectors/ = 1196.
# Found Culex pipiens
# No. of files in Culex pipiens = 5970.
# No. of files in "/tmp/tmpxvnd4cj5/train/Culex pipiens/" should be around 4776.
# No. of files in /tmp/tmpxvnd4cj5/train/Culex pipiens/ = 4777.
# No. of files in "/tmp/tmpxvnd4cj5/test/Culex pipiens/" should be around 0.
# No. of files in /tmp/tmpxvnd4cj5/test/Culex pipiens/ = 0.
# No. of files in "/tmp/tmpxvnd4cj5/val/Culex pipiens/" should be around 1194.
# No. of files in /tmp/tmpxvnd4cj5/val/Culex pipiens/ = 1193.

# %%
(train_ds, val_ds) = read_ds(tmpX)
(train_ds, val_ds) = preprocessDS(train_ds, val_ds)
#-----------------------
# Out:
# Found 28659 files belonging to 6 classes.
# Found 7081 files belonging to 6 classes.

# %%
model = buildSDModel()
model = loadVGG16ImageNetWeightsSD(model)
model = compileModel(model)
fitHistory = fitModel(model, train_ds, val_ds, lr_adjust, early_stopping)
#-----------------------
# Out:
# Start fitting from 2022/09/26-04:39:20
#
# Epoch 1: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 1/40
# 3583/3583 [==============================] - 212s 57ms/step - loss: 1.8209 - accuracy: 0.1819 - val_loss: 1.7072 - val_accuracy: 0.2635 - lr: 2.0000e-05
#
# Epoch 2: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 2/40
# 3583/3583 [==============================] - 209s 58ms/step - loss: 1.5122 - accuracy: 0.3430 - val_loss: 1.3346 - val_accuracy: 0.4345 - lr: 2.0000e-05
#
# Epoch 3: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 3/40
# 3583/3583 [==============================] - 208s 58ms/step - loss: 1.2811 - accuracy: 0.4695 - val_loss: 1.0095 - val_accuracy: 0.5938 - lr: 2.0000e-05
#
# Epoch 4: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 4/40
# 3583/3583 [==============================] - 206s 58ms/step - loss: 0.9630 - accuracy: 0.6296 - val_loss: 0.6748 - val_accuracy: 0.7531 - lr: 2.0000e-05
#
# Epoch 5: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 5/40
# 3583/3583 [==============================] - 206s 57ms/step - loss: 0.7160 - accuracy: 0.7293 - val_loss: 0.5973 - val_accuracy: 0.7753 - lr: 2.0000e-05
#
# Epoch 6: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 6/40
# 3583/3583 [==============================] - 204s 57ms/step - loss: 0.5418 - accuracy: 0.8017 - val_loss: 0.4085 - val_accuracy: 0.8492 - lr: 2.0000e-05
#
# Epoch 7: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 7/40
# 3583/3583 [==============================] - 199s 56ms/step - loss: 0.4154 - accuracy: 0.8487 - val_loss: 0.4105 - val_accuracy: 0.8599 - lr: 2.0000e-05
#
# Epoch 8: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch
LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 25/40
# 3583/3583 [==============================] - 202s 56ms/step - loss: 0.0238 - accuracy: 0.9920 - val_loss: 0.2781 - val_accuracy: 0.9339 - lr: 5.0000e-06
#
# Epoch 26: LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 26/40
# 3583/3583 [==============================] - 204s 57ms/step - loss: 0.0248 - accuracy: 0.9910 - val_loss: 0.2447 - val_accuracy: 0.9389 - lr: 5.0000e-06
#
# Epoch 27: LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 27/40
# 3583/3583 [==============================] - 207s 58ms/step - loss: 0.0226 - accuracy: 0.9924 - val_loss: 0.2460 - val_accuracy: 0.9408 - lr: 5.0000e-06
#
# Epoch 28: LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 28/40
# 3583/3583 [==============================] - 202s 56ms/step - loss: 0.0221 - accuracy: 0.9925 - val_loss: 0.2405 - val_accuracy: 0.9389 - lr: 5.0000e-06
#
# Epoch 29: LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 29/40
# 3583/3583 [==============================] - 202s 56ms/step - loss: 0.0209 - accuracy: 0.9930 - val_loss: 0.2820 - val_accuracy: 0.9335 - lr: 5.0000e-06
#
# Epoch 30: LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 30/40
# 3583/3583 [==============================] - 204s 57ms/step - loss: 0.0192 - accuracy: 0.9940 - val_loss: 0.2930 - val_accuracy: 0.9326 - lr: 5.0000e-06
#
# Epoch 31: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 31/40
# 3583/3583 [==============================] - 202s 56ms/step - loss: 0.0158 - accuracy: 0.9947 - val_loss: 0.2753 - val_accuracy: 0.9349 - lr: 2.5000e-06
#
# Epoch 32: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 32/40
# 3583/3583 [==============================] - 198s 55ms/step - loss: 0.0160 - accuracy: 0.9951 - val_loss: 0.2541 - val_accuracy: 0.9410 - lr: 2.5000e-06
#
# Epoch 33: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 33/40
# 3583/3583 [==============================] - 204s 57ms/step - loss: 0.0146 - accuracy: 0.9955 - val_loss: 0.2813 - val_accuracy: 0.9370 - lr: 2.5000e-06
# End fitting at 2022/09/26-06:32:14

# %%
maxAcc = np.max(fitHistory.history['val_accuracy'])
print('Maximum test accuracy is at', np.round(maxAcc*100,2), '%.')
plotAccuracyLoss(fitHistory)
#-----------------------
# Out:
# Maximum test accuracy is at 94.38 %.

# %%
printConfusionMatrix(model, val_ds)
earlyModelPath = saveSDOModel(model)
# Out:
# 886/886 [==============================] - 14s 15ms/step
# Confusion Matrix
# [[1112   44    0    0   19    8]
#  [   2 1032   14   11   73   35]
#  [   4   16 1118    5    1   17]
#  [   0    1    7 1157    0   28]
#  [   2   37    0    2 1136    4]
#  [   0   24   13   26    5 1128]]
#
#
# Classification Report
#                          precision    recall  f1-score   support
#
#        Aedes albopictus       0.99      0.94      0.97      1183
#            Aedes vexans       0.89      0.88      0.89      1167
#      Anopheles sinensis       0.97      0.96      0.97      1161
#           Culex pipiens       0.96      0.97      0.97      1193
# Culex tritaeniorhynchus       0.92      0.96      0.94      1181
#             Non vectors       0.92      0.94      0.93      1196
#
#                accuracy                           0.94      7081
#               macro avg       0.94      0.94      0.94      7081
#            weighted avg       0.94      0.94      0.94      7081
#
# Model is saved in ./models/Model_SDO_Park_2022-09-26_06-32.h5

# %%
#-----Run 4

# %%
tmpX = tempfile.TemporaryDirectory().name
RandomTrainValTest(mos_img_dir, tmpX, ratio = (0.8,0.2,0))
#-----------------------
# Out:
# Ratio = (0.8, 0.2, -0.0).
# Found Aedes vexans
# No. of files in Aedes vexans = 5901.
# No. of files in "/tmp/tmpcvca28b6/train/Aedes vexans/" should be around 4721.
# No. of files in /tmp/tmpcvca28b6/train/Aedes vexans/ = 4726.
# No. of files in "/tmp/tmpcvca28b6/test/Aedes vexans/" should be around 0.
# No. of files in /tmp/tmpcvca28b6/test/Aedes vexans/ = 0.
# No. of files in "/tmp/tmpcvca28b6/val/Aedes vexans/" should be around 1181.
# No. of files in /tmp/tmpcvca28b6/val/Aedes vexans/ = 1175.
# Found Anopheles sinensis
# No. of files in Anopheles sinensis = 5923.
# No. of files in "/tmp/tmpcvca28b6/train/Anopheles sinensis/" should be around 4739.
# No. of files in /tmp/tmpcvca28b6/train/Anopheles sinensis/ = 4758.
# No. of files in "/tmp/tmpcvca28b6/test/Anopheles sinensis/" should be around 0.
# No. of files in /tmp/tmpcvca28b6/test/Anopheles sinensis/ = 0.
# No. of files in "/tmp/tmpcvca28b6/val/Anopheles sinensis/" should be around 1185.
# No. of files in /tmp/tmpcvca28b6/val/Anopheles sinensis/ = 1165.
# Found Culex tritaeniorhynchus
# No. of files in Culex tritaeniorhynchus = 5940.
# No. of files in "/tmp/tmpcvca28b6/train/Culex tritaeniorhynchus/" should be around 4752.
# No. of files in /tmp/tmpcvca28b6/train/Culex tritaeniorhynchus/ = 4755.
# No. of files in "/tmp/tmpcvca28b6/test/Culex tritaeniorhynchus/" should be around 0.
# No. of files in /tmp/tmpcvca28b6/test/Culex tritaeniorhynchus/ = 0.
# No. of files in "/tmp/tmpcvca28b6/val/Culex tritaeniorhynchus/" should be around 1188.
# No. of files in /tmp/tmpcvca28b6/val/Culex tritaeniorhynchus/ = 1185.
# Found Aedes albopictus
# No. of files in Aedes albopictus = 6000.
# No. of files in "/tmp/tmpcvca28b6/train/Aedes albopictus/" should be around 4800.
# No. of files in /tmp/tmpcvca28b6/train/Aedes albopictus/ = 4824.
# No. of files in "/tmp/tmpcvca28b6/test/Aedes albopictus/" should be around 0.
# No. of files in /tmp/tmpcvca28b6/test/Aedes albopictus/ = 0.
# No. of files in "/tmp/tmpcvca28b6/val/Aedes albopictus/" should be around 1200.
# No. of files in /tmp/tmpcvca28b6/val/Aedes albopictus/ = 1176.
# Found Non vectors
# No. of files in Non vectors = 6006.
# No. of files in "/tmp/tmpcvca28b6/train/Non vectors/" should be around 4805.
# No. of files in /tmp/tmpcvca28b6/train/Non vectors/ = 4815.
# No. of files in "/tmp/tmpcvca28b6/test/Non vectors/" should be around 0.
# No. of files in /tmp/tmpcvca28b6/test/Non vectors/ = 0.
# No. of files in "/tmp/tmpcvca28b6/val/Non vectors/" should be around 1202.
# No. of files in /tmp/tmpcvca28b6/val/Non vectors/ = 1191.
# Found Culex pipiens
# No. of files in Culex pipiens = 5970.
# No. of files in "/tmp/tmpcvca28b6/train/Culex pipiens/" should be around 4776.
# No. of files in /tmp/tmpcvca28b6/train/Culex pipiens/ = 4778.
# No. of files in "/tmp/tmpcvca28b6/test/Culex pipiens/" should be around 0.
# No. of files in /tmp/tmpcvca28b6/test/Culex pipiens/ = 0.
# No. of files in "/tmp/tmpcvca28b6/val/Culex pipiens/" should be around 1194.
# No. of files in /tmp/tmpcvca28b6/val/Culex pipiens/ = 1192.

# %%
(train_ds, val_ds) = read_ds(tmpX)
(train_ds, val_ds) = preprocessDS(train_ds, val_ds)
#-----------------------
# Out:
# Found 28656 files belonging to 6 classes.
# Found 7084 files belonging to 6 classes.

# %%
model = buildSDModel()
model = loadVGG16ImageNetWeightsSD(model)
model = compileModel(model)
fitHistory = fitModel(model, train_ds, val_ds, lr_adjust, early_stopping)
#-----------------------
# Out:
# Start fitting from 2022/09/26-06:32:52
#
# Epoch 1: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 1/40
# 3582/3582 [==============================] - 214s 58ms/step - loss: 1.8209 - accuracy: 0.1798 - val_loss: 1.7228 - val_accuracy: 0.2108 - lr: 2.0000e-05
#
# Epoch 2: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 2/40
# 3582/3582 [==============================] - 208s 58ms/step - loss: 1.4961 - accuracy: 0.3593 - val_loss: 1.3441 - val_accuracy: 0.5069 - lr: 2.0000e-05
#
# Epoch 3: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 3/40
# 3582/3582 [==============================] - 206s 58ms/step - loss: 1.1245 - accuracy: 0.5595 - val_loss: 0.7844 - val_accuracy: 0.7002 - lr: 2.0000e-05
#
# Epoch 4: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 4/40
# 3582/3582 [==============================] - 206s 58ms/step - loss: 0.7872 - accuracy: 0.7047 - val_loss: 0.7573 - val_accuracy: 0.7261 - lr: 2.0000e-05
#
# Epoch 5: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 5/40
# 3582/3582 [==============================] - 203s 57ms/step - loss: 0.5817 - accuracy: 0.7861 - val_loss: 0.4065 - val_accuracy: 0.8577 - lr: 2.0000e-05
#
# Epoch 6: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 6/40
# 3582/3582 [==============================] - 207s 58ms/step - loss: 0.4315 - accuracy: 0.8438 - val_loss: 0.3372 - val_accuracy: 0.8802 - lr: 2.0000e-05
#
# Epoch 7: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 7/40
# 3582/3582 [==============================] - 206s 58ms/step - loss: 0.3202 - accuracy: 0.8861 - val_loss: 0.2601 - val_accuracy: 0.9102 - lr: 2.0000e-05
#
# Epoch 8: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 8/40
# 3582/3582 [==============================] - 209s 58ms/step - loss: 0.2451 - accuracy: 0.9139 - val_loss: 0.2353 - val_accuracy: 0.9224 - lr: 2.0000e-05
#
# Epoch 9: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 9/40
# 3582/3582 [==============================] - 197s 55ms/step - loss: 0.1945 - accuracy: 0.9315 - val_loss: 0.2366 - val_accuracy: 0.9222 - lr: 2.0000e-05
#
# Epoch 10: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 10/40
# 3582/3582 [==============================] - 205s 57ms/step - loss: 0.1522 - accuracy: 0.9458 - val_loss: 0.2113 - val_accuracy: 0.9345 - lr: 2.0000e-05
#
# Epoch 11: LearningRateScheduler setting learning rate to 9.999999747378752e-06.
# Epoch 11/40
# 3582/3582 [==============================] - 206s 58ms/step - loss: 0.1038 - accuracy: 0.9637 - val_loss: 0.2208 - val_accuracy: 0.9328 - lr: 1.0000e-05
#
# Epoch 12: LearningRateScheduler setting learning rate to 9.999999747378752e-06.
# Epoch
LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 28/40
# 3582/3582 [==============================] - 199s 56ms/step - loss: 0.0179 - accuracy: 0.9938 - val_loss: 0.1580 - val_accuracy: 0.9598 - lr: 5.0000e-06
#
# Epoch 29: LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 29/40
# 3582/3582 [==============================] - 202s 56ms/step - loss: 0.0178 - accuracy: 0.9941 - val_loss: 0.1713 - val_accuracy: 0.9554 - lr: 5.0000e-06
#
# Epoch 30: LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 30/40
# 3582/3582 [==============================] - 204s 57ms/step - loss: 0.0157 - accuracy: 0.9950 - val_loss: 0.1827 - val_accuracy: 0.9558 - lr: 5.0000e-06
#
# Epoch 31: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 31/40
# 3582/3582 [==============================] - 205s 57ms/step - loss: 0.0146 - accuracy: 0.9949 - val_loss: 0.1765 - val_accuracy: 0.9579 - lr: 2.5000e-06
#
# Epoch 32: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 32/40
# 3582/3582 [==============================] - 200s 56ms/step - loss: 0.0154 - accuracy: 0.9950 - val_loss: 0.1660 - val_accuracy: 0.9561 - lr: 2.5000e-06
#
# Epoch 33: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 33/40
# 3582/3582 [==============================] - 204s 57ms/step - loss: 0.0122 - accuracy: 0.9961 - val_loss: 0.1564 - val_accuracy: 0.9615 - lr: 2.5000e-06
#
# Epoch 34: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 34/40
# 3582/3582 [==============================] - 198s 55ms/step - loss: 0.0134 - accuracy: 0.9954 - val_loss: 0.1689 - val_accuracy: 0.9593 - lr: 2.5000e-06
#
# Epoch 35: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 35/40
# 3582/3582 [==============================] - 201s 56ms/step - loss: 0.0135 - accuracy: 0.9956 - val_loss: 0.1654 - val_accuracy: 0.9605 - lr: 2.5000e-06
#
# Epoch 36: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 36/40
# 3582/3582 [==============================] - 205s 57ms/step - loss: 0.0112 - accuracy: 0.9964 - val_loss: 0.1699 - val_accuracy: 0.9599 - lr: 2.5000e-06
#
# Epoch 37: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 37/40
# 3582/3582 [==============================] - 201s 56ms/step - loss: 0.0123 - accuracy: 0.9960 - val_loss: 0.1834 - val_accuracy: 0.9582 - lr: 2.5000e-06
#
# Epoch 38: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 38/40
# 3582/3582 [==============================] - 202s 56ms/step - loss: 0.0116 - accuracy: 0.9966 - val_loss: 0.1710 - val_accuracy: 0.9606 - lr: 2.5000e-06
#
# Epoch 39: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 39/40
# 3582/3582 [==============================] - 202s 56ms/step - loss: 0.0119 - accuracy: 0.9963 - val_loss: 0.1686 - val_accuracy: 0.9593 - lr: 2.5000e-06
#
# Epoch 40: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 40/40
# 3582/3582 [==============================] - 201s 56ms/step - loss: 0.0106 - accuracy: 0.9968 - val_loss: 0.1760 - val_accuracy: 0.9593 - lr: 2.5000e-06
# End fitting at 2022/09/26-08:48:57

# %%
maxAcc = np.max(fitHistory.history['val_accuracy'])
print('Maximum test accuracy is at', np.round(maxAcc*100,2), '%.')
plotAccuracyLoss(fitHistory)
#-----------------------
# Out:
# Maximum test accuracy is at 96.15 %.

# %%
printConfusionMatrix(model, val_ds)
earlyModelPath = saveSDOModel(model)
# Out:
# 886/886 [==============================] - 13s 15ms/step
# Confusion Matrix
# [[1131   27    2    3   10    3]
#  [   0 1102    8    0   42   23]
#  [   0   26 1129    5    0    5]
#  [   0    0    0 1189    0    3]
#  [   3   44    2    0 1134    2]
#  [   9   27    5   37    2 1111]]
#
#
# Classification Report
#                          precision    recall  f1-score   support
#
#        Aedes albopictus       0.99      0.96      0.98      1176
#            Aedes vexans       0.90      0.94      0.92      1175
#      Anopheles sinensis       0.99      0.97      0.98      1165
#           Culex pipiens       0.96      1.00      0.98      1192
# Culex tritaeniorhynchus       0.95      0.96      0.96      1185
#             Non vectors       0.97      0.93      0.95      1191
#
#                accuracy                           0.96      7084
#               macro avg       0.96      0.96      0.96      7084
#            weighted avg       0.96      0.96      0.96      7084
#
# Model is saved in ./models/Model_SDO_Park_2022-09-26_08-49.h5

# %%
#-----Run 5

# %%
tmpX = tempfile.TemporaryDirectory().name
RandomTrainValTest(mos_img_dir, tmpX, ratio = (0.8,0.2,0))
#-----------------------
# Out:
# Ratio = (0.8, 0.2, -0.0).
# Found Aedes vexans
# No. of files in Aedes vexans = 5901.
# No. of files in "/tmp/tmpsjd1luza/train/Aedes vexans/" should be around 4721.
# No. of files in /tmp/tmpsjd1luza/train/Aedes vexans/ = 4731.
# No. of files in "/tmp/tmpsjd1luza/test/Aedes vexans/" should be around 0.
# No. of files in /tmp/tmpsjd1luza/test/Aedes vexans/ = 0.
# No. of files in "/tmp/tmpsjd1luza/val/Aedes vexans/" should be around 1181.
# No. of files in /tmp/tmpsjd1luza/val/Aedes vexans/ = 1170.
# Found Anopheles sinensis
# No. of files in Anopheles sinensis = 5923.
# No. of files in "/tmp/tmpsjd1luza/train/Anopheles sinensis/" should be around 4739.
# No. of files in /tmp/tmpsjd1luza/train/Anopheles sinensis/ = 4747.
# No. of files in "/tmp/tmpsjd1luza/test/Anopheles sinensis/" should be around 0.
# No. of files in /tmp/tmpsjd1luza/test/Anopheles sinensis/ = 0.
# No. of files in "/tmp/tmpsjd1luza/val/Anopheles sinensis/" should be around 1185.
# No. of files in /tmp/tmpsjd1luza/val/Anopheles sinensis/ = 1176.
# Found Culex tritaeniorhynchus
# No. of files in Culex tritaeniorhynchus = 5940.
# No. of files in "/tmp/tmpsjd1luza/train/Culex tritaeniorhynchus/" should be around 4752.
# No. of files in /tmp/tmpsjd1luza/train/Culex tritaeniorhynchus/ = 4753.
# No. of files in "/tmp/tmpsjd1luza/test/Culex tritaeniorhynchus/" should be around 0.
# No. of files in /tmp/tmpsjd1luza/test/Culex tritaeniorhynchus/ = 0.
# No. of files in "/tmp/tmpsjd1luza/val/Culex tritaeniorhynchus/" should be around 1188.
# No. of files in /tmp/tmpsjd1luza/val/Culex tritaeniorhynchus/ = 1187.
# Found Aedes albopictus
# No. of files in Aedes albopictus = 6000.
# No. of files in "/tmp/tmpsjd1luza/train/Aedes albopictus/" should be around 4800.
# No. of files in /tmp/tmpsjd1luza/train/Aedes albopictus/ = 4837.
# No. of files in "/tmp/tmpsjd1luza/test/Aedes albopictus/" should be around 0.
# No. of files in /tmp/tmpsjd1luza/test/Aedes albopictus/ = 0.
# No. of files in "/tmp/tmpsjd1luza/val/Aedes albopictus/" should be around 1200.
# No. of files in /tmp/tmpsjd1luza/val/Aedes albopictus/ = 1163.
# Found Non vectors
# No. of files in Non vectors = 6006.
# No. of files in "/tmp/tmpsjd1luza/train/Non vectors/" should be around 4805.
# No. of files in /tmp/tmpsjd1luza/train/Non vectors/ = 4813.
# No. of files in "/tmp/tmpsjd1luza/test/Non vectors/" should be around 0.
# No. of files in /tmp/tmpsjd1luza/test/Non vectors/ = 0.
# No. of files in "/tmp/tmpsjd1luza/val/Non vectors/" should be around 1202.
# No. of files in /tmp/tmpsjd1luza/val/Non vectors/ = 1193.
# Found Culex pipiens
# No. of files in Culex pipiens = 5970.
# No. of files in "/tmp/tmpsjd1luza/train/Culex pipiens/" should be around 4776.
# No. of files in /tmp/tmpsjd1luza/train/Culex pipiens/ = 4786.
# No. of files in "/tmp/tmpsjd1luza/test/Culex pipiens/" should be around 0.
# No. of files in /tmp/tmpsjd1luza/test/Culex pipiens/ = 0.
# No. of files in "/tmp/tmpsjd1luza/val/Culex pipiens/" should be around 1194.
# No. of files in /tmp/tmpsjd1luza/val/Culex pipiens/ = 1184.

# %%
(train_ds, val_ds) = read_ds(tmpX)
(train_ds, val_ds) = preprocessDS(train_ds, val_ds)
#-----------------------
# Out:
# Found 28667 files belonging to 6 classes.
# Found 7073 files belonging to 6 classes.

# %%
model = buildSDModel()
model = loadVGG16ImageNetWeightsSD(model)
model = compileModel(model)
fitHistory = fitModel(model, train_ds, val_ds, lr_adjust, early_stopping)
#-----------------------
# Out:
# Start fitting from 2022/09/26-08:49:34
#
# Epoch 1: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 1/40
# 3584/3584 [==============================] - 212s 57ms/step - loss: 1.8159 - accuracy: 0.1840 - val_loss: 1.5651 - val_accuracy: 0.2965 - lr: 2.0000e-05
#
# Epoch 2: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 2/40
# 3584/3584 [==============================] - 211s 59ms/step - loss: 1.4381 - accuracy: 0.3879 - val_loss: 1.2530 - val_accuracy: 0.5351 - lr: 2.0000e-05
#
# Epoch 3: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 3/40
# 3584/3584 [==============================] - 208s 58ms/step - loss: 1.0526 - accuracy: 0.5886 - val_loss: 0.7398 - val_accuracy: 0.7281 - lr: 2.0000e-05
#
# Epoch 4: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 4/40
# 3584/3584 [==============================] - 202s 56ms/step - loss: 0.7303 - accuracy: 0.7273 - val_loss: 0.6089 - val_accuracy: 0.7683 - lr: 2.0000e-05
#
# Epoch 5: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 5/40
# 3584/3584 [==============================] - 206s 57ms/step - loss: 0.5174 - accuracy: 0.8103 - val_loss: 0.4456 - val_accuracy: 0.8452 - lr: 2.0000e-05
#
# Epoch 6: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 6/40
# 3584/3584 [==============================] - 206s 57ms/step - loss: 0.3824 - accuracy: 0.8616 - val_loss: 0.3943 - val_accuracy: 0.8619 - lr: 2.0000e-05
#
# Epoch 7: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 7/40
# 3584/3584 [==============================] - 207s 58ms/step - loss: 0.2862 - accuracy: 0.8964 - val_loss: 0.3103 - val_accuracy: 0.8923 - lr: 2.0000e-05
#
# Epoch 8: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 8/40
# 3584/3584 [==============================] - 209s 58ms/step - loss: 0.2222 - accuracy: 0.9211 - val_loss: 0.2013 - val_accuracy: 0.9321 - lr: 2.0000e-05
#
# Epoch 9: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 9/40
# 3584/3584 [==============================] - 202s 56ms/step - loss: 0.1735 - accuracy: 0.9396 - val_loss: 0.2028 - val_accuracy: 0.9282 - lr: 2.0000e-05
#
# Epoch 10: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 10/40
# 3584/3584 [==============================] - 203s 57ms/step - loss: 0.1391 - accuracy: 0.9518 - val_loss: 0.1813 - val_accuracy: 0.9412 - lr: 2.0000e-05
#
# Epoch 11: LearningRateScheduler setting learning rate to 9.999999747378752e-06.
# Epoch
LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 28/40
# 3584/3584 [==============================] - 209s 58ms/step - loss: 0.0170 - accuracy: 0.9943 - val_loss: 0.1696 - val_accuracy: 0.9562 - lr: 5.0000e-06
#
# Epoch 29: LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 29/40
# 3584/3584 [==============================] - 209s 58ms/step - loss: 0.0146 - accuracy: 0.9956 - val_loss: 0.1789 - val_accuracy: 0.9555 - lr: 5.0000e-06
#
# Epoch 30: LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 30/40
# 3584/3584 [==============================] - 210s 59ms/step - loss: 0.0136 - accuracy: 0.9954 - val_loss: 0.1736 - val_accuracy: 0.9562 - lr: 5.0000e-06
#
# Epoch 31: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 31/40
# 3584/3584 [==============================] - 207s 58ms/step - loss: 0.0133 - accuracy: 0.9957 - val_loss: 0.1823 - val_accuracy: 0.9555 - lr: 2.5000e-06
#
# Epoch 32: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 32/40
# 3584/3584 [==============================] - 213s 59ms/step - loss: 0.0113 - accuracy: 0.9961 - val_loss: 0.1886 - val_accuracy: 0.9546 - lr: 2.5000e-06
#
# Epoch 33: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 33/40
# 3584/3584 [==============================] - 210s 59ms/step - loss: 0.0122 - accuracy: 0.9961 - val_loss: 0.1871 - val_accuracy: 0.9556 - lr: 2.5000e-06
#
# Epoch 34: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 34/40
# 3584/3584 [==============================] - 202s 56ms/step - loss: 0.0109 - accuracy: 0.9964 - val_loss: 0.1798 - val_accuracy: 0.9576 - lr: 2.5000e-06
#
# Epoch 35: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 35/40
# 3584/3584 [==============================] - 207s 58ms/step - loss: 0.0111 - accuracy: 0.9963 - val_loss: 0.1857 - val_accuracy: 0.9565 - lr: 2.5000e-06
#
# Epoch 36: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 36/40
# 3584/3584 [==============================] - 215s 60ms/step - loss: 0.0112 - accuracy: 0.9961 - val_loss: 0.1775 - val_accuracy: 0.9574 - lr: 2.5000e-06
#
# Epoch 37: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 37/40
# 3584/3584 [==============================] - 214s 60ms/step - loss: 0.0110 - accuracy: 0.9961 - val_loss: 0.1766 - val_accuracy: 0.9579 - lr: 2.5000e-06
#
# Epoch 38: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 38/40
# 3584/3584 [==============================] - 214s 60ms/step - loss: 0.0118 - accuracy: 0.9962 - val_loss: 0.1902 - val_accuracy: 0.9546 - lr: 2.5000e-06
#
# Epoch 39: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 39/40
# 3584/3584 [==============================] - 217s 61ms/step - loss: 0.0100 - accuracy: 0.9968 - val_loss: 0.1865 - val_accuracy: 0.9562 - lr: 2.5000e-06
#
# Epoch 40: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 40/40
# 3584/3584 [==============================] - 211s 59ms/step - loss: 0.0102 - accuracy: 0.9968 - val_loss: 0.1907 - val_accuracy: 0.9557 - lr: 2.5000e-06
# End fitting at 2022/09/26-11:08:32

# %%
maxAcc = np.max(fitHistory.history['val_accuracy'])
print('Maximum test accuracy is at', np.round(maxAcc*100,2), '%.')
plotAccuracyLoss(fitHistory)
#-----------------------
# Out:
# Maximum test accuracy is at 95.79 %.

# %%
printConfusionMatrix(model, val_ds)
earlyModelPath = saveSDOModel(model)
# Out:
# 885/885 [==============================] - 14s 16ms/step
# Confusion Matrix
# [[1129   14    5    2    5    8]
#  [   1 1096    4    1   51   17]
#  [   1   25 1139    0    5    6]
#  [   1    0    2 1179    0    2]
#  [   7   63    0    1 1116    0]
#  [   4   34   36   17    1 1101]]
#
#
# Classification Report
#                          precision    recall  f1-score   support
#
#        Aedes albopictus       0.99      0.97      0.98      1163
#            Aedes vexans       0.89      0.94      0.91      1170
#      Anopheles sinensis       0.96      0.97      0.96      1176
#           Culex pipiens       0.98      1.00      0.99      1184
# Culex tritaeniorhynchus       0.95      0.94      0.94      1187
#             Non vectors       0.97      0.92      0.95      1193
#
#                accuracy                           0.96      7073
#               macro avg       0.96      0.96      0.96      7073
#            weighted avg       0.96      0.96      0.96      7073
#
# Model is saved in ./models/Model_SDO_Park_2022-09-26_11-08.h5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [43], in <cell line: 2>()
#       1 printConfusionMatrix(model, val_ds)
# ----> 2 earlyModelPath = saveSDOModel(model)
#
# Input In [13], in saveSDOModel(model)
#       2 path = './models/Model_SDO_Park_' + datetime.now().strftime("%Y-%m-%d_%H-%M") +'.h5'
#       3 print('Model is saved in ' + path)
# ----> 4 model.save(path)
#       5 return path
#
# File ~/miniforge3/envs/mosquito/lib/python3.10/site-packages/keras/utils/traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniforge3/envs/mosquito/lib/python3.10/site-packages/keras/engine/training.py:2435, in Model.save(self, filepath, overwrite, include_optimizer, save_format, signatures, options, save_traces)
#    2393 """Saves the model to Tensorflow SavedModel or a single HDF5 file.
#    2394
#    2395 Please see `tf.keras.models.save_model` or the
#    (...)
#    2432 ```
#    2433 """
#    2434 # pylint: enable=line-too-long
# -> 2435 save.save_model(self, filepath, overwrite, include_optimizer, save_format,
#    2436                 signatures, options, save_traces)
#
# File ~/miniforge3/envs/mosquito/lib/python3.10/site-packages/keras/utils/traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniforge3/envs/mosquito/lib/python3.10/site-packages/keras/saving/save.py:149, in save_model(model, filepath, overwrite, include_optimizer, save_format, signatures, options, save_traces)
#     140   if (not model._is_graph_network and  # pylint:disable=protected-access
#     141       not isinstance(model, sequential.Sequential)):
#     142     raise NotImplementedError(
#     143         'Saving the model to HDF5 format requires the model to be a '
#     144         'Functional model or a Sequential model. It does not work for '
#    (...)
#     147         'to the Tensorflow SavedModel format (by setting save_format="tf") '
#     148         'or using `save_weights`.')
# --> 149   hdf5_format.save_model_to_hdf5(
#     150       model, filepath, overwrite, include_optimizer)
#     151 else:
#     152   with generic_utils.SharedObjectSavingScope():
#
# File ~/miniforge3/envs/mosquito/lib/python3.10/site-packages/keras/saving/hdf5_format.py:131, in save_model_to_hdf5(model, filepath, overwrite, include_optimizer)
#     126     logging.warning('HDF5 format does not save weights of'
#     127                     ' `optimizer_experimental.Optimizer`, your optimizer will'
#     128                     ' be recompiled at loading time.')
#     129   elif (include_optimizer and model.optimizer and
#     130         not isinstance(model.optimizer, optimizer_v1.TFOptimizer)):
# --> 131     save_optimizer_weights_to_hdf5_group(f, model.optimizer)
#     133   f.flush()
#     134 finally:
#
# File ~/miniforge3/envs/mosquito/lib/python3.10/site-packages/keras/saving/hdf5_format.py:603, in save_optimizer_weights_to_hdf5_group(hdf5_group, optimizer)
#     601 weight_names = [str(w.name).encode('utf8') for w in symbolic_weights]
#     602 save_attributes_to_hdf5_group(weights_group, 'weight_names', weight_names)
# --> 603 weight_values = backend.batch_get_value(symbolic_weights)
#     604 for name, val in zip(weight_names, weight_values):
#     605   param_dset = weights_group.create_dataset(
#     606       name, val.shape, dtype=val.dtype)
#
# File ~/miniforge3/envs/mosquito/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniforge3/envs/mosquito/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py:1082, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1080 # Fallback dispatch system (dispatch v1):
#    1081 try:
# -> 1082   return dispatch_target(*args, **kwargs)
#    1083 except (TypeError, ValueError):
#    1084   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1085   # TypeError, when given unexpected types.  So we need to catch both.
#    1086   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~/miniforge3/envs/mosquito/lib/python3.10/site-packages/keras/backend.py:3968, in batch_get_value(tensors)
#    3956 """Returns the value of more than one tensor variable.
#    3957
#    3958 Args:
#    (...)
#    3965     RuntimeError: If this method is called inside defun.
#    3966 """
#    3967 if tf.executing_eagerly():
# -> 3968   return [x.numpy() for x in tensors]
#    3969 elif tf.inside_function():  # pylint: disable=protected-access
#    3970   raise RuntimeError('Cannot get value inside Tensorflow graph function.')
#
# File ~/miniforge3/envs/mosquito/lib/python3.10/site-packages/keras/backend.py:3968, in <listcomp>(.0)
#    3956 """Returns the value of more than one tensor variable.
#    3957
#    3958 Args:
#    (...)
#    3965     RuntimeError: If this method is called inside defun.
#    3966 """
#    3967 if tf.executing_eagerly():
# -> 3968   return [x.numpy() for x in tensors]
#    3969 elif tf.inside_function():  # pylint: disable=protected-access
#    3970   raise RuntimeError('Cannot get value inside Tensorflow graph function.')
#
# File ~/miniforge3/envs/mosquito/lib/python3.10/site-packages/tensorflow/python/ops/resource_variable_ops.py:637, in BaseResourceVariable.numpy(self)
#     635 def numpy(self):
#     636   if context.executing_eagerly():
# --> 637     return self.read_value().numpy()
#     638   raise NotImplementedError(
#     639       "numpy() is only available when eager execution is enabled.")
#
# File ~/miniforge3/envs/mosquito/lib/python3.10/site-packages/tensorflow/python/framework/ops.py:1160, in _EagerTensorBase.numpy(self)
#    1158 # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
#    1159 maybe_arr = self._numpy()  # pylint: disable=protected-access
# -> 1160 return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#
# KeyboardInterrupt:

# %%
#-----Run 6

# %%
tmpX = tempfile.TemporaryDirectory().name
RandomTrainValTest(mos_img_dir, tmpX, ratio = (0.8,0.2,0))
#-----------------------
# Out:
# Ratio = (0.8, 0.2, -0.0).
# Found Aedes vexans
# No. of files in Aedes vexans = 5901.
# No. of files in "/tmp/tmp0k151tmd/train/Aedes vexans/" should be around 4721.
# No. of files in /tmp/tmp0k151tmd/train/Aedes vexans/ = 4749.
# No. of files in "/tmp/tmp0k151tmd/test/Aedes vexans/" should be around 0.
# No. of files in /tmp/tmp0k151tmd/test/Aedes vexans/ = 0.
# No. of files in "/tmp/tmp0k151tmd/val/Aedes vexans/" should be around 1181.
# No. of files in /tmp/tmp0k151tmd/val/Aedes vexans/ = 1152.
# Found Anopheles sinensis
# No. of files in Anopheles sinensis = 5923.
# No. of files in "/tmp/tmp0k151tmd/train/Anopheles sinensis/" should be around 4739.
# No. of files in /tmp/tmp0k151tmd/train/Anopheles sinensis/ = 4748.
# No. of files in "/tmp/tmp0k151tmd/test/Anopheles sinensis/" should be around 0.
# No. of files in /tmp/tmp0k151tmd/test/Anopheles sinensis/ = 0.
# No. of files in "/tmp/tmp0k151tmd/val/Anopheles sinensis/" should be around 1185.
# No. of files in /tmp/tmp0k151tmd/val/Anopheles sinensis/ = 1175.
# Found Culex tritaeniorhynchus
# No. of files in Culex tritaeniorhynchus = 5940.
# No. of files in "/tmp/tmp0k151tmd/train/Culex tritaeniorhynchus/" should be around 4752.
# No. of files in /tmp/tmp0k151tmd/train/Culex tritaeniorhynchus/ = 4752.
# No. of files in "/tmp/tmp0k151tmd/test/Culex tritaeniorhynchus/" should be around 0.
# No. of files in /tmp/tmp0k151tmd/test/Culex tritaeniorhynchus/ = 0.
# No. of files in "/tmp/tmp0k151tmd/val/Culex tritaeniorhynchus/" should be around 1188.
# No. of files in /tmp/tmp0k151tmd/val/Culex tritaeniorhynchus/ = 1188.
# Found Aedes albopictus
# No. of files in Aedes albopictus = 6000.
# No. of files in "/tmp/tmp0k151tmd/train/Aedes albopictus/" should be around 4800.
# No. of files in /tmp/tmp0k151tmd/train/Aedes albopictus/ = 4807.
# No. of files in "/tmp/tmp0k151tmd/test/Aedes albopictus/" should be around 0.
# No. of files in /tmp/tmp0k151tmd/test/Aedes albopictus/ = 0.
# No. of files in "/tmp/tmp0k151tmd/val/Aedes albopictus/" should be around 1200.
# No. of files in /tmp/tmp0k151tmd/val/Aedes albopictus/ = 1193.
# Found Non vectors
# No. of files in Non vectors = 6006.
# No. of files in "/tmp/tmp0k151tmd/train/Non vectors/" should be around 4805.
# No. of files in /tmp/tmp0k151tmd/train/Non vectors/ = 4818.
# No. of files in "/tmp/tmp0k151tmd/test/Non vectors/" should be around 0.
# No. of files in /tmp/tmp0k151tmd/test/Non vectors/ = 0.
# No. of files in "/tmp/tmp0k151tmd/val/Non vectors/" should be around 1202.
# No. of files in /tmp/tmp0k151tmd/val/Non vectors/ = 1188.
# Found Culex pipiens
# No. of files in Culex pipiens = 5970.
# No. of files in "/tmp/tmp0k151tmd/train/Culex pipiens/" should be around 4776.
# No. of files in /tmp/tmp0k151tmd/train/Culex pipiens/ = 4779.
# No. of files in "/tmp/tmp0k151tmd/test/Culex pipiens/" should be around 0.
# No. of files in /tmp/tmp0k151tmd/test/Culex pipiens/ = 0.
# No. of files in "/tmp/tmp0k151tmd/val/Culex pipiens/" should be around 1194.
# No. of files in /tmp/tmp0k151tmd/val/Culex pipiens/ = 1191.

# %%
(train_ds, val_ds) = read_ds(tmpX)
(train_ds, val_ds) = preprocessDS(train_ds, val_ds)
#-----------------------
# Out:
# Found 28653 files belonging to 6 classes.
# 2022-09-27 23:46:33.279189: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-27 23:46:34.122836: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22227 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:af:00.0, compute capability: 8.6
# Found 7087 files belonging to 6 classes.

# %%
model = buildSDModel()
model = loadVGG16ImageNetWeightsSD(model)
model = compileModel(model)
fitHistory = fitModel(model, train_ds, val_ds, lr_adjust, early_stopping)
#-----------------------
# Out:
# Start fitting from 2022/09/27-23:46:41
#
# Epoch 1: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 1/40
# 2022-09-27 23:46:48.207417: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8401
# 2022-09-27 23:46:50.645864: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 3582/3582 [==============================] - 243s 65ms/step - loss: 1.7970 - accuracy: 0.1996 - val_loss: 1.4723 - val_accuracy: 0.3388 - lr: 2.0000e-05
#
# Epoch 2: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 2/40
# 3582/3582 [==============================] - 221s 62ms/step - loss: 1.4132 - accuracy: 0.3985 - val_loss: 1.2470 - val_accuracy: 0.4915 - lr: 2.0000e-05
#
# Epoch 3: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 3/40
# 3582/3582 [==============================] - 217s 61ms/step - loss: 1.0702 - accuracy: 0.5802 - val_loss: 0.8367 - val_accuracy: 0.6743 - lr: 2.0000e-05
#
# Epoch 4: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 4/40
# 3582/3582 [==============================] - 216s 60ms/step - loss: 0.7652 - accuracy: 0.7111 - val_loss: 0.5848 - val_accuracy: 0.7912 - lr: 2.0000e-05
#
# Epoch 5: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch
LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 21/40
# 3582/3582 [==============================] - 215s 60ms/step - loss: 0.0240 - accuracy: 0.9923 - val_loss: 0.1904 - val_accuracy: 0.9477 - lr: 5.0000e-06
#
# Epoch 22: LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 22/40
# 3582/3582 [==============================] - 215s 60ms/step - loss: 0.0244 - accuracy: 0.9915 - val_loss: 0.2050 - val_accuracy: 0.9453 - lr: 5.0000e-06
#
# Epoch 23: LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 23/40
# 3582/3582 [==============================] - 215s 60ms/step - loss: 0.0225 - accuracy: 0.9926 - val_loss: 0.2011 - val_accuracy: 0.9484 - lr: 5.0000e-06
#
# Epoch 24: LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 24/40
# 3582/3582 [==============================] - 214s 60ms/step - loss: 0.0185 - accuracy: 0.9939 - val_loss: 0.1845 - val_accuracy: 0.9537 - lr: 5.0000e-06
#
# Epoch 25: LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 25/40
# 3582/3582 [==============================] - 215s 60ms/step - loss: 0.0198 - accuracy: 0.9937 - val_loss: 0.1932 - val_accuracy: 0.9513 - lr: 5.0000e-06
#
# Epoch 26: LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 26/40
# 3582/3582 [==============================] - 215s 60ms/step - loss: 0.0156 - accuracy: 0.9945 - val_loss: 0.2161 - val_accuracy: 0.9462 - lr: 5.0000e-06
#
# Epoch 27: LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 27/40
# 3582/3582 [==============================] - 214s 60ms/step - loss: 0.0163 - accuracy: 0.9948 - val_loss: 0.2279 - val_accuracy: 0.9434 - lr: 5.0000e-06
#
# Epoch 28: LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 28/40
# 3582/3582 [==============================] - 214s 60ms/step - loss: 0.0161 - accuracy: 0.9939 - val_loss: 0.2108 - val_accuracy: 0.9491 - lr: 5.0000e-06
#
# Epoch 29: LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 29/40
# 3582/3582 [==============================] - 214s 60ms/step - loss: 0.0156 - accuracy: 0.9945 - val_loss: 0.2317 - val_accuracy: 0.9482 - lr: 5.0000e-06
#
# Epoch 30: LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 30/40
# 3582/3582 [==============================] - 215s 60ms/step - loss: 0.0164 - accuracy: 0.9944 - val_loss: 0.2222 - val_accuracy: 0.9462 - lr: 5.0000e-06
#
# Epoch 31: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 31/40
# 3582/3582 [==============================] - 214s 60ms/step - loss: 0.0131 - accuracy: 0.9955 - val_loss: 0.1990 - val_accuracy: 0.9522 - lr: 2.5000e-06
#
# Epoch 32: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 32/40
# 3582/3582 [==============================] - 214s 60ms/step - loss: 0.0116 - accuracy: 0.9962 - val_loss: 0.2224 - val_accuracy: 0.9481 - lr: 2.5000e-06
#
# Epoch 33: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 33/40
# 3582/3582 [==============================] - 215s 60ms/step - loss: 0.0126 - accuracy: 0.9955 - val_loss: 0.1988 - val_accuracy: 0.9546 - lr: 2.5000e-06
# End fitting at 2022/09/28-01:45:46

# %%
maxAcc = np.max(fitHistory.history['val_accuracy'])
print('Maximum test accuracy is at', np.round(maxAcc*100,2), '%.')
plotAccuracyLoss(fitHistory)
#-----------------------
# Out:
# Maximum test accuracy is at 95.65 %.

# %%
printConfusionMatrix(model, val_ds)
earlyModelPath = saveSDOModel(model)
# Out:
# 886/886 [==============================] - 14s 15ms/step
# Confusion Matrix
# [[1155    4    8    3   22    1]
#  [   4 1053   10   26   31   28]
#  [   2   17 1144    3    0    9]
#  [   0    4    8 1160    0   19]
#  [   1   43    2    1 1141    0]
#  [   4   26    8   18    6 1126]]
#
#
# Classification Report
#                          precision    recall  f1-score   support
#
#        Aedes albopictus       0.99      0.97      0.98      1193
#            Aedes vexans       0.92      0.91      0.92      1152
#      Anopheles sinensis       0.97      0.97      0.97      1175
#           Culex pipiens       0.96      0.97      0.97      1191
# Culex tritaeniorhynchus       0.95      0.96      0.96      1188
#             Non vectors       0.95      0.95      0.95      1188
#
#                accuracy                           0.96      7087
#               macro avg       0.96      0.96      0.96      7087
#            weighted avg       0.96      0.96      0.96      7087
#
# Model is saved in ./models/Model_SDO_Park_2022-09-28_01-46.h5

# %%
#-----Run 7

# %%
tmpX = tempfile.TemporaryDirectory().name
RandomTrainValTest(mos_img_dir, tmpX, ratio = (0.8,0.2,0))
#-----------------------
# Out:
# Ratio = (0.8, 0.2, -0.0).
# Found Aedes vexans
# No. of files in Aedes vexans = 5901.
# No. of files in "/tmp/tmp0x3tl4o8/train/Aedes vexans/" should be around 4721.
# No. of files in /tmp/tmp0x3tl4o8/train/Aedes vexans/ = 4726.
# No. of files in "/tmp/tmp0x3tl4o8/test/Aedes vexans/" should be around 0.
# No. of files in /tmp/tmp0x3tl4o8/test/Aedes vexans/ = 0.
# No. of files in "/tmp/tmp0x3tl4o8/val/Aedes vexans/" should be around 1181.
# No. of files in /tmp/tmp0x3tl4o8/val/Aedes vexans/ = 1175.
# Found Anopheles sinensis
# No. of files in Anopheles sinensis = 5923.
# No. of files in "/tmp/tmp0x3tl4o8/train/Anopheles sinensis/" should be around 4739.
# No. of files in /tmp/tmp0x3tl4o8/train/Anopheles sinensis/ = 4740.
# No. of files in "/tmp/tmp0x3tl4o8/test/Anopheles sinensis/" should be around 0.
# No. of files in /tmp/tmp0x3tl4o8/test/Anopheles sinensis/ = 0.
# No. of files in "/tmp/tmp0x3tl4o8/val/Anopheles sinensis/" should be around 1185.
# No. of files in /tmp/tmp0x3tl4o8/val/Anopheles sinensis/ = 1183.
# Found Culex tritaeniorhynchus
# No. of files in Culex tritaeniorhynchus = 5940.
# No. of files in "/tmp/tmp0x3tl4o8/train/Culex tritaeniorhynchus/" should be around 4752.
# No. of files in /tmp/tmp0x3tl4o8/train/Culex tritaeniorhynchus/ = 4783.
# No. of files in "/tmp/tmp0x3tl4o8/test/Culex tritaeniorhynchus/" should be around 0.
# No. of files in /tmp/tmp0x3tl4o8/test/Culex tritaeniorhynchus/ = 0.
# No. of files in "/tmp/tmp0x3tl4o8/val/Culex tritaeniorhynchus/" should be around 1188.
# No. of files in /tmp/tmp0x3tl4o8/val/Culex tritaeniorhynchus/ = 1157.
# Found Aedes albopictus
# No. of files in Aedes albopictus = 6000.
# No. of files in "/tmp/tmp0x3tl4o8/train/Aedes albopictus/" should be around 4800.
# No. of files in /tmp/tmp0x3tl4o8/train/Aedes albopictus/ = 4822.
# No. of files in "/tmp/tmp0x3tl4o8/test/Aedes albopictus/" should be around 0.
# No. of files in /tmp/tmp0x3tl4o8/test/Aedes albopictus/ = 0.
# No. of files in "/tmp/tmp0x3tl4o8/val/Aedes albopictus/" should be around 1200.
# No. of files in /tmp/tmp0x3tl4o8/val/Aedes albopictus/ = 1178.
# Found Non vectors
# No. of files in Non vectors = 6006.
# No. of files in "/tmp/tmp0x3tl4o8/train/Non vectors/" should be around 4805.
# No. of files in /tmp/tmp0x3tl4o8/train/Non vectors/ = 4870.
# No. of files in "/tmp/tmp0x3tl4o8/test/Non vectors/" should be around 0.
# No. of files in /tmp/tmp0x3tl4o8/test/Non vectors/ = 0.
# No. of files in "/tmp/tmp0x3tl4o8/val/Non vectors/" should be around 1202.
# No. of files in /tmp/tmp0x3tl4o8/val/Non vectors/ = 1136.
# Found Culex pipiens
# No. of files in Culex pipiens = 5970.
# No. of files in "/tmp/tmp0x3tl4o8/train/Culex pipiens/" should be around 4776.
# No. of files in /tmp/tmp0x3tl4o8/train/Culex pipiens/ = 4783.
# No. of files in "/tmp/tmp0x3tl4o8/test/Culex pipiens/" should be around 0.
# No. of files in /tmp/tmp0x3tl4o8/test/Culex pipiens/ = 0.
# No. of files in "/tmp/tmp0x3tl4o8/val/Culex pipiens/" should be around 1194.
# No. of files in /tmp/tmp0x3tl4o8/val/Culex pipiens/ = 1187.

# %%
(train_ds, val_ds) = read_ds(tmpX)
(train_ds, val_ds) = preprocessDS(train_ds, val_ds)
#-----------------------
# Out:
# Found 28724 files belonging to 6 classes.
# Found 7016 files belonging to 6 classes.

# %%
model = buildSDModel()
model = loadVGG16ImageNetWeightsSD(model)
model = compileModel(model)
fitHistory = fitModel(model, train_ds, val_ds, lr_adjust, early_stopping)
#-----------------------
# Out:
# Start fitting from 2022/09/28-01:46:23
#
# Epoch 1: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 1/40
# 3591/3591 [==============================] - 223s 60ms/step - loss: 1.7899 - accuracy: 0.2076 - val_loss: 1.4500 - val_accuracy: 0.3798 - lr: 2.0000e-05
#
# Epoch 2: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 2/40
# 3591/3591 [==============================] - 216s 60ms/step - loss: 1.3917 - accuracy: 0.4143 - val_loss: 1.1165 - val_accuracy: 0.5725 - lr: 2.0000e-05
#
# Epoch 3: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 3/40
# 3591/3591 [==============================] - 216s 60ms/step - loss: 1.0060 - accuracy: 0.6129 - val_loss: 0.7757 - val_accuracy: 0.7008 - lr: 2.0000e-05
#
# Epoch 4: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 4/40
# 3591/3591 [==============================] - 216s 60ms/step - loss: 0.7092 - accuracy: 0.7359 - val_loss: 0.5408 - val_accuracy: 0.7940 - lr: 2.0000e-05
#
# Epoch 5: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 5/40
# 3591/3591 [==============================] - 216s 60ms/step - loss: 0.5057 - accuracy: 0.8144 - val_loss: 0.4232 - val_accuracy: 0.8469 - lr: 2.0000e-05
#
# Epoch 6: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 6/40
# 3591/3591 [==============================] - 215s 60ms/step - loss: 0.3663 - accuracy: 0.8678 - val_loss: 0.3853 - val_accuracy: 0.8645 - lr: 2.0000e-05
#
# Epoch 7: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 7/40
# 3591/3591 [==============================] - 216s 60ms/step - loss: 0.2820 - accuracy: 0.8985 - val_loss: 0.2684 - val_accuracy: 0.8995 - lr: 2.0000e-05
#
# Epoch 8: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 8/40
# 3591/3591 [==============================] - 215s 60ms/step - loss: 0.2121 - accuracy: 0.9237 - val_loss: 0.2384 - val_accuracy: 0.9113 - lr: 2.0000e-05
#
# Epoch 9: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 9/40
# 3591/3591 [==============================] - 215s 60ms/step - loss: 0.1695 - accuracy: 0.9404 - val_loss: 0.2108 - val_accuracy: 0.9196 - lr: 2.0000e-05
#
# Epoch 10: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch
LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 31/40
# 3591/3591 [==============================] - 215s 60ms/step - loss: 0.0101 - accuracy: 0.9969 - val_loss: 0.1574 - val_accuracy: 0.9580 - lr: 2.5000e-06
#
# Epoch 32: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 32/40
# 3591/3591 [==============================] - 214s 60ms/step - loss: 0.0127 - accuracy: 0.9958 - val_loss: 0.1557 - val_accuracy: 0.9580 - lr: 2.5000e-06
#
# Epoch 33: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 33/40
# 3591/3591 [==============================] - 215s 60ms/step - loss: 0.0110 - accuracy: 0.9964 - val_loss: 0.1570 - val_accuracy: 0.9588 - lr: 2.5000e-06
#
# Epoch 34: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 34/40
# 3591/3591 [==============================] - 214s 60ms/step - loss: 0.0117 - accuracy: 0.9961 - val_loss: 0.1649 - val_accuracy: 0.9558 - lr: 2.5000e-06
#
# Epoch 35: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 35/40
# 3591/3591 [==============================] - 215s 60ms/step - loss: 0.0108 - accuracy: 0.9965 - val_loss: 0.1684 - val_accuracy: 0.9560 - lr: 2.5000e-06
#
# Epoch 36: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 36/40
# 3591/3591 [==============================] - 215s 60ms/step - loss: 0.0094 - accuracy: 0.9969 - val_loss: 0.1661 - val_accuracy: 0.9572 - lr: 2.5000e-06
#
# Epoch 37: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 37/40
# 3591/3591 [==============================] - 215s 60ms/step - loss: 0.0083 - accuracy: 0.9975 - val_loss: 0.1627 - val_accuracy: 0.9557 - lr: 2.5000e-06
#
# Epoch 38: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 38/40
# 3591/3591 [==============================] - 215s 60ms/step - loss: 0.0097 - accuracy: 0.9970 - val_loss: 0.1613 - val_accuracy: 0.9582 - lr: 2.5000e-06
#
# Epoch 39: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 39/40
# 3591/3591 [==============================] - 215s 60ms/step - loss: 0.0104 - accuracy: 0.9962 - val_loss: 0.1523 - val_accuracy: 0.9601 - lr: 2.5000e-06
#
# Epoch 40: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 40/40
# 3591/3591 [==============================] - 215s 60ms/step - loss: 0.0091 - accuracy: 0.9971 - val_loss: 0.1632 - val_accuracy: 0.9568 - lr: 2.5000e-06
# End fitting at 2022/09/28-04:09:49

# %%
maxAcc = np.max(fitHistory.history['val_accuracy'])
print('Maximum test accuracy is at', np.round(maxAcc*100,2), '%.')
plotAccuracyLoss(fitHistory)
#-----------------------
# Out:
# Maximum test accuracy is at 96.08 %.

# %%
printConfusionMatrix(model, val_ds)
earlyModelPath = saveSDOModel(model)
# Out:
# 877/877 [==============================] - 14s 15ms/step
# Confusion Matrix
# [[1154   17    2    1    2    2]
#  [   1 1107    7    0   49   11]
#  [   3   14 1153    4    3    6]
#  [   1    2    2 1177    0    5]
#  [   0   33    0    2 1122    0]
#  [  11   51   22   50    2 1000]]
#
#
# Classification Report
#                          precision    recall  f1-score   support
#
#        Aedes albopictus       0.99      0.98      0.98      1178
#            Aedes vexans       0.90      0.94      0.92      1175
#      Anopheles sinensis       0.97      0.97      0.97      1183
#           Culex pipiens       0.95      0.99      0.97      1187
# Culex tritaeniorhynchus       0.95      0.97      0.96      1157
#             Non vectors       0.98      0.88      0.93      1136
#
#                accuracy                           0.96      7016
#               macro avg       0.96      0.96      0.96      7016
#            weighted avg       0.96      0.96      0.96      7016
#
# Model is saved in ./models/Model_SDO_Park_2022-09-28_04-10.h5

# %%
#-----Run 8

# %%
tmpX = tempfile.TemporaryDirectory().name
RandomTrainValTest(mos_img_dir, tmpX, ratio = (0.8,0.2,0))
#-----------------------
# Out:
# Ratio = (0.8, 0.2, -0.0).
# Found Aedes vexans
# No. of files in Aedes vexans = 5901.
# No. of files in "/tmp/tmpfcy_piv2/train/Aedes vexans/" should be around 4721.
# No. of files in /tmp/tmpfcy_piv2/train/Aedes vexans/ = 4736.
# No. of files in "/tmp/tmpfcy_piv2/test/Aedes vexans/" should be around 0.
# No. of files in /tmp/tmpfcy_piv2/test/Aedes vexans/ = 0.
# No. of files in "/tmp/tmpfcy_piv2/val/Aedes vexans/" should be around 1181.
# No. of files in /tmp/tmpfcy_piv2/val/Aedes vexans/ = 1165.
# Found Anopheles sinensis
# No. of files in Anopheles sinensis = 5923.
# No. of files in "/tmp/tmpfcy_piv2/train/Anopheles sinensis/" should be around 4739.
# No. of files in /tmp/tmpfcy_piv2/train/Anopheles sinensis/ = 4748.
# No. of files in "/tmp/tmpfcy_piv2/test/Anopheles sinensis/" should be around 0.
# No. of files in /tmp/tmpfcy_piv2/test/Anopheles sinensis/ = 0.
# No. of files in "/tmp/tmpfcy_piv2/val/Anopheles sinensis/" should be around 1185.
# No. of files in /tmp/tmpfcy_piv2/val/Anopheles sinensis/ = 1175.
# Found Culex tritaeniorhynchus
# No. of files in Culex tritaeniorhynchus = 5940.
# No. of files in "/tmp/tmpfcy_piv2/train/Culex tritaeniorhynchus/" should be around 4752.
# No. of files in /tmp/tmpfcy_piv2/train/Culex tritaeniorhynchus/ = 4763.
# No. of files in "/tmp/tmpfcy_piv2/test/Culex tritaeniorhynchus/" should be around 0.
# No. of files in /tmp/tmpfcy_piv2/test/Culex tritaeniorhynchus/ = 0.
# No. of files in "/tmp/tmpfcy_piv2/val/Culex tritaeniorhynchus/" should be around 1188.
# No. of files in /tmp/tmpfcy_piv2/val/Culex tritaeniorhynchus/ = 1177.
# Found Aedes albopictus
# No. of files in Aedes albopictus = 6000.
# No. of files in "/tmp/tmpfcy_piv2/train/Aedes albopictus/" should be around 4800.
# No. of files in /tmp/tmpfcy_piv2/train/Aedes albopictus/ = 4813.
# No. of files in "/tmp/tmpfcy_piv2/test/Aedes albopictus/" should be around 0.
# No. of files in /tmp/tmpfcy_piv2/test/Aedes albopictus/ = 0.
# No. of files in "/tmp/tmpfcy_piv2/val/Aedes albopictus/" should be around 1200.
# No. of files in /tmp/tmpfcy_piv2/val/Aedes albopictus/ = 1187.
# Found Non vectors
# No. of files in Non vectors = 6006.
# No. of files in "/tmp/tmpfcy_piv2/train/Non vectors/" should be around 4805.
# No. of files in /tmp/tmpfcy_piv2/train/Non vectors/ = 4832.
# No. of files in "/tmp/tmpfcy_piv2/test/Non vectors/" should be around 0.
# No. of files in /tmp/tmpfcy_piv2/test/Non vectors/ = 0.
# No. of files in "/tmp/tmpfcy_piv2/val/Non vectors/" should be around 1202.
# No. of files in /tmp/tmpfcy_piv2/val/Non vectors/ = 1174.
# Found Culex pipiens
# No. of files in Culex pipiens = 5970.
# No. of files in "/tmp/tmpfcy_piv2/train/Culex pipiens/" should be around 4776.
# No. of files in /tmp/tmpfcy_piv2/train/Culex pipiens/ = 4784.
# No. of files in "/tmp/tmpfcy_piv2/test/Culex pipiens/" should be around 0.
# No. of files in /tmp/tmpfcy_piv2/test/Culex pipiens/ = 0.
# No. of files in "/tmp/tmpfcy_piv2/val/Culex pipiens/" should be around 1194.
# No. of files in /tmp/tmpfcy_piv2/val/Culex pipiens/ = 1186.

# %%
(train_ds, val_ds) = read_ds(tmpX)
(train_ds, val_ds) = preprocessDS(train_ds, val_ds)
#-----------------------
# Out:
# Found 28676 files belonging to 6 classes.
# Found 7064 files belonging to 6 classes.

# %%
model = buildSDModel()
model = loadVGG16ImageNetWeightsSD(model)
model = compileModel(model)
fitHistory = fitModel(model, train_ds, val_ds, lr_adjust, early_stopping)
#-----------------------
# Out:
# Start fitting from 2022/09/28-04:10:25
#
# Epoch 1: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch
LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 21/40
# 3585/3585 [==============================] - 215s 60ms/step - loss: 0.0317 - accuracy: 0.9896 - val_loss: 0.1679 - val_accuracy: 0.9510 - lr: 5.0000e-06
#
# Epoch 22: LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 22/40
# 3585/3585 [==============================] - 215s 60ms/step - loss: 0.0271 - accuracy: 0.9909 - val_loss: 0.1654 - val_accuracy: 0.9540 - lr: 5.0000e-06
#
# Epoch 23: LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 23/40
# 3585/3585 [==============================] - 215s 60ms/step - loss: 0.0226 - accuracy: 0.9926 - val_loss: 0.1673 - val_accuracy: 0.9551 - lr: 5.0000e-06
#
# Epoch 24: LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 24/40
# 3585/3585 [==============================] - 214s 60ms/step - loss: 0.0249 - accuracy: 0.9917 - val_loss: 0.1669 - val_accuracy: 0.9530 - lr: 5.0000e-06
#
# Epoch 25: LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 25/40
# 3585/3585 [==============================] - 214s 60ms/step - loss: 0.0210 - accuracy: 0.9927 - val_loss: 0.1747 - val_accuracy: 0.9510 - lr: 5.0000e-06
#
# Epoch 26: LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 26/40
# 3585/3585 [==============================] - 216s 60ms/step - loss: 0.0237 - accuracy: 0.9917 - val_loss: 0.1674 - val_accuracy: 0.9557 - lr: 5.0000e-06
#
# Epoch 27: LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 27/40
# 3585/3585 [==============================] - 215s 60ms/step - loss: 0.0202 - accuracy: 0.9932 - val_loss: 0.1738 - val_accuracy: 0.9567 - lr: 5.0000e-06
#
# Epoch 28: LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 28/40
# 3585/3585 [==============================] - 214s 60ms/step - loss: 0.0219 - accuracy: 0.9929 - val_loss: 0.1753 - val_accuracy: 0.9526 - lr: 5.0000e-06
#
# Epoch 29: LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 29/40
# 3585/3585 [==============================] - 214s 60ms/step - loss: 0.0184 - accuracy: 0.9937 - val_loss: 0.1735 - val_accuracy: 0.9537 - lr: 5.0000e-06
#
# Epoch 30: LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 30/40
# 3585/3585 [==============================] - 215s 60ms/step - loss: 0.0186 - accuracy: 0.9941 - val_loss: 0.1701 - val_accuracy: 0.9555 - lr: 5.0000e-06
#
# Epoch 31: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 31/40
# 3585/3585 [==============================] - 215s 60ms/step - loss: 0.0169 - accuracy: 0.9946 - val_loss: 0.1691 - val_accuracy: 0.9571 - lr: 2.5000e-06
#
# Epoch 32: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 32/40
# 3585/3585 [==============================] - 215s 60ms/step - loss: 0.0164 - accuracy: 0.9947 - val_loss: 0.1704 - val_accuracy: 0.9565 - lr: 2.5000e-06
#
# Epoch 33: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 33/40
# 3585/3585 [==============================] - 215s 60ms/step - loss: 0.0147 - accuracy: 0.9955 - val_loss: 0.1708 - val_accuracy: 0.9565 - lr: 2.5000e-06
#
# Epoch 34: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 34/40
# 3585/3585 [==============================] - 215s 60ms/step - loss: 0.0138 - accuracy: 0.9951 - val_loss: 0.1839 - val_accuracy: 0.9557 - lr: 2.5000e-06
#
# Epoch 35: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 35/40
# 3585/3585 [==============================] - 214s 60ms/step - loss: 0.0139 - accuracy: 0.9953 - val_loss: 0.1723 - val_accuracy: 0.9547 - lr: 2.5000e-06
#
# Epoch 36: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 36/40
# 3585/3585 [==============================] - 215s 60ms/step - loss: 0.0131 - accuracy: 0.9958 - val_loss: 0.1782 - val_accuracy: 0.9546 - lr: 2.5000e-06
#
# Epoch 37: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 37/40
# 3585/3585 [==============================] - 215s 60ms/step - loss: 0.0119 - accuracy: 0.9958 - val_loss: 0.1767 - val_accuracy: 0.9537 - lr: 2.5000e-06
#
# Epoch 38: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 38/40
# 3585/3585 [==============================] - 215s 60ms/step - loss: 0.0132 - accuracy: 0.9957 - val_loss: 0.1847 - val_accuracy: 0.9575 - lr: 2.5000e-06
#
# Epoch 39: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 39/40
# 3585/3585 [==============================] - 215s 60ms/step - loss: 0.0114 - accuracy: 0.9963 - val_loss: 0.1846 - val_accuracy: 0.9561 - lr: 2.5000e-06
#
# Epoch 40: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 40/40
# 3585/3585 [==============================] - 214s 60ms/step - loss: 0.0109 - accuracy: 0.9962 - val_loss: 0.1827 - val_accuracy: 0.9555 - lr: 2.5000e-06
# End fitting at 2022/09/28-06:33:41

# %%
maxAcc = np.max(fitHistory.history['val_accuracy'])
print('Maximum test accuracy is at', np.round(maxAcc*100,2), '%.')
plotAccuracyLoss(fitHistory)
#-----------------------
# Out:
# Maximum test accuracy is at 95.75 %.

# %%
printConfusionMatrix(model, val_ds)
earlyModelPath = saveSDOModel(model)
# Out:
# 883/883 [==============================] - 14s 15ms/step
# Confusion Matrix
# [[1166    9    2    8    0    2]
#  [   1 1093    5    0   55   11]
#  [   0   30 1121    0    4   20]
#  [   0    1    8 1166    0   11]
#  [   3   54    3    2 1114    1]
#  [  13   36   17   18    0 1090]]
#
#
# Classification Report
#                          precision    recall  f1-score   support
#
#        Aedes albopictus       0.99      0.98      0.98      1187
#            Aedes vexans       0.89      0.94      0.92      1165
#      Anopheles sinensis       0.97      0.95      0.96      1175
#           Culex pipiens       0.98      0.98      0.98      1186
# Culex tritaeniorhynchus       0.95      0.95      0.95      1177
#             Non vectors       0.96      0.93      0.94      1174
#
#                accuracy                           0.96      7064
#               macro avg       0.96      0.96      0.96      7064
#            weighted avg       0.96      0.96      0.96      7064
#
# Model is saved in ./models/Model_SDO_Park_2022-09-28_06-33.h5

# %%
#-----Run 9

# %%
tmpX = tempfile.TemporaryDirectory().name
RandomTrainValTest(mos_img_dir, tmpX, ratio = (0.8,0.2,0))
#-----------------------
# Out:
# Ratio = (0.8, 0.2, -0.0).
# Found Aedes vexans
# No. of files in Aedes vexans = 5901.
# No. of files in "/tmp/tmpoh2wvg3v/train/Aedes vexans/" should be around 4721.
# No. of files in /tmp/tmpoh2wvg3v/train/Aedes vexans/ = 4728.
# No. of files in "/tmp/tmpoh2wvg3v/test/Aedes vexans/" should be around 0.
# No. of files in /tmp/tmpoh2wvg3v/test/Aedes vexans/ = 0.
# No. of files in "/tmp/tmpoh2wvg3v/val/Aedes vexans/" should be around 1181.
# No. of files in /tmp/tmpoh2wvg3v/val/Aedes vexans/ = 1173.
# Found Anopheles sinensis
# No. of files in Anopheles sinensis = 5923.
# No. of files in "/tmp/tmpoh2wvg3v/train/Anopheles sinensis/" should be around 4739.
# No. of files in /tmp/tmpoh2wvg3v/train/Anopheles sinensis/ = 4760.
# No. of files in "/tmp/tmpoh2wvg3v/test/Anopheles sinensis/" should be around 0.
# No. of files in /tmp/tmpoh2wvg3v/test/Anopheles sinensis/ = 0.
# No. of files in "/tmp/tmpoh2wvg3v/val/Anopheles sinensis/" should be around 1185.
# No. of files in /tmp/tmpoh2wvg3v/val/Anopheles sinensis/ = 1163.
# Found Culex tritaeniorhynchus
# No. of files in Culex tritaeniorhynchus = 5940.
# No. of files in "/tmp/tmpoh2wvg3v/train/Culex tritaeniorhynchus/" should be around 4752.
# No. of files in /tmp/tmpoh2wvg3v/train/Culex tritaeniorhynchus/ = 4780.
# No. of files in "/tmp/tmpoh2wvg3v/test/Culex tritaeniorhynchus/" should be around 0.
# No. of files in /tmp/tmpoh2wvg3v/test/Culex tritaeniorhynchus/ = 0.
# No. of files in "/tmp/tmpoh2wvg3v/val/Culex tritaeniorhynchus/" should be around 1188.
# No. of files in /tmp/tmpoh2wvg3v/val/Culex tritaeniorhynchus/ = 1160.
# Found Aedes albopictus
# No. of files in Aedes albopictus = 6000.
# No. of files in "/tmp/tmpoh2wvg3v/train/Aedes albopictus/" should be around 4800.
# No. of files in /tmp/tmpoh2wvg3v/train/Aedes albopictus/ = 4801.
# No. of files in "/tmp/tmpoh2wvg3v/test/Aedes albopictus/" should be around 0.
# No. of files in /tmp/tmpoh2wvg3v/test/Aedes albopictus/ = 0.
# No. of files in "/tmp/tmpoh2wvg3v/val/Aedes albopictus/" should be around 1200.
# No. of files in /tmp/tmpoh2wvg3v/val/Aedes albopictus/ = 1199.
# Found Non vectors
# No. of files in Non vectors = 6006.
# No. of files in "/tmp/tmpoh2wvg3v/train/Non vectors/" should be around 4805.
# No. of files in /tmp/tmpoh2wvg3v/train/Non vectors/ = 4823.
# No. of files in "/tmp/tmpoh2wvg3v/test/Non vectors/" should be around 0.
# No. of files in /tmp/tmpoh2wvg3v/test/Non vectors/ = 0.
# No. of files in "/tmp/tmpoh2wvg3v/val/Non vectors/" should be around 1202.
# No. of files in /tmp/tmpoh2wvg3v/val/Non vectors/ = 1183.
# Found Culex pipiens
# No. of files in Culex pipiens = 5970.
# No. of files in "/tmp/tmpoh2wvg3v/train/Culex pipiens/" should be around 4776.
# No. of files in /tmp/tmpoh2wvg3v/train/Culex pipiens/ = 4776.
# No. of files in "/tmp/tmpoh2wvg3v/test/Culex pipiens/" should be around 0.
# No. of files in /tmp/tmpoh2wvg3v/test/Culex pipiens/ = 0.
# No. of files in "/tmp/tmpoh2wvg3v/val/Culex pipiens/" should be around 1194.
# No. of files in /tmp/tmpoh2wvg3v/val/Culex pipiens/ = 1194.

# %%
(train_ds, val_ds) = read_ds(tmpX)
(train_ds, val_ds) = preprocessDS(train_ds, val_ds)
#-----------------------
# Out:
# Found 28668 files belonging to 6 classes.
# Found 7072 files belonging to 6 classes.

# %%
model = buildSDModel()
model = loadVGG16ImageNetWeightsSD(model)
model = compileModel(model)
fitHistory = fitModel(model, train_ds, val_ds, lr_adjust, early_stopping)
#-----------------------
# Out:
# Start fitting from 2022/09/28-06:34:20
#
# Epoch 1: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 1/40
# 3584/3584 [==============================] - 222s 60ms/step - loss: 1.8180 - accuracy: 0.1844 - val_loss: 1.7001 - val_accuracy: 0.2865 - lr: 2.0000e-05
#
# Epoch 2: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 2/40
# 3584/3584 [==============================] - 215s 60ms/step - loss: 1.5110 - accuracy: 0.3483 - val_loss: 1.3234 - val_accuracy: 0.4646 - lr: 2.0000e-05
#
# Epoch 3: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 3/40
# 3584/3584 [==============================] - 213s 60ms/step - loss: 1.2200 - accuracy: 0.5061 - val_loss: 0.9127 - val_accuracy: 0.6428 - lr: 2.0000e-05
#
# Epoch 4: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 4/40
# 3584/3584 [==============================] - 214s 60ms/step - loss: 0.8429 - accuracy: 0.6814 - val_loss: 0.6819 - val_accuracy: 0.7569 - lr: 2.0000e-05
#
# Epoch 5: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 5/40
# 3584/3584 [==============================] - 216s 60ms/step - loss: 0.6159 - accuracy: 0.7725 - val_loss: 0.6359 - val_accuracy: 0.7735 - lr: 2.0000e-05
#
# Epoch 6: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 6/40
# 3584/3584 [==============================] - 215s 60ms/step - loss: 0
40
# 3584/3584 [==============================] - 215s 60ms/step - loss: 0.0184 - accuracy: 0.9937 - val_loss: 0.2655 - val_accuracy: 0.9333 - lr: 5.0000e-06
#
# Epoch 28: LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 28/40
# 3584/3584 [==============================] - 215s 60ms/step - loss: 0.0176 - accuracy: 0.9943 - val_loss: 0.2587 - val_accuracy: 0.9352 - lr: 5.0000e-06
#
# Epoch 29: LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 29/40
# 3584/3584 [==============================] - 215s 60ms/step - loss: 0.0172 - accuracy: 0.9943 - val_loss: 0.2782 - val_accuracy: 0.9317 - lr: 5.0000e-06
#
# Epoch 30: LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 30/40
# 3584/3584 [==============================] - 214s 60ms/step - loss: 0.0178 - accuracy: 0.9942 - val_loss: 0.2871 - val_accuracy: 0.9300 - lr: 5.0000e-06
#
# Epoch 31: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 31/40
# 3584/3584 [==============================] - 215s 60ms/step - loss: 0.0140 - accuracy: 0.9955 - val_loss: 0.2770 - val_accuracy: 0.9321 - lr: 2.5000e-06
#
# Epoch 32: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 32/40
# 3584/3584 [==============================] - 215s 60ms/step - loss: 0.0135 - accuracy: 0.9957 - val_loss: 0.2615 - val_accuracy: 0.9367 - lr: 2.5000e-06
#
# Epoch 33: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 33/40
# 3584/3584 [==============================] - 215s 60ms/step - loss: 0.0133 - accuracy: 0.9957 - val_loss: 0.2725 - val_accuracy: 0.9361 - lr: 2.5000e-06
#
# Epoch 34: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 34/40
# 3584/3584 [==============================] - 215s 60ms/step - loss: 0.0134 - accuracy: 0.9955 - val_loss: 0.2609 - val_accuracy: 0.9386 - lr: 2.5000e-06
#
# Epoch 35: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 35/40
# 3584/3584 [==============================] - 214s 60ms/step - loss: 0.0129 - accuracy: 0.9956 - val_loss: 0.2640 - val_accuracy: 0.9379 - lr: 2.5000e-06
#
# Epoch 36: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 36/40
# 3584/3584 [==============================] - 215s 60ms/step - loss: 0.0122 - accuracy: 0.9959 - val_loss: 0.2506 - val_accuracy: 0.9385 - lr: 2.5000e-06
#
# Epoch 37: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 37/40
# 3584/3584 [==============================] - 215s 60ms/step - loss: 0.0114 - accuracy: 0.9960 - val_loss: 0.2642 - val_accuracy: 0.9389 - lr: 2.5000e-06
#
# Epoch 38: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 38/40
# 3584/3584 [==============================] - 214s 60ms/step - loss: 0.0119 - accuracy: 0.9962 - val_loss: 0.2749 - val_accuracy: 0.9364 - lr: 2.5000e-06
#
# Epoch 39: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 39/40
# 3584/3584 [==============================] - 215s 60ms/step - loss: 0.0092 - accuracy: 0.9972 - val_loss: 0.2964 - val_accuracy: 0.9344 - lr: 2.5000e-06
#
# Epoch 40: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 40/40
# 3584/3584 [==============================] - 214s 60ms/step - loss: 0.0116 - accuracy: 0.9963 - val_loss: 0.2774 - val_accuracy: 0.9371 - lr: 2.5000e-06
# End fitting at 2022/09/28-08:57:42

# %%
maxAcc = np.max(fitHistory.history['val_accuracy'])
print('Maximum test accuracy is at', np.round(maxAcc*100,2), '%.')
plotAccuracyLoss(fitHistory)
#-----------------------
# Out:
# Maximum test accuracy is at 93.89 %.

# %%
printConfusionMatrix(model, val_ds)
earlyModelPath = saveSDOModel(model)
# Out:
# 884/884 [==============================] - 14s 15ms/step
# Confusion Matrix
# [[1139   25   16    1   13    5]
#  [   0 1088   13    1   54   17]
#  [   1   58 1055    1    8   40]
#  [   0    8    4 1176    0    6]
#  [   1   57    0    0 1101    1]
#  [   0   56   13   41    5 1068]]
#
#
# Classification Report
#                          precision    recall  f1-score   support
#
#        Aedes albopictus       1.00      0.95      0.97      1199
#            Aedes vexans       0.84      0.93      0.88      1173
#      Anopheles sinensis       0.96      0.91      0.93      1163
#           Culex pipiens       0.96      0.98      0.97      1194
# Culex tritaeniorhynchus       0.93      0.95      0.94      1160
#             Non vectors       0.94      0.90      0.92      1183
#
#                accuracy                           0.94      7072
#               macro avg       0.94      0.94      0.94      7072
#            weighted avg       0.94      0.94      0.94      7072
#
# Model is saved in ./models/Model_SDO_Park_2022-09-28_08-57.h5

# %%
#-----Run 10

# %%
tmpX = tempfile.TemporaryDirectory().name
RandomTrainValTest(mos_img_dir, tmpX, ratio = (0.8,0.2,0))

#-----------------------
# Out:
# Ratio = (0.8, 0.2, -0.0).
# Found Aedes vexans
# No. of files in Aedes vexans = 5901.
# No. of files in "/tmp/tmpp91k94a4/train/Aedes vexans/" should be around 4721.
# No. of files in /tmp/tmpp91k94a4/train/Aedes vexans/ = 4721.
# No. of files in "/tmp/tmpp91k94a4/test/Aedes vexans/" should be around 0.
# No. of files in /tmp/tmpp91k94a4/test/Aedes vexans/ = 0.
# No. of files in "/tmp/tmpp91k94a4/val/Aedes vexans/" should be around 1181.
# No. of files in /tmp/tmpp91k94a4/val/Aedes vexans/ = 1180.
# Found Anopheles sinensis
# No. of files in Anopheles sinensis = 5923.
# No. of files in "/tmp/tmpp91k94a4/train/Anopheles sinensis/" should be around 4739.
# No. of files in /tmp/tmpp91k94a4/train/Anopheles sinensis/ = 4741.
# No. of files in "/tmp/tmpp91k94a4/test/Anopheles sinensis/" should be around 0.
# No. of files in /tmp/tmpp91k94a4/test/Anopheles sinensis/ = 0.
# No. of files in "/tmp/tmpp91k94a4/val/Anopheles sinensis/" should be around 1185.
# No. of files in /tmp/tmpp91k94a4/val/Anopheles sinensis/ = 1182.
# Found Culex tritaeniorhynchus
# No. of files in Culex tritaeniorhynchus = 5940.
# No. of files in "/tmp/tmpp91k94a4/train/Culex tritaeniorhynchus/" should be around 4752.
# No. of files in /tmp/tmpp91k94a4/train/Culex tritaeniorhynchus/ = 4753.
# No. of files in "/tmp/tmpp91k94a4/test/Culex tritaeniorhynchus/" should be around 0.
# No. of files in /tmp/tmpp91k94a4/test/Culex tritaeniorhynchus/ = 0.
# No. of files in "/tmp/tmpp91k94a4/val/Culex tritaeniorhynchus/" should be around 1188.
# No. of files in /tmp/tmpp91k94a4/val/Culex tritaeniorhynchus/ = 1187.
# Found Aedes albopictus
# No. of files in Aedes albopictus = 6000.
# No. of files in "/tmp/tmpp91k94a4/train/Aedes albopictus/" should be around 4800.
# No. of files in /tmp/tmpp91k94a4/train/Aedes albopictus/ = 4816.
# No. of files in "/tmp/tmpp91k94a4/test/Aedes albopictus/" should be around 0.
# No. of files in /tmp/tmpp91k94a4/test/Aedes albopictus/ = 0.
# No. of files in "/tmp/tmpp91k94a4/val/Aedes albopictus/" should be around 1200.
# No. of files in /tmp/tmpp91k94a4/val/Aedes albopictus/ = 1184.
# Found Non vectors
# No. of files in Non vectors = 6006.
# No. of files in "/tmp/tmpp91k94a4/train/Non vectors/" should be around 4805.
# No. of files in /tmp/tmpp91k94a4/train/Non vectors/ = 4864.
# No. of files in "/tmp/tmpp91k94a4/test/Non vectors/" should be around 0.
# No. of files in /tmp/tmpp91k94a4/test/Non vectors/ = 0.
# No. of files in "/tmp/tmpp91k94a4/val/Non vectors/" should be around 1202.
# No. of files in /tmp/tmpp91k94a4/val/Non vectors/ = 1142.
# Found Culex pipiens
# No. of files in Culex pipiens = 5970.
# No. of files in "/tmp/tmpp91k94a4/train/Culex pipiens/" should be around 4776.
# No. of files in /tmp/tmpp91k94a4/train/Culex pipiens/ = 4783.
# No. of files in "/tmp/tmpp91k94a4/test/Culex pipiens/" should be around 0.
# No. of files in /tmp/tmpp91k94a4/test/Culex pipiens/ = 0.
# No. of files in "/tmp/tmpp91k94a4/val/Culex pipiens/" should be around 1194.
# No. of files in /tmp/tmpp91k94a4/val/Culex pipiens/ = 1187.

# %%
(train_ds, val_ds) = read_ds(tmpX)
(train_ds, val_ds) = preprocessDS(train_ds, val_ds)
#-----------------------
# Out:
# Found 28678 files belonging to 6 classes.
# Found 7062 files belonging to 6 classes.

# %%
model = buildSDModel()
model = loadVGG16ImageNetWeightsSD(model)
model = compileModel(model)
fitHistory = fitModel(model, train_ds, val_ds, lr_adjust, early_stopping)
#-----------------------
# Out:
# Start fitting from 2022/09/28-08:58:21
#
# Epoch 1: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 1/40
# 3585/3585 [==============================] - 222s 60ms/step - loss: 1.8176 - accuracy: 0.1924 - val_loss: 1.6854 - val_accuracy: 0.2543 - lr: 2.0000e-05
#
# Epoch 2: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 2/40
# 3585/3585 [==============================] - 216s 60ms/step - loss: 1.4799 - accuracy: 0.3796 - val_loss: 1.0413 - val_accuracy: 0.5987 - lr: 2.0000e-05
#
# Epoch 3: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 3/40
# 3585/3585 [==============================] - 214s 60ms/step - loss: 1.0562 - accuracy: 0.5797 - val_loss: 0.7235 - val_accuracy: 0.7287 - lr: 2.0000e-05
#
# Epoch 4: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 4/40
# 3585/3585 [==============================] - 215s 60ms/step - loss: 0.7660 - accuracy: 0.7082 - val_loss: 0.5857 - val_accuracy: 0.7740 - lr: 2.0000e-05
#
# Epoch 5: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 5/40
# 3585/3585 [==============================] - 215s 60ms/step - loss: 0.5548 - accuracy: 0.7936 - val_loss: 0.4894 - val_accuracy: 0.8212 - lr: 2.0000e-05
#
# Epoch 6: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 6/40
# 3585/3585 [==============================] - 215s 60ms/step - loss: 0.4124 - accuracy: 0.8496 - val_loss: 0.3681 - val_accuracy: 0.8638 - lr: 2.0000e-05
#
# Epoch 7: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 7/40
# 3585/3585 [==============================] - 215s 60ms/step - loss: 0.2982 - accuracy: 0.8923 - val_loss: 0.2854 - val_accuracy: 0.9006 - lr: 2.0000e-05
#
# Epoch 8: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 8/40
# 3585/3585 [==============================] - 215s 60ms/step - loss: 0.2317 - accuracy: 0.9185 - val_loss: 0.2437 - val_accuracy: 0.9135 - lr: 2.0000e-05
#
# Epoch 9: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 9/40
# 3585/3585 [==============================] - 216s 60ms/step - loss: 0.1772 - accuracy: 0.9386 - val_loss: 0.2035 - val_accuracy: 0.9310 - lr: 2.0000e-05
#
# Epoch 10: LearningRateScheduler setting learning rate to 1.9999999494757503e-05.
# Epoch 10/40
# 3585/3585 [==============================] - 213s 60ms/step - loss: 0.1458 - accuracy: 0.9492 - val_loss: 0.2067 - val_accuracy: 0.9278 - lr: 2.0000e-05
#
# Epoch 11: LearningRateScheduler setting learning rate to 9.999999747378752e-06.
# Epoch 11/40
# 3585/3585 [==============================] - 215s 60ms/step - loss: 0.0929 - accuracy: 0.9670 - val_loss: 0.1877 - val_accuracy: 0.9391 - lr: 1.0000e-05
#
# Epoch 12: LearningRateScheduler setting learning rate to 9.999999747378752e-06.
# Epoch 12/40
# 3585/3585 [==============================] - 207s 58ms/step - loss: 0.0779 - accuracy: 0.9722 - val_loss: 0.2192 - val_accuracy: 0.9292 - lr: 1.0000e-05
#
# Epoch 13: LearningRateScheduler setting learning rate to 9.999999747378752e-06.
# Epoch 13/40
# 3585/3585 [==============================] - 211s 59ms/step - loss: 0.0727 - accuracy: 0.9744 - val_loss: 0.1801 - val_accuracy: 0.9442 - lr: 1.0000e-05
#
# Epoch 14: LearningRateScheduler setting learning rate to 9.999999747378752e-06.
# Epoch
LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 29/40
# 3585/3585 [==============================] - 208s 58ms/step - loss: 0.0166 - accuracy: 0.9944 - val_loss: 0.1924 - val_accuracy: 0.9523 - lr: 5.0000e-06
#
# Epoch 30: LearningRateScheduler setting learning rate to 4.999999873689376e-06.
# Epoch 30/40
# 3585/3585 [==============================] - 205s 57ms/step - loss: 0.0187 - accuracy: 0.9938 - val_loss: 0.2191 - val_accuracy: 0.9448 - lr: 5.0000e-06
#
# Epoch 31: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 31/40
# 3585/3585 [==============================] - 204s 57ms/step - loss: 0.0163 - accuracy: 0.9945 - val_loss: 0.1966 - val_accuracy: 0.9510 - lr: 2.5000e-06
#
# Epoch 32: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 32/40
# 3585/3585 [==============================] - 207s 58ms/step - loss: 0.0129 - accuracy: 0.9958 - val_loss: 0.1968 - val_accuracy: 0.9519 - lr: 2.5000e-06
#
# Epoch 33: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 33/40
# 3585/3585 [==============================] - 212s 59ms/step - loss: 0.0133 - accuracy: 0.9960 - val_loss: 0.2062 - val_accuracy: 0.9482 - lr: 2.5000e-06
#
# Epoch 34: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 34/40
# 3585/3585 [==============================] - 204s 57ms/step - loss: 0.0129 - accuracy: 0.9957 - val_loss: 0.1966 - val_accuracy: 0.9510 - lr: 2.5000e-06
#
# Epoch 35: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 35/40
# 3585/3585 [==============================] - 208s 58ms/step - loss: 0.0142 - accuracy: 0.9955 - val_loss: 0.1930 - val_accuracy: 0.9517 - lr: 2.5000e-06
#
# Epoch 36: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 36/40
# 3585/3585 [==============================] - 206s 58ms/step - loss: 0.0127 - accuracy: 0.9959 - val_loss: 0.2001 - val_accuracy: 0.9506 - lr: 2.5000e-06
#
# Epoch 37: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 37/40
# 3585/3585 [==============================] - 205s 57ms/step - loss: 0.0114 - accuracy: 0.9962 - val_loss: 0.1945 - val_accuracy: 0.9533 - lr: 2.5000e-06
#
# Epoch 38: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 38/40
# 3585/3585 [==============================] - 208s 58ms/step - loss: 0.0110 - accuracy: 0.9961 - val_loss: 0.1940 - val_accuracy: 0.9538 - lr: 2.5000e-06
#
# Epoch 39: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 39/40
# 3585/3585 [==============================] - 206s 58ms/step - loss: 0.0115 - accuracy: 0.9963 - val_loss: 0.1991 - val_accuracy: 0.9526 - lr: 2.5000e-06
#
# Epoch 40: LearningRateScheduler setting learning rate to 2.499999936844688e-06.
# Epoch 40/40
# 3585/3585 [==============================] - 205s 57ms/step - loss: 0.0105 - accuracy: 0.9967 - val_loss: 0.1952 - val_accuracy: 0.9531 - lr: 2.5000e-06
# End fitting at 2022/09/28-11:17:31

# %%
maxAcc = np.max(fitHistory.history['val_accuracy'])
print('Maximum test accuracy is at', np.round(maxAcc*100,2), '%.')
plotAccuracyLoss(fitHistory)
#-----------------------
# Out:
# Maximum test accuracy is at 95.38 %.

# %%
printConfusionMatrix(model, val_ds)
earlyModelPath = saveSDOModel(model)
# Out:
# 883/883 [==============================] - 14s 15ms/step
# Confusion Matrix
# [[1138   17    5    0   22    2]
#  [   0 1117    6   10   32   15]
#  [   1   36 1110    3    1   31]
#  [   1    0    2 1179    0    5]
#  [   1   43    0    0 1143    0]
#  [   3   40   14   31   10 1044]]
#
#
# Classification Report
#                          precision    recall  f1-score   support
#
#        Aedes albopictus       0.99      0.96      0.98      1184
#            Aedes vexans       0.89      0.95      0.92      1180
#      Anopheles sinensis       0.98      0.94      0.96      1182
#           Culex pipiens       0.96      0.99      0.98      1187
# Culex tritaeniorhynchus       0.95      0.96      0.95      1187
#             Non vectors       0.95      0.91      0.93      1142
#
#                accuracy                           0.95      7062
#               macro avg       0.95      0.95      0.95      7062
#            weighted avg       0.95      0.95      0.95      7062
#
# Model is saved in ./models/Model_SDO_Park_2022-09-28_11-17.h5
